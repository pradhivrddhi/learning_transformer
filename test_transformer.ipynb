# %%
from transformer.config import FetchFromPretrained as ConfigFromPretrained

# %%
from transformer.tokenizer import FetchFromPretrained as TokenizerFromPretrained

# %%
from datasets import load_dataset

# %%
import torch

# %%
device = 'cuda' if torch.cuda.is_available() else 'cpu'
device = 'cpu'
device
# Out:
# 'cpu'

# %%
data = load_dataset('AlekseyKorshuk/books')
data
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['text'],
#         num_rows: 741
#     })
# })

# %%
model_ckpt = 'bert-base-uncased'

# %%
config = ConfigFromPretrained(model_ckpt=model_ckpt).fetch()
config
# Out:
# BertConfig {
#   "_name_or_path": "bert-base-uncased",
#   "architectures": [
#     "BertForMaskedLM"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "classifier_dropout": null,
#   "gradient_checkpointing": false,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "layer_norm_eps": 1e-12,
#   "max_position_embeddings": 512,
#   "model_type": "bert",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "pad_token_id": 0,
#   "position_embedding_type": "absolute",
#   "transformers_version": "4.39.2",
#   "type_vocab_size": 2,
#   "use_cache": true,
#   "vocab_size": 30522
# }

# %%
config.hidden_size = 128
config.intermediate_size = 1024 
config.compress_layer_size = 128
config.max_position_embeddings = 128
config.num_attention_heads = 64
config.num_hidden_layers = 8
config.device = device
config.dtype = torch.float32

# %%
batch_size = 8

# %%
tokenizer = TokenizerFromPretrained(model_ckpt=model_ckpt).fetch()
tokenizer
# Out:
# BertTokenizerFast(name_or_path='bert-base-uncased', vocab_size=30522, model_max_length=512, is_fast=True, padding_side='right', truncation_side='right', special_tokens={'unk_token': '[UNK]', 'sep_token': '[SEP]', 'pad_token': '[PAD]', 'cls_token': '[CLS]', 'mask_token': '[MASK]'}, clean_up_tokenization_spaces=True),  added_tokens_decoder={
# 	0: AddedToken("[PAD]", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	100: AddedToken("[UNK]", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	101: AddedToken("[CLS]", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	102: AddedToken("[SEP]", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	103: AddedToken("[MASK]", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# }

# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
import numpy as np

# %%
import os

# %%
import pickle

# %%
import random

# %%
import re

# %%
files_count = len(data['train'])
files_count
# Out:
# 741

# %%
split_index_1, split_index_2 = int(files_count * 0.8), int(files_count * 0.9)
split_index_1, split_index_2
# Out:
# (592, 666)

# %%
def get_data_from_random_files(split):
    indices = []
    if split == 'train':
        file_id = random.randint(0, split_index_1)
    elif split == 'test':
        file_id = random.randint(split_index_1, split_index_2)
    elif split == 'val':
        file_id = random.randint(split_index_2, files_count)

    file = data['train'][file_id]['text']

    input_ids = tokenizer(file, return_tensors='pt', add_special_tokens=False).input_ids[0]
    return input_ids

# %%
def get_batch(split):
    input_ids = get_data_from_random_files(split=split)
    ix = torch.randint(len(input_ids) - config.max_position_embeddings, (batch_size,))
    x = torch.stack([input_ids[i:i + config.max_position_embeddings] for i in ix])
    y = torch.stack([input_ids[i + 1:i + config.max_position_embeddings + 1] for i in ix])
    x, y = x.to(torch.int64).to(device), y.to(torch.int64).to(device)
    return x, y

# %%
get_data_from_random_files('train')
# Out:
# Token indices sequence length is longer than the specified maximum sequence length for this model (1469867 > 512). Running this sequence through the model will result in indexing errors
# tensor([1036, 1036, 2748,  ..., 2026, 3566, 1012])

# %%
get_batch('train')
# Out:
# (tensor([[ 1029,  1005,  1005,  ...,  1012,  1036,  1036],
#          [ 2007,  2033,  2005,  ...,  1012,  2008,  1005],
#          [ 1997,  1996,  2300,  ...,  1012,  1996, 18499],
#          ...,
#          [ 2524, 15113, 14855,  ...,  1025,  1045,  3140],
#          [ 1036,  1045,  2097,  ...,  2052,  2963,  1012],
#          [ 1036,  1036,  2017,  ...,  3961,  4333,  2055]]),
#  tensor([[ 1005,  1005,  7733,  ...,  1036,  1036,  2272],
#          [ 2033,  2005,  1037,  ...,  2008,  1005,  1055],
#          [ 1996,  2300,  1012,  ...,  1996, 18499,  6873],
#          ...,
#          [15113, 14855, 23200,  ...,  1045,  3140,  2009],
#          [ 1045,  2097,  2156,  ...,  2963,  1012,  2021],
#          [ 1036,  2017,  2024,  ...,  4333,  2055,  2009]]))

# %%
from transformer.head.text_generator_decoder_only import TextGenerator

# %%
generator = TextGenerator(config)

# %%
gen = generator.to(device)

# %%
eval_iters = 100

# %%
eval_iter_ticks = 5

# %%
X, Y = get_batch('train')
logits, loss = gen(X, Y, tokenizer)
logits, logits.size(), loss
# Out:
# [unused823] alexandreifying receptor nearing prairie urge mathews
# re ran. say'texted of talk
# (tensor([[-0.8650, -0.5177,  0.1017,  ...,  0.6171,  0.1362,  0.3305],
#          [-0.1632, -0.7614,  0.4080,  ...,  0.6095,  0.4628,  0.2499],
#          [ 0.6692, -0.2312, -0.4737,  ..., -0.0150, -0.3001, -0.0529],
#          ...,
#          [-0.1580,  0.4409, -0.2210,  ..., -0.0432, -0.1676, -0.0061],
#          [ 0.0568, -0.3153, -0.2447,  ..., -0.5499, -0.4244, -0.5407],
#          [ 0.5821,  0.2160, -0.8159,  ...,  1.3224,  0.9266,  0.4906]],
#         grad_fn=<SliceBackward0>),
#  torch.Size([8, 30522]),
#  tensor(10.4422, grad_fn=<NllLossBackward0>))

# %%
pretrained = False

# %%
build_pretrained = False

# %%
@torch.no_grad()
def estimate_loss():
    out = {}
    if (not pretrained) or build_pretrained:
        with open('text_generator.pkl', 'wb') as handler:
            pickle.dump(gen, handler)
    gen.eval()
    for split in ['train', 'val']:
        losses = torch.zeros(eval_iters)
        for k in range(eval_iter_ticks):
            X, Y = get_batch(split)
            logits, loss = gen(X, Y)
            losses[k] = loss.item()
        out[split] = losses.mean()
    gen.train()
    return out

# %%
learning_rate = 5e-4

# %%
iterations = 10000

# %%
if (not pretrained) or build_pretrained:
    # create a PyTorch optimizer
    optimizer = torch.optim.AdamW(gen.parameters(), lr=learning_rate, weight_decay=0.01, amsgrad=True)

    for iter in range(iterations):
        try:
            
            if (iter != 0) and (iter % eval_iters == 0):
                losses = estimate_loss()
                train_loss = losses['train']
                val_loss = losses['val']
                print(f'Loss at step = {iter} for train data is {train_loss:.4f} for val it is {val_loss:.4f}')

            # sample a batch of data
            xb, yb = get_batch('train')

            # evaluate the loss
            logits, loss = gen.forward(xb, yb, tokenizer)
            if not torch.isnan(loss).any():
                print(iter, loss)
                optimizer.zero_grad(set_to_none=True)
                loss.backward()
                torch.torch.nn.utils.clip_grad_norm_(gen.parameters(), max_norm=15.0)
                optimizer.step()
            else:
                print('NaN loss')
                print(iter, loss)
                input()
        except Exception as e:
            print(e)
# Out:
# stormy nueva entry rex relationship hua [unused10] waterfall
# d eleven. have. k, wrong
# 0 tensor(10.4215, grad_fn=<NllLossBackward0>)
# 2011 cerebral specify crashed lineman dismissed 130 storm
# .'* instructions eyes apparently new.
# 1 tensor(10.3404, grad_fn=<NllLossBackward0>)
# stove amount國 attorney provide blandpd gazing
# for of car toning behind. be
# 2 tensor(10.3400, grad_fn=<NllLossBackward0>)
# politician shuffled [unused894]haven preference calcium heated andhra
# n either.. it you s -
# 3 tensor(10.1304, grad_fn=<NllLossBackward0>)
# converting sequential mercenary prophet project buckingham curatedibar
# on with forbel things'; over
# 4 tensor(10.0296, grad_fn=<NllLossBackward0>)
# cai glitteringjust photos sails food weaken within
# i curtain to, entire ` okay do
# 5 tensor(9.7554, grad_fn=<NllLossBackward0>)
# ##bbing beard boredomholz plightcards aliens mechanics
# don remembering have second a two already cycle
# 6 tensor(9.7585, grad_fn=<NllLossBackward0>)
# theta emptiness manifestation ed berwick 分 wiped segunda
# shet any. time don up been
# 7 tensor(9.1077, grad_fn=<NllLossBackward0>)
# ##icle hitchcock.'wouldn swan saw aware
# may i my charity sat seeing f the
# 8 tensor(9.1398, grad_fn=<NllLossBackward0>)
# bruisesped reformed compressed⁹ monroe appetite sweeney
# quite front loveliner the, come.
# 9 tensor(9.0654, grad_fn=<NllLossBackward0>)
# し asylum legitimate vincenzo av pamphlets f panic
# order a nothing who.tiv save said
# 10 tensor(9.2518, grad_fn=<NllLossBackward0>)
# [unused717] sadler [unused641]non ʲ constituent borg laura
# do me meg. teach after allzzled
# 11 tensor(8.3072, grad_fn=<NllLossBackward0>)
# ##lino approached enclave id quarterback rude jayne nl
# ch thinks strange again doing person in there
# 12 tensor(8.8733, grad_fn=<NllLossBackward0>)
# fossilsriding northwest amendments wires swapolaromic
# will you had look justsum actress,
# 13 tensor(8.6720, grad_fn=<NllLossBackward0>)
# initiative carvings inch click greensboro office indochina cautious
# passed for out sweetheart townily now changed
# 14 tensor(8.1384, grad_fn=<NllLossBackward0>)
# drama might top 'craft andize straight
# rising handle wound s else took you her
# 15 tensor(7.8469, grad_fn=<NllLossBackward0>)
# recognize seat and i.. 〜↔
# her on she its a cracked curb tree
# 16 tensor(7.7393, grad_fn=<NllLossBackward0>)
# through.. through., ʿ outside
# down. ` realising ups to,.
# 17 tensor(8.0184, grad_fn=<NllLossBackward0>)
# i thinkcraft, herman kentucky least
# the. someone only to lithuanian worry the
# 18 tensor(8.1814, grad_fn=<NllLossBackward0>)
# label 192 snake the trained echo liturgywoman
# to that ` she school see and pre
# 19 tensor(7.2998, grad_fn=<NllLossBackward0>)
# live vineyards bala brood ` converselyilia inauguration
# lies not he how her with and i
# 20 tensor(7.0565, grad_fn=<NllLossBackward0>)
# khel i -d the think champs
# she turn the. `. young they
# 21 tensor(7.3507, grad_fn=<NllLossBackward0>)
# transvaal 171 spinning mel her um as [unused960]
# ,ed s people the nurses (,
# 22 tensor(7.7052, grad_fn=<NllLossBackward0>)
# - the41 nocturnal, [unused789]'when
# two'him tried'glass s his
# 23 tensor(7.1236, grad_fn=<NllLossBackward0>)
# ' is instead, sit ` had madam
# are desk was on ethan'had he
# 24 tensor(6.8698, grad_fn=<NllLossBackward0>)
# i. clarence just54 kept features story
# and ari has. narrowed and meet tears
# 25 tensor(6.9540, grad_fn=<NllLossBackward0>)
# bat jane serve and'` a '
# did so too the brad she boy but
# 26 tensor(7.4547, grad_fn=<NllLossBackward0>)
# ee it carolyn inlyn procedural, are
# wood, they introductions through well approached the
# 27 tensor(6.7354, grad_fn=<NllLossBackward0>)
# gaze optimization wash, rocket claims but stated
# he and said she with in'`
# 28 tensor(6.3409, grad_fn=<NllLossBackward0>)
# , [unused325] statements anne next germans ofonis
# ' his t report mildly temper too had
# 29 tensor(7.0364, grad_fn=<NllLossBackward0>)
# of nightled toward i upbeat soo spun
# to his, kept thing for her we
# 30 tensor(6.6074, grad_fn=<NllLossBackward0>)
# were mouth. magical an - of `
# alien'the an. ` - as
# 31 tensor(6.7032, grad_fn=<NllLossBackward0>)
# cyclones words until can photographs brushed out though
# the of she his, n can probably
# 32 tensor(6.7919, grad_fn=<NllLossBackward0>)
# its before mades stride england buteron
# been the maze raised. each red reached
# 33 tensor(6.9610, grad_fn=<NllLossBackward0>)
# though or following'renault'day daughter
# ' of middle'chief ` now during
# 34 tensor(6.2909, grad_fn=<NllLossBackward0>)
# was should diner *lais she stopped that
# fathers get of possible to we ; like
# 35 tensor(7.5075, grad_fn=<NllLossBackward0>)
# inca and of ` raising so with we
# you to shower `. heard where absent
# 36 tensor(6.4283, grad_fn=<NllLossBackward0>)
# .y.lea were that he sides
# recommend his but buy a ve closely barely
# 37 tensor(6.9468, grad_fn=<NllLossBackward0>)
# theyve coming ill s if was still
# . street masculine up i compounds. expenses
# 38 tensor(6.3395, grad_fn=<NllLossBackward0>)
# ancient mandatory feet when what, like her
# ? actually corridors, she cabin in,
# 39 tensor(6.3055, grad_fn=<NllLossBackward0>)
# ', i s'very. just
# i. that nicholas, and on like
# 40 tensor(6.4061, grad_fn=<NllLossBackward0>)
# washington them digging loud sadler? still d
# * crying in as ve and steel `
# 41 tensor(6.2368, grad_fn=<NllLossBackward0>)
# . damien in sophia him toilet,.
# ##iff to itweight ` an believe forehead
# 42 tensor(6.4500, grad_fn=<NllLossBackward0>)
# time sound'in his you vantage got
# worried, but g port as leaned sword
# 43 tensor(6.9695, grad_fn=<NllLossBackward0>)
# felt warm - her i beverage optic happily
# happy.less of some probably withouts
# 44 tensor(7.1160, grad_fn=<NllLossBackward0>)
# ##lation along him child `. outside founded
# ., toumb ` thought down un
# 45 tensor(6.1969, grad_fn=<NllLossBackward0>)
# [unused329]. maj do.. attached was
# vial.k worry turned. be you
# 46 tensor(7.0613, grad_fn=<NllLossBackward0>)
# carrying,,, die individual family.
# course.. breaths. for the up
# 47 tensor(6.4278, grad_fn=<NllLossBackward0>)
# about for with the 164 the honest time
# personallyd place, was from barak.
# 48 tensor(6.5517, grad_fn=<NllLossBackward0>)
# his hand like never, - not bursts
# me a,bag. well onlyog
# 49 tensor(6.6469, grad_fn=<NllLossBackward0>)
# away needed might pain turning match we.
# god of'd des onceyx '
# 50 tensor(6.3369, grad_fn=<NllLossBackward0>)
# she is t the is, 1993 this
# was her s friendships myp without four
# 51 tensor(6.1232, grad_fn=<NllLossBackward0>)
# voice announce, solo.sy. the
# bus was anding?.!.
# 52 tensor(6.3535, grad_fn=<NllLossBackward0>)
# ` mysteries'beds tightened to panic i
# ` thought heard than n position it but
# 53 tensor(6.1031, grad_fn=<NllLossBackward0>)
# ' filtering somehow crimes t right from manchu
# a be you by'horrific have,
# 54 tensor(6.6161, grad_fn=<NllLossBackward0>)
# brought abs romanian like both been suddenly,
# theiny'decided, at contract the
# 55 tensor(6.9546, grad_fn=<NllLossBackward0>)
# i mesa she be.'actually matter
# the not he the front of mis.
# 56 tensor(6.8720, grad_fn=<NllLossBackward0>)
# approached through the ofdong they neck at
# `, the marcus ` i not wide
# 57 tensor(6.4370, grad_fn=<NllLossBackward0>)
# the out wasament she randomly outside picket
# amulet re. settlement he thickness'but
# 58 tensor(6.6521, grad_fn=<NllLossBackward0>)
# my good, he * itbula wishing
# . perhaps take.'burn me call
# 59 tensor(5.8899, grad_fn=<NllLossBackward0>)
# and of better always lived ll all time
# , dishes the jean in had - any
# 60 tensor(6.5864, grad_fn=<NllLossBackward0>)
# in if you the to did he,
# n hungry it would'wish who depths
# 61 tensor(6.9551, grad_fn=<NllLossBackward0>)
# hisd never something i of wave life
# for starting we some'to you waving
# 62 tensor(6.2110, grad_fn=<NllLossBackward0>)
# .. in members movement '良.
# slowingd yourself great lit later jet not
# 63 tensor(7.1257, grad_fn=<NllLossBackward0>)
# ##ping out beacon conform voice or'and
# curls, was him watch,'thing
# 64 tensor(6.3711, grad_fn=<NllLossBackward0>)
# remaining standing. at the'from has
# dress cream all. at and. deep
# 65 tensor(6.5951, grad_fn=<NllLossBackward0>)
# glucoseci over ended -wire ensuing will
# her so ill of most looked airport totally
# 66 tensor(7.2540, grad_fn=<NllLossBackward0>)
# but s in coe me the outfit brilliant
# and'elegant'not his nice he
# 67 tensor(6.0026, grad_fn=<NllLossBackward0>)
# ##hos the said the'i render laugh
# eyes. ingredientscc the leading. this
# 68 tensor(6.6056, grad_fn=<NllLossBackward0>)
# . nice wouldlad people too in he
# the the, his she was it meal
# 69 tensor(7.0596, grad_fn=<NllLossBackward0>)
# the tying you here yourself ', of
# pretty s. fact, '. picking
# 70 tensor(6.0521, grad_fn=<NllLossBackward0>)
# to around thes ` ten'off
# ##or building to dripping ` up ` streaks
# 71 tensor(6.4563, grad_fn=<NllLossBackward0>)
# accusations coiled him, s short att
# . as i me charge looked head old
# 72 tensor(6.8454, grad_fn=<NllLossBackward0>)
# the, anything from practice i grandmother brutally
# .t head building yelled she what tree
# 73 tensor(6.9528, grad_fn=<NllLossBackward0>)
# ##ing ifmun who that he the said
# the missing she the thorn, moment give
# 74 tensor(6.8325, grad_fn=<NllLossBackward0>)
# the later with various 島 1836 mounts yes
# ko never rememberedur cut'think looked
# 75 tensor(6.6677, grad_fn=<NllLossBackward0>)
# mali to movement placed as formal endings touch
# by he maintained t pink of see the
# 76 tensor(6.2814, grad_fn=<NllLossBackward0>)
# in re on both, swiped,.
# throwing sa his blood motion be is now
# 77 tensor(6.6431, grad_fn=<NllLossBackward0>)
# felt ted call for size and to sadly
# . they gone the soft the fear probably
# 78 tensor(6.0487, grad_fn=<NllLossBackward0>)
# the he in breathing sloan mad andin
# here c. car not mean again `
# 79 tensor(6.2391, grad_fn=<NllLossBackward0>)
# bra'and in the ` i mac
# ' d we your, ` her shaggy
# 80 tensor(5.8227, grad_fn=<NllLossBackward0>)
# more queen really said found. faint do
# i i i meet coming ca it least
# 81 tensor(6.0881, grad_fn=<NllLossBackward0>)
# and who when are the and - me
# kelly wicket do.. could car me
# 82 tensor(6.9395, grad_fn=<NllLossBackward0>)
# nria him down,.. the
# more. : slipped behind and, applies
# 83 tensor(7.1219, grad_fn=<NllLossBackward0>)
# see gave of out tall less he lips
# and right casino monitored voice. her to
# 84 tensor(6.5344, grad_fn=<NllLossBackward0>)
# hand, sometimespoints against ass i large
# honour, help an, back ` where
# 85 tensor(6.7226, grad_fn=<NllLossBackward0>)
# anotherlak for that him discontinued also gift
# ? saw flames took bodo bottle said a
# 86 tensor(6.0081, grad_fn=<NllLossBackward0>)
# dor way job no n in attend
# ` and open was yeahbling the very
# 87 tensor(6.0227, grad_fn=<NllLossBackward0>)
# employs wo the a its'me if
# the get you not and was compelling want
# 88 tensor(5.8261, grad_fn=<NllLossBackward0>)
# startled power into mad them the for whoever
# up'the floppy one man a wrists
# 89 tensor(6.9024, grad_fn=<NllLossBackward0>)
# ` the 'heim, is - '
# ##le down'looked to going''
# 90 tensor(6.0556, grad_fn=<NllLossBackward0>)
# down the, she they the tonight more
# she a. in in'could i
# 91 tensor(6.3461, grad_fn=<NllLossBackward0>)
# a crossing sure were thailand across. defeats
# nothing drew'people, set exactly you
# 92 tensor(6.5463, grad_fn=<NllLossBackward0>)
# least'seems he approached vincent came,
# on and now last a immediately them helped
# 93 tensor(6.4166, grad_fn=<NllLossBackward0>)
# to oilers except,. california down.
# , over the with teach,ch i
# 94 tensor(6.9094, grad_fn=<NllLossBackward0>)
# and enhancedd and at had. arya
# ied business filled me'out,
# 95 tensor(5.8649, grad_fn=<NllLossBackward0>)
# lass joy stubborn sam his borg. to
# it to at'quiet he what he
# 96 tensor(6.2539, grad_fn=<NllLossBackward0>)
# on it. a the so morere
# were before our implant there ` can are
# 97 tensor(6.5133, grad_fn=<NllLossBackward0>)
# and boneverted welcome any'for midnight
# .'floor ofs ', bucket
# 98 tensor(5.6163, grad_fn=<NllLossBackward0>)
# three its : we. - a
# thought la. imagined shuddering okay the when
# 99 tensor(6.8385, grad_fn=<NllLossBackward0>)
# tensor([ 1996,  1055, 10662,  2017,  5822,  2128,  2002,  1036])
# tensor([2025, 1036, 2215, 2061, 2079, 1005, 2310, 1036])
# tensor([1012, 2350, 2560, 9686, 7543, 1005, 1012, 2010])
# tensor([2031, 2026, 1999, 2010, 1012, 2074, 2044, 2008])
# tensor([7608, 2442, 2711, 1997, 2125, 2006, 5698, 1005])
# tensor([ 2302,  9301,  1012,  4571,  2022, 17454,  2412,  2001])
# tensor([2134, 8431, 2469, 2032, 2001, 1036, 1010, 1050])
# tensor([1996, 1037, 8253, 1010, 2048, 1005, 2010, 1050])
# tensor([ 3773,  2222,  2489, 13433,  5779,  1996,  2568,  2074])
# tensor([ 2019,  1040,  1997,  1012, 12918,  2017,  1050,  2002])
# tensor([ 1005,  2978,  2033, 16516,  2012,  2008,  2002,  1012])
# tensor([ 2441, 14542,  2020,  1996,  1005,  1012,  1010,  4902])
# tensor([ 1011,  2109, 11741,  4539,  4892, 25024,  2035,  2657])
# tensor([ 4355,  1997,  1998,  6283,  5475,  1996,  1045, 10041])
# tensor([1012, 2021, 4389, 1036, 4175, 2030, 1012, 2387])
# tensor([2008, 1036, 2071, 1036, 2003, 4902, 1012, 1037])
# tensor([ 1353,  1036,  8884, 14752,  1036,  1996,   999,  2075])
# tensor([ 2392,  2059,   999, 10036,  1045, 10733,  2129,  2054])
# tensor([2045, 1010, 2005, 2045, 1996, 1005, 4282, 1005])
# tensor([1010, 1045, 4010, 2196, 2006, 2000, 2061, 1005])
# Loss at step = 100 for train data is 0.3090 for val it is 0.3059
# lot -'fall books. a was
# her quietly granny long leftl do a
# 100 tensor(6.3317, grad_fn=<NllLossBackward0>)
# my basel designatedte going mo back an
# what fool like living to started manron
# 101 tensor(6.9436, grad_fn=<NllLossBackward0>)
# - welcome gave apartmentshaft okay shoulders ship
# , past the wine to personal return,
# 102 tensor(6.0838, grad_fn=<NllLossBackward0>)
# ' growled not he, was me two
# ' always head? up em. that
# 103 tensor(5.9835, grad_fn=<NllLossBackward0>)
# sat at [unused680] positioned and. says.
# anything she revolver don flipped school'he
# 104 tensor(6.3221, grad_fn=<NllLossBackward0>)
# fast they emails my are held the to
# .imeter of to to on but down
# 105 tensor(6.9202, grad_fn=<NllLossBackward0>)
# to! to damn. going was gently
# ##nell could backrons it this lifeng
# 106 tensor(6.7922, grad_fn=<NllLossBackward0>)
# mia know means so bes london you
# stuart control get, sun construction as exaggerated
# 107 tensor(5.8037, grad_fn=<NllLossBackward0>)
# ' birds do either i sand up teeth
# ' it my,.ous, you
# 108 tensor(6.1434, grad_fn=<NllLossBackward0>)
# the thrust of out ` quietly'serbia
# . happy himself could she wanting self down
# 109 tensor(6.1597, grad_fn=<NllLossBackward0>)
# net'you robot filling?. three
# d he dared hips heard mile about proves
# 110 tensor(5.8241, grad_fn=<NllLossBackward0>)
# was! shrugged the the of. did
# topic of theycoats this. and
# 111 tensor(6.7670, grad_fn=<NllLossBackward0>)
# he, nothing to all strong. another
# is that back a durable a the,
# 112 tensor(6.5890, grad_fn=<NllLossBackward0>)
# me are. has is ear hope to
# to nicole of about and, wanting i
# 113 tensor(6.0045, grad_fn=<NllLossBackward0>)
# for out less bigger.fully room everything
# da woman then.r ground the thud
# 114 tensor(6.6109, grad_fn=<NllLossBackward0>)
# sometimes [unused94] there theyboot worry alan are
# back i i ` edward attention ushered.
# 115 tensor(6.9912, grad_fn=<NllLossBackward0>)
# deeply chimney since know. night i felt
# have. of into it kylie that donated
# 116 tensor(6.0706, grad_fn=<NllLossBackward0>)
# months feltق the for somehow 'ew
# , him rot the warm'the had
# 117 tensor(6.3711, grad_fn=<NllLossBackward0>)
# i of was eye discovered ` defense had
# `,'picture we george shook e
# 118 tensor(5.6861, grad_fn=<NllLossBackward0>)
# heated getnessren least was'feeling
# ., it of then i i without
# 119 tensor(6.5133, grad_fn=<NllLossBackward0>)
# so whistling dead like her'` it
# i. everything ban with'` it
# 120 tensor(6.1018, grad_fn=<NllLossBackward0>)
# sure., `'strategy'think
# he here gratitude'' encouragement i my
# 121 tensor(5.8614, grad_fn=<NllLossBackward0>)
# he -,'beauty was mine,
# and some, if jail readily scene her
# 122 tensor(7.1248, grad_fn=<NllLossBackward0>)
# she twenty but children them against couldble
# helen gabriel and done and fellow that her
# 123 tensor(6.6561, grad_fn=<NllLossBackward0>)
# four very marxist? going coughing, pull
# tel she consistentlyla far now know was
# 124 tensor(6.9872, grad_fn=<NllLossBackward0>)
# i heys sense ghana choices there before
# after. handed investigators and look you it
# 125 tensor(6.2423, grad_fn=<NllLossBackward0>)
# mouth woodsity and listen guide counted
# might in, was s the magic mile
# 126 tensor(6.6328, grad_fn=<NllLossBackward0>)
# winter relationsve said order would pressure on
# needed subject warning clue the sliding agesgal
# 127 tensor(6.1802, grad_fn=<NllLossBackward0>)
# next mar yous asking the saidick
# oft. us under a zoe looks
# 128 tensor(7.3183, grad_fn=<NllLossBackward0>)
# ' coming do and hole wine. work
# ve i with a. the for sparkle
# 129 tensor(6.0289, grad_fn=<NllLossBackward0>)
# to roster shifts, spent readers his and
# the show the. them you its our
# 130 tensor(6.5476, grad_fn=<NllLossBackward0>)
# ' a in me ` that family that
# tomorrow aroundi lauren this `'her
# 131 tensor(6.3179, grad_fn=<NllLossBackward0>)
# ##ᴺ,dberg always but that in players
# my. new him knowing, if.
# 132 tensor(5.7362, grad_fn=<NllLossBackward0>)
# upright rosy not. only she was be
# , my need here noticeally not.
# 133 tensor(6.5064, grad_fn=<NllLossBackward0>)
# ' her -'s.. coven
# . been'instead s hadback surface
# 134 tensor(5.9967, grad_fn=<NllLossBackward0>)
# aly she ` family s neck breast
# nodded i the d be t the the
# 135 tensor(6.2880, grad_fn=<NllLossBackward0>)
# you gave gouna closes pressed that stroking
# . what back s the smiled..
# 136 tensor(6.7283, grad_fn=<NllLossBackward0>)
# our - unable roared crossing loves to husband
# . a back going and told you the
# 137 tensor(6.5196, grad_fn=<NllLossBackward0>)
# . was have were a fond t with
# . in'stood after a from double
# 138 tensor(6.0958, grad_fn=<NllLossBackward0>)
# march what we was un? they pack
# ##t said she mina why curl up she
# 139 tensor(6.7864, grad_fn=<NllLossBackward0>)
# did'the they of news i `
# ' re that no at myself fragile you
# 140 tensor(5.7769, grad_fn=<NllLossBackward0>)
# getting label your ready martin was i.
# tri'someows s. and that
# 141 tensor(6.4119, grad_fn=<NllLossBackward0>)
# ##ti does were,'on! order
# ##sh doors scholar i owner it it but
# 142 tensor(6.9532, grad_fn=<NllLossBackward0>)
# function called 訁 but hardwood the kind `
# eyes. waited'walls only'an
# 143 tensor(5.9100, grad_fn=<NllLossBackward0>)
# that he got shook a him better of
# . man hers looked how ` it walls
# 144 tensor(5.8555, grad_fn=<NllLossBackward0>)
# . dark he every that'grey i
# . sarcastic biting him. ` window '
# 145 tensor(6.0438, grad_fn=<NllLossBackward0>)
# first like lot okaytino viola,.
# the cass idea jeff mountain head said if
# 146 tensor(6.6769, grad_fn=<NllLossBackward0>)
# truth'gr did for were stretched bits
# sentimental, well didn. point was jake
# 147 tensor(6.8005, grad_fn=<NllLossBackward0>)
# . iy the - more from you
# startled ` frenzy'entry wait made hired
# 148 tensor(6.1612, grad_fn=<NllLossBackward0>)
# for rhythm the,'a withdrawal iv
# most finger him outside n on have `
# 149 tensor(5.8087, grad_fn=<NllLossBackward0>)
# kisse pleasedntsie should lying the
# discussed she two he a. also before
# 150 tensor(6.6311, grad_fn=<NllLossBackward0>)
# the, year her then.. around
# i with. to war to for section
# 151 tensor(6.7810, grad_fn=<NllLossBackward0>)
# creature, phones'stadion? `,
# `. monster ` there'she her
# 152 tensor(5.9982, grad_fn=<NllLossBackward0>)
# when mod he soundedlington guard ` enough
# these way rubblelev mean absurd ` presence
# 153 tensor(6.8354, grad_fn=<NllLossBackward0>)
# as aye was s starting a the the
# . of gasped t ` pins falling to
# 154 tensor(5.9440, grad_fn=<NllLossBackward0>)
# he.'provisions it s from lurched
# each john ` all started she let.
# 155 tensor(6.4949, grad_fn=<NllLossBackward0>)
# seemed marsh now i m? did.
# of to it name my desk quit in
# 156 tensor(5.6592, grad_fn=<NllLossBackward0>)
# kellyagi. rec.ed you were
# ##c newscast was need, feel way no
# 157 tensor(6.5011, grad_fn=<NllLossBackward0>)
# the asked back, lesson scat is
# ` cell head with.'on had
# 158 tensor(6.0020, grad_fn=<NllLossBackward0>)
# . hise backyard thanks swallowed asked,
# . face from are came to ground cell
# 159 tensor(6.7104, grad_fn=<NllLossBackward0>)
# told re z from small he leaders interrupting
# clouded m so smile i. test in
# 160 tensor(5.9698, grad_fn=<NllLossBackward0>)
# ' 'pur sat frequent the out made
# ` next, shifted lighthouse because out at
# 161 tensor(5.7261, grad_fn=<NllLossBackward0>)
# presses his leaf worn the'cautiously added
# have lock.pl im'guilty yet
# 162 tensor(6.3549, grad_fn=<NllLossBackward0>)
# just,, orbit im knowing ` and
# .,n something her fact that more
# 163 tensor(6.8486, grad_fn=<NllLossBackward0>)
# maybe blood out again he his a '
# the feel say about'yeah i he
# 164 tensor(5.5863, grad_fn=<NllLossBackward0>)
# had smashwords.. inside., the
# drawn first had in. that get then
# 165 tensor(6.1357, grad_fn=<NllLossBackward0>)
# terms agreement sam t. one and i
# to'' ryder was im no '
# 166 tensor(6.0341, grad_fn=<NllLossBackward0>)
# decided she down a could just with there
# place'aslative dec was try for
# 167 tensor(6.6398, grad_fn=<NllLossBackward0>)
# is albert sq maybe bee, ` her
# boy read to. move care ` laughed
# 168 tensor(5.9742, grad_fn=<NllLossBackward0>)
# ##ed the once needed. are bed acted
# knows.? the skin of hearing in
# 169 tensor(6.5911, grad_fn=<NllLossBackward0>)
# al looked informant under track in today
# ##au to'the you what.ers
# 170 tensor(5.7289, grad_fn=<NllLossBackward0>)
# with sun'harm get n kids peg
# she. it miss did said through coming
# 171 tensor(5.7371, grad_fn=<NllLossBackward0>)
# the they i ` book'dress flying
# and up ` ` losing her'roared
# 172 tensor(5.9665, grad_fn=<NllLossBackward0>)
# `'returned about somehow me tell scrutiny
# if day thumbs doing and one a tr
# 173 tensor(5.7196, grad_fn=<NllLossBackward0>)
# latest had do next show todd ` offered
# . the took'grin little s patricia
# 174 tensor(6.1351, grad_fn=<NllLossBackward0>)
# staringnsk.. through looking s not
# 'ly a. you with t i
# 175 tensor(6.0172, grad_fn=<NllLossBackward0>)
# my betters her,'' d
# need peered into the,, and d
# 176 tensor(5.4481, grad_fn=<NllLossBackward0>)
# ,. in, from the no published
# . yelled took haded took, to
# 177 tensor(6.4985, grad_fn=<NllLossBackward0>)
# ' experience mean quick wasoth back open
# it not had i thereafter en he its
# 178 tensor(6.7302, grad_fn=<NllLossBackward0>)
# they here aslines avid. let,
# marital his weci he. hedic
# 179 tensor(5.8600, grad_fn=<NllLossBackward0>)
# elevator other ` to deeply he ian there
# ,. she cagezi andmage.
# 180 tensor(5.9113, grad_fn=<NllLossBackward0>)
# ' tell leaving male the great, member
# my hands. bring have step started her
# 181 tensor(5.9158, grad_fn=<NllLossBackward0>)
# how what'am suddenly that. find
# turning to the nice we. to shit
# 182 tensor(5.6772, grad_fn=<NllLossBackward0>)
# to in into, you met over '
# were and, what cr. a that
# 183 tensor(6.4646, grad_fn=<NllLossBackward0>)
# every are her'the, his '
# he else how park now? we '
# 184 tensor(5.7466, grad_fn=<NllLossBackward0>)
# meant along building know back of on news
# . information than could show have her?
# 185 tensor(6.0504, grad_fn=<NllLossBackward0>)
# ,'n in the gave must,
# before in '.'make nothing you
# 186 tensor(5.7548, grad_fn=<NllLossBackward0>)
# yet. fat a virgin would setting to
# doing. my normally there his butlyn
# 187 tensor(6.5475, grad_fn=<NllLossBackward0>)
# bun `'there here. stream maybe
# very one breathed, stove.. we
# 188 tensor(5.9590, grad_fn=<NllLossBackward0>)
# was run about confused. - running `
# doien eye some. liberty i what
# 189 tensor(6.3352, grad_fn=<NllLossBackward0>)
# crow with was demanded his into am blinked
# threw to his that you hand. '
# 190 tensor(5.7079, grad_fn=<NllLossBackward0>)
# what is she was. from i,
# she it `,xie to'have
# 191 tensor(5.7186, grad_fn=<NllLossBackward0>)
# youlic. over. handques.
# around and. sound two thumb modern like
# 192 tensor(6.2736, grad_fn=<NllLossBackward0>)
# . sleep. ` table ` followed.
# around,. no reach she doing ashton
# 193 tensor(6.0082, grad_fn=<NllLossBackward0>)
# you destroy rolled if edible did to the
# fist hired her her his do all while
# 194 tensor(6.2661, grad_fn=<NllLossBackward0>)
# . s his as the to forks before
# players the shown, already off fuss rooms
# 195 tensor(6.6435, grad_fn=<NllLossBackward0>)
# ' swaying lady stirringrm er a normal
# them could. did the seth. with
# 196 tensor(5.8768, grad_fn=<NllLossBackward0>)
# else are what her,'cheʷ
# that to ` else away'with '
# 197 tensor(6.1028, grad_fn=<NllLossBackward0>)
# where like did max at made. as
# - going my low. out la if
# 198 tensor(7.0318, grad_fn=<NllLossBackward0>)
# ivly all standing, bathroom arms ellis
# knocking now asked work, been it only
# 199 tensor(6.2464, grad_fn=<NllLossBackward0>)
# tensor([2359, 2009, 1012, 1005, 2339, 1996, 1012, 2469])
# tensor([ 2157, 18777,  2298,  1036,  2054,  2841,  1012,  2229])
# tensor([ 1036,  1005,  2027, 17462,  2471,  3830,  1005,  2052])
# tensor([1036, 1036, 2032, 2021, 5094, 1045, 1036, 1005])
# tensor([6198, 2043, 1996, 2053, 2784, 1012, 2008, 1998])
# tensor([ 2005,  2012,  2068,  2122,  2519,  2015, 12273,  4873])
# tensor([ 2000,  2084, 25861,  5533,  1005,  1005,  2009,  1010])
# tensor([1997, 2159, 2033, 8437, 1036, 2246, 2336, 2014])
# tensor([1005, 1005, 3242, 1996, 2359, 2057, 1005, 6207])
# tensor([20839,  1055,  2122,  2010,  2019,  3402,  2004,  7653])
# tensor([1036, 2020, 5156, 1036, 1036, 1999, 7768, 2056])
# tensor([1005, 2009, 2431, 1012, 1005, 2065, 1012, 1005])
# tensor([2020, 1010, 4196, 2042, 1029, 2018, 2243, 3133])
# tensor([1012, 4367, 2017, 1010, 2785, 2515, 1005, 2098])
# tensor([22327,  1012,  2001,  1012,  2706,  2606,  2165,  2003])
# tensor([2305, 1010, 2001, 1997, 3924, 7388, 2001, 2397])
# tensor([ 2006,  2317, 10895,  2131,  7796,  2130,  1998,  2032])
# tensor([2004, 1012, 1996, 1010, 2215, 1005, 2065, 2014])
# tensor([24842,  1998,  2041,  1036,  5738,  1005,  1012,  2041])
# tensor([2034, 2016, 2130, 1036, 1996, 1005, 2001, 2014])
# Loss at step = 200 for train data is 0.3025 for val it is 0.2992
# western tea important office to by from what
# ,. table to, but you i
# 200 tensor(5.8842, grad_fn=<NllLossBackward0>)
# shaken was she was of. soon than
# pursue. it? sharply away soon looked
# 201 tensor(5.7073, grad_fn=<NllLossBackward0>)
# a. of out cock brothers for home
# so ago to know a '. tyler
# 202 tensor(6.1616, grad_fn=<NllLossBackward0>)
# ##room'`, it, nice first
# ' and `.'i we '
# 203 tensor(5.7265, grad_fn=<NllLossBackward0>)
# months lies down and a free happy black
# in to dark xavier the not defend men
# 204 tensor(7.0937, grad_fn=<NllLossBackward0>)
# tight talking t,s'flames weak
# days but said drawing,'doesn more
# 205 tensor(6.6489, grad_fn=<NllLossBackward0>)
# ' was ofstream ever walked is lily
# ' alley 42. some the a you
# 206 tensor(6.3711, grad_fn=<NllLossBackward0>)
# ##e me would eyes became his burning branch
# ##at hand back and end hers nanny
# 207 tensor(6.5136, grad_fn=<NllLossBackward0>)
# too ` ` had fade'myour
# a'` and many.ris before
# 208 tensor(6.5061, grad_fn=<NllLossBackward0>)
# pleaser know,, her goded
# ` i'has you have my.
# 209 tensor(4.9455, grad_fn=<NllLossBackward0>)
# legs the choice that. looked steven them
# his let? excuse that she shareholders his
# 210 tensor(6.0271, grad_fn=<NllLossBackward0>)
# out ve and, immediately the,.
# , zach in over do spoken centuries vision
# 211 tensor(6.3438, grad_fn=<NllLossBackward0>)
# right depths as eyed, there must outside
# ' nineteen made, streetted be them
# 212 tensor(6.3850, grad_fn=<NllLossBackward0>)
# actions grabs the longer for they tunnel and
# super un boil foreign managed takes kits told
# 213 tensor(6.9020, grad_fn=<NllLossBackward0>)
# loved, thee ` friend enough '
# and tiet embarrassing oh up to how
# 214 tensor(6.3032, grad_fn=<NllLossBackward0>)
# began ward yeshiva what. in house drop
# more kim approved natalie.. for do
# 215 tensor(6.1600, grad_fn=<NllLossBackward0>)
# ' ` course period idea, ; was
# ' ` yours every did opposite the needed
# 216 tensor(6.3063, grad_fn=<NllLossBackward0>)
# very - keen 'd from usual thank
# was he have now flashed. to s
# 217 tensor(5.5874, grad_fn=<NllLossBackward0>)
# your camouflage imgman, the here.
# with laughed. taylor relax him fast softly
# 218 tensor(5.9822, grad_fn=<NllLossBackward0>)
# for her to my, - side normally
# a and the.. driveway to it
# 219 tensor(6.5240, grad_fn=<NllLossBackward0>)
# that three little ', ceiling so distant
# door jumped did. nothing school and ban
# 220 tensor(5.2676, grad_fn=<NllLossBackward0>)
# . them heration between youl asked
# for the taa larry friend too find
# 221 tensor(6.2826, grad_fn=<NllLossBackward0>)
# at kind against..'' not
# gathered him his.,cc ` it
# 222 tensor(6.1095, grad_fn=<NllLossBackward0>)
# . need is walk by a spent a
# wisdom. would? all would tonight standing
# 223 tensor(6.2714, grad_fn=<NllLossBackward0>)
# than raised what scooped armsful dick,
# too behind until people., no.
# 224 tensor(6.4702, grad_fn=<NllLossBackward0>)
# where said them, ether mac backyard,
# those a agreed which'pink only
# 225 tensor(6.3007, grad_fn=<NllLossBackward0>)
# noble hand he'imperfect her laughed.
# dish kiss i'quickly damn, and
# 226 tensor(5.5643, grad_fn=<NllLossBackward0>)
# three fight a ethantal hips stupid us
# oh direction least get, of stucco husband
# 227 tensor(6.3352, grad_fn=<NllLossBackward0>)
# cord tempting don were - i shaking a
# and and was. i sitting.?
# 228 tensor(5.6703, grad_fn=<NllLossBackward0>)
# ? smiled if 'iss, left forward
# just that. surveying, ever. years
# 229 tensor(6.0371, grad_fn=<NllLossBackward0>)
# to. seeing to but talking or glow
# she and vampire three which up a of
# 230 tensor(5.7966, grad_fn=<NllLossBackward0>)
# it no if, like intove,
# hudson it'ella. the attacked not
# 231 tensor(5.9240, grad_fn=<NllLossBackward0>)
# sky i per see ricky pink wanted the
# left ` hunt. van river found.
# 232 tensor(6.2333, grad_fn=<NllLossBackward0>)
# floor ` have, neuroscience deacon. re
# rude it hit she really myself the s
# 233 tensor(5.5238, grad_fn=<NllLossBackward0>)
# su used?,, ` have admitted
# car too waking nu just'',
# 234 tensor(5.5151, grad_fn=<NllLossBackward0>)
# became forgotten phone take, me thingᅯ
# savage and pretty toward upind the longtime
# 235 tensor(6.7356, grad_fn=<NllLossBackward0>)
# i scared not oscar or where knew i
# ie a. said made'it
# 236 tensor(6.0698, grad_fn=<NllLossBackward0>)
# caught. territories break off that arink
# ##pa that ` be. ` peered on
# 237 tensor(6.0914, grad_fn=<NllLossBackward0>)
# carnage maybe camenel. the k struggled
# all oh andting tea had want.
# 238 tensor(6.5123, grad_fn=<NllLossBackward0>)
# of'' if she ca i leisure
# toward s. going into hissed tea turns
# 239 tensor(5.4557, grad_fn=<NllLossBackward0>)
# noticed burst must active the ` my was
# was it ask guilt stuck,, could
# 240 tensor(6.6294, grad_fn=<NllLossBackward0>)
# lounge taking in ponytail beth something time lunch
# idea she, it up. part drink
# 241 tensor(5.8817, grad_fn=<NllLossBackward0>)
# ##hoot winked to do like loves since '
# condom as'be got, down he
# 242 tensor(5.9109, grad_fn=<NllLossBackward0>)
# ##jia you,'outsider quiet. '
# ' suddenly over i understand hand to '
# 243 tensor(5.4864, grad_fn=<NllLossBackward0>)
# drifted happened size laugh from. ofri
# betray. bray climbed. do mistress whole
# 244 tensor(6.8125, grad_fn=<NllLossBackward0>)
# his had steve with, thatksha oh
# hands hair to, from lettingber bra
# 245 tensor(5.9291, grad_fn=<NllLossBackward0>)
# the -. hey she a this -
# . dull. i. extends. of
# 246 tensor(6.4076, grad_fn=<NllLossBackward0>)
# . well i. want if, i
# ##s snack there why'head, sad
# 247 tensor(5.7626, grad_fn=<NllLossBackward0>)
# and to,? wall from not goes
# behind, in, coordinator just obviouslypha
# 248 tensor(5.5411, grad_fn=<NllLossBackward0>)
# . selected coffee. hallway and elegant lying
# the ones stairs a his she had awake
# 249 tensor(6.1268, grad_fn=<NllLossBackward0>)
# ` as lined the it later thy of
# he anisi in seatedlyburyied
# 250 tensor(6.9900, grad_fn=<NllLossBackward0>)
# ` wanted, muttering it in cared '
# t than of trust be'n saved
# 251 tensor(5.8639, grad_fn=<NllLossBackward0>)
# ' - into quiet outward the u of
# d mouth, had. looked was invitation
# 252 tensor(5.6492, grad_fn=<NllLossBackward0>)
# as that like you andine million at
# car he from his but my that by
# 253 tensor(5.2492, grad_fn=<NllLossBackward0>)
# of followingfish out i of him of
# . i pleasure came and temporary the.
# 254 tensor(5.4581, grad_fn=<NllLossBackward0>)
# eyes him the.'are it the
# all i and one of head money and
# 255 tensor(5.6303, grad_fn=<NllLossBackward0>)
# swing'n s i costumes in wear
# to's ki happy description there be
# 256 tensor(5.6808, grad_fn=<NllLossBackward0>)
# . or let k were to waitedlly
# have it, former. mecated and
# 257 tensor(6.2597, grad_fn=<NllLossBackward0>)
# to is eyese go that that -
# the n fists percent talk zone? studied
# 258 tensor(6.0507, grad_fn=<NllLossBackward0>)
# smile me, for get you. that
# vessel your., never'throat time
# 259 tensor(5.8588, grad_fn=<NllLossBackward0>)
# lot keating iniee old you if
# d that a,. jumped'he
# 260 tensor(5.8473, grad_fn=<NllLossBackward0>)
# to withna he to gods ` '
# for my. like. they there `
# 261 tensor(5.4044, grad_fn=<NllLossBackward0>)
# copss ran do that'mis evening
# believe, she know lied ` question was
# 262 tensor(5.7633, grad_fn=<NllLossBackward0>)
# the my hard ` to n you the
# does the of ` do n when blue
# 263 tensor(5.4538, grad_fn=<NllLossBackward0>)
# , note. small sky `'`
# f res. consulting head ` d hi
# 264 tensor(5.6491, grad_fn=<NllLossBackward0>)
# situation and robe could'apartment to considered
# thicku did was much exclaimed foot was
# 265 tensor(6.4823, grad_fn=<NllLossBackward0>)
# on curated could filled taken said this and
# ( half knew year that could to whispered
# 266 tensor(6.0301, grad_fn=<NllLossBackward0>)
# , '. long have or to solid
# is sounded me because get. previous most
# 267 tensor(6.3269, grad_fn=<NllLossBackward0>)
# they it did i she., she
# i afraid knew ` yeah fists delilah '
# 268 tensor(5.4573, grad_fn=<NllLossBackward0>)
# , do set wr earlier love decided called
# here realized i under when. alex brightest
# 269 tensor(5.6447, grad_fn=<NllLossBackward0>)
# [unused286] for, read and his too eyes
# yeah itory drawing with let it her
# 270 tensor(5.4590, grad_fn=<NllLossBackward0>)
# me ` kiss was he were them brushed
# the `. them'sent work himself
# 271 tensor(5.8006, grad_fn=<NllLossBackward0>)
# couch the plane smoothly my. head his
# i yelled advantage to him come. believe
# 272 tensor(6.6265, grad_fn=<NllLossBackward0>)
# n s pri les grown. as chasing
# neat -. then symbol, i or
# 273 tensor(6.5712, grad_fn=<NllLossBackward0>)
# andrce'ahead flared across like that
# what com lemon noticed watched'know wrote
# 274 tensor(5.7033, grad_fn=<NllLossBackward0>)
# making haven flat american'up of knew
# would wanting spot penthouse d. slammed did
# 275 tensor(5.4719, grad_fn=<NllLossBackward0>)
# barely, the me..'any
# lia je whose aheadopped n ve covering
# 276 tensor(6.7054, grad_fn=<NllLossBackward0>)
# . a hat - he i automotive maintained
# to everything step. much ', whispered
# 277 tensor(5.4516, grad_fn=<NllLossBackward0>)
# in does that stan into his few this
# wakes shot he fighting, out paper.
# 278 tensor(6.4892, grad_fn=<NllLossBackward0>)
# was burst food license me reel the hang
# was love say ` song a polo both
# 279 tensor(5.3190, grad_fn=<NllLossBackward0>)
# the and uniforms smile for get used friend
# head and is puzzled that. and my
# 280 tensor(5.4673, grad_fn=<NllLossBackward0>)
# and knowly the wo doiko happy
# a the so a he started n he
# 281 tensor(5.6149, grad_fn=<NllLossBackward0>)
# the my beside told he ` with he
# . na illegitimate'not ` he i
# 282 tensor(5.6216, grad_fn=<NllLossBackward0>)
# my bodyting. where me by,
# don can paid nightpha them bon all
# 283 tensor(6.7058, grad_fn=<NllLossBackward0>)
# claudia and is, little'' room
# evening i was. hint.'to
# 284 tensor(5.7835, grad_fn=<NllLossBackward0>)
# 5. heavyng words the at throw
# where sadly towardhara. thoughtv and
# 285 tensor(6.4328, grad_fn=<NllLossBackward0>)
# last that,. propulsion a in!
# . than. beat with mushrooms i get
# 286 tensor(6.2913, grad_fn=<NllLossBackward0>)
# she leaves to stomach `man invitedou
# drawn kept? and rich sister mud just
# 287 tensor(6.5364, grad_fn=<NllLossBackward0>)
# i. and but and slap coward grabs
# but of among talking and the'a
# 288 tensor(6.2972, grad_fn=<NllLossBackward0>)
# stop, about taking was twins myzzle
# death in wanted the finally referred data concern
# 289 tensor(6.5492, grad_fn=<NllLossBackward0>)
# accentou railroad, i a the own
# but false playboy, i so back n
# 290 tensor(5.6370, grad_fn=<NllLossBackward0>)
# little and help and had ', them
# later gently her bit, when with the
# 291 tensor(6.2261, grad_fn=<NllLossBackward0>)
# amissive to, something to torybooks
# his for the,. wind, she
# 292 tensor(5.9619, grad_fn=<NllLossBackward0>)
# on a rounded,able perfume don he
# jeff it fingers up ever, fall there
# 293 tensor(6.4720, grad_fn=<NllLossBackward0>)
# ##mat i heat of of.'sweet
# pat ` old from ito she and
# 294 tensor(6.2727, grad_fn=<NllLossBackward0>)
# administering must the two it tents'then
# arsenic to i see just and `,
# 295 tensor(5.9518, grad_fn=<NllLossBackward0>)
# ##46 reluctantly already thank ` i. held
# ' of man'brick ` stationary held
# 296 tensor(5.5276, grad_fn=<NllLossBackward0>)
# pale heaved'proven out happy s relax
# zoom warehouse, '. and tided
# 297 tensor(6.0792, grad_fn=<NllLossBackward0>)
# your for at living on there no?
# a looks with then in shendi in
# 298 tensor(6.2913, grad_fn=<NllLossBackward0>)
# it a loved and long awkwardly `.
# the rising smile rev drumming fbi she you
# 299 tensor(6.2548, grad_fn=<NllLossBackward0>)
# tensor([2023, 1012, 1010, 2008, 4532, 1012, 2016, 1055])
# tensor([ 1036, 12582,  2010,  1996, 14151, 11552,  1005,  2128])
# tensor([ 2017,  2445,  3457,  8766,  8586,  6627,  1005, 18162])
# tensor([ 2056, 15575,  2242,  2600,  4253,  2021,  2055,  2055])
# tensor([ 6499,  2001,  3066,  2339,  6258, 26156,  1012,  2029])
# tensor([3442, 2035, 2019, 1037, 2111, 4717, 2006, 1998])
# tensor([2008, 1005, 2006, 1996, 2020, 1997, 2115, 1999])
# tensor([ 2158,  1010,  2025,  3071,  2008,  2066, 20014,  8875])
# tensor([1037, 1010, 1045, 1010, 2172, 1005, 2158, 4845])
# tensor([ 4877, 11498,  2646, 11005,  1996,  2071,  2067,  2103])
# tensor([2018, 2071, 2003, 2001, 2022, 2655, 2304, 1005])
# tensor([ 2001,  2318,  2182,  1012,  1996,  2067, 11025,  1055])
# tensor([7995, 2016, 1010, 2282, 2159, 2007, 1045, 9346])
# tensor([5048, 2053, 1998, 2010, 2067, 2000, 1999, 2034])
# tensor([1036, 1998, 5810, 2437, 2005, 1010, 1012, 4606])
# tensor([1045, 3257, 2132, 9853, 2419, 2303, 2711, 2788])
# tensor([2978, 2021, 2114, 2215, 2001, 2027, 4130, 1998])
# tensor([17763,  2017,  1010,  1012,  2039,  1010,  4204,  2052])
# tensor([ 5035,  2748, 13481,  2079,  1011,  2699,  2023,  2505])
# tensor([28092,  2021,  1012,  2835,  1005,  6209,  2002,  2842])
# Loss at step = 300 for train data is 0.3050 for val it is 0.2794
# . i i was on all we saying
# i are not step,'mil.
# 300 tensor(5.2323, grad_fn=<NllLossBackward0>)
# reading n the. are say? back
# a n, - people known. at
# 301 tensor(5.4079, grad_fn=<NllLossBackward0>)
# rights thought back the in..
# a those are i her back '
# 302 tensor(6.5546, grad_fn=<NllLossBackward0>)
# repeated not. us the brown a hen
# faster it the of the group, im
# 303 tensor(6.6081, grad_fn=<NllLossBackward0>)
# do features groaned against ` analyst'he
# .. in were grape micro imagined it
# 304 tensor(5.4689, grad_fn=<NllLossBackward0>)
# ` `ies home to himself back t
# in he pin it realistic mark man '
# 305 tensor(5.7369, grad_fn=<NllLossBackward0>)
# ultimately stopped more blocked his speed on neurological
# trigger in see meat for of now ships
# 306 tensor(7.0958, grad_fn=<NllLossBackward0>)
# the, of the me. combined steaming
# here i the the do the books '
# 307 tensor(5.9328, grad_fn=<NllLossBackward0>)
# . back room'myself t gun tried
# who rolledook '.zar school again
# 308 tensor(5.9567, grad_fn=<NllLossBackward0>)
# of of a anything stone used is not
# a looked an jeans iv do believed boys
# 309 tensor(6.4632, grad_fn=<NllLossBackward0>)
# . minds to. vice up respond '
# n st an. arms.'storm
# 310 tensor(5.6612, grad_fn=<NllLossBackward0>)
# alcohol ever'was the bath head and
# the.'be ki every tak he
# 311 tensor(5.9791, grad_fn=<NllLossBackward0>)
# sam that fingers just hold and k reaction
# i oh herself. herself. don.
# 312 tensor(6.3228, grad_fn=<NllLossBackward0>)
# ##le gain years a like shoulder coupling.
# had lot ko `. past ache,
# 313 tensor(6.1048, grad_fn=<NllLossBackward0>)
# except'n. something, up.
# a'carcker. out the.
# 314 tensor(5.7163, grad_fn=<NllLossBackward0>)
# ' knew? and of on his a
# ''11 buted with. burke
# 315 tensor(5.8557, grad_fn=<NllLossBackward0>)
# . `light pan with, ` jake
# was janet pistol city i to yeah doing
# 316 tensor(6.3226, grad_fn=<NllLossBackward0>)
# . to my to alone door it she
# away'planned was bright. ` have
# 317 tensor(5.3545, grad_fn=<NllLossBackward0>)
# n'his as for'pulsed along
# des'you a. think, to
# 318 tensor(5.5632, grad_fn=<NllLossBackward0>)
# she t he was and `? '
# simple s '. the yes i it
# 319 tensor(6.0792, grad_fn=<NllLossBackward0>)
# it eyes way needshiro still with wanted
# so in wrath that we save had mused
# 320 tensor(6.3158, grad_fn=<NllLossBackward0>)
# my mean with the was is arm ignored
# ##ing wasled was. won dragonlee
# 321 tensor(6.5050, grad_fn=<NllLossBackward0>)
# a own'do while linda? clock
# torture sending'lowered herself i do clusters
# 322 tensor(5.5354, grad_fn=<NllLossBackward0>)
# 'ter he annoyance ashley have peered '
# ` but she differences i 'ol `
# 323 tensor(6.0469, grad_fn=<NllLossBackward0>)
# changed over `uh. would owning it
# n the i. opportunity? my ruler
# 324 tensor(5.8813, grad_fn=<NllLossBackward0>)
# not he for an do - torn '
# much i branch anti want sense for '
# 325 tensor(6.2235, grad_fn=<NllLossBackward0>)
# talking is. several to one'`
# . `, let you passing did `
# 326 tensor(6.1032, grad_fn=<NllLossBackward0>)
# in clear.. solid one mom on
# outrage. one yous of a world
# 327 tensor(5.5700, grad_fn=<NllLossBackward0>)
# dark the had thirdies offered it they
# over their goes bit, forces. drew
# 328 tensor(6.3566, grad_fn=<NllLossBackward0>)
# ,'as have it stood calling her
# me m private '. with. education
# 329 tensor(5.4269, grad_fn=<NllLossBackward0>)
# downper me ` said ebook close '
# ##ich shield. we were - of `
# 330 tensor(6.2803, grad_fn=<NllLossBackward0>)
# go angola see for link would zur jan
# pat line threw teachers direction mean at her
# 331 tensor(6.4292, grad_fn=<NllLossBackward0>)
# ba'reluctant smith louis. - what
# is did. fire side anymore. half
# 332 tensor(5.3392, grad_fn=<NllLossBackward0>)
# table, to crackedly hetedthe
# ##ses by to at automatically shirtups '
# 333 tensor(6.6674, grad_fn=<NllLossBackward0>)
# to'door cityt wantedive unable
# ##ously '. back upstairs., and
# 334 tensor(5.6928, grad_fn=<NllLossBackward0>)
# get ` it can. of. to
# lunch ` now stepped that of a over
# 335 tensor(5.3969, grad_fn=<NllLossBackward0>)
# in o?. held to they bathroom
# n much were halfugh so'with
# 336 tensor(5.7551, grad_fn=<NllLossBackward0>)
# exhausted soon cara them presentation then me midnight
# ` i his more. it the and
# 337 tensor(5.9301, grad_fn=<NllLossBackward0>)
# . the on.cted benny staying the
# there andnedping now warm somehow at
# 338 tensor(6.5635, grad_fn=<NllLossBackward0>)
# it. chin so separate incredible of olive
# , much head vi disgusted'potato we
# 339 tensor(6.4327, grad_fn=<NllLossBackward0>)
# ethnic can ares out most went evident
# we boomed got charged, i don and
# 340 tensor(6.2289, grad_fn=<NllLossBackward0>)
# held final his either. what him when
# them her ounce sex her keep lifts until
# 341 tensor(5.5342, grad_fn=<NllLossBackward0>)
# his'resist as them. you expression
# almost'dil, obviously. the n
# 342 tensor(5.5907, grad_fn=<NllLossBackward0>)
# from rest whom hour, up in,
# , of eyes parents and ninja carry pandora
# 343 tensor(6.6114, grad_fn=<NllLossBackward0>)
# lucky with awkward she,.ection [unused790]
# police for eyes i.. up her
# 344 tensor(5.7979, grad_fn=<NllLossBackward0>)
# ##s be a would, she. pull
# into another to very goodbye that have do
# 345 tensor(5.4334, grad_fn=<NllLossBackward0>)
# ' matter on he to. : '
# never guy with `. his here '
# 346 tensor(5.7993, grad_fn=<NllLossBackward0>)
# just retreating'almost ` in, the
# play deals gapst i everyone you items
# 347 tensor(6.2469, grad_fn=<NllLossBackward0>)
# ##z pen'and her were. to
# to for ` that in him who,
# 348 tensor(6.1842, grad_fn=<NllLossBackward0>)
# everything section andmming did you that keep
# i company he i that any yes the
# 349 tensor(5.7541, grad_fn=<NllLossBackward0>)
# at nothing ribbon pretty grip whatever the well
# against placed ` where started i ran slow
# 350 tensor(6.0495, grad_fn=<NllLossBackward0>)
# could from since try he'for slid
# want leaving holds always ` t to does
# 351 tensor(5.2842, grad_fn=<NllLossBackward0>)
# bed on had reached could texasa assess
# all -. outside sixteenth marriage gate his
# 352 tensor(6.6083, grad_fn=<NllLossBackward0>)
# the gunshot'that'rape my '
# . the her some'` had `
# 353 tensor(5.5963, grad_fn=<NllLossBackward0>)
# from hadly and ', but a
# , recognized, his '. right you
# 354 tensor(6.0900, grad_fn=<NllLossBackward0>)
# are ', plus in you to he
# deeper for to was turned cut. my
# 355 tensor(5.5291, grad_fn=<NllLossBackward0>)
# '.'think their them gallon,
# is, ca moved i king very those
# 356 tensor(5.7941, grad_fn=<NllLossBackward0>)
# balls of admiration on. right was mark
# load be but exist to see did who
# 357 tensor(6.3999, grad_fn=<NllLossBackward0>)
# she die he wo i `ful he
# her for ` his high he decide missing
# 358 tensor(5.7300, grad_fn=<NllLossBackward0>)
# on mistake slamming so states can came of
# , along about he while giggleszzling.
# 359 tensor(6.9458, grad_fn=<NllLossBackward0>)
# typical like thanked. looking sign his wavy
# loaf her hu,'i in feet
# 360 tensor(5.5914, grad_fn=<NllLossBackward0>)
# held ms the s steps she cassie hiking
# it feet'ku the 'ing vessel
# 361 tensor(6.3197, grad_fn=<NllLossBackward0>)
# rebel pulled subject, that a locate i
# , my to of'- diamonds `
# 362 tensor(5.9465, grad_fn=<NllLossBackward0>)
# mentioned. i ry hand - outdoor brave
# ,. i sean halt the slip a
# 363 tensor(6.4581, grad_fn=<NllLossBackward0>)
# things camera prepared ` at agreed hand was
# life trace you hey at reached di without
# 364 tensor(6.0103, grad_fn=<NllLossBackward0>)
# would s bluemer sisters peacefully instead if
# had t hitmo. edges horror wrong
# 365 tensor(6.1988, grad_fn=<NllLossBackward0>)
# in sleeping chimed gorgeous. him was causing
# ,. showing newspaper, limb. chuck
# 366 tensor(6.4325, grad_fn=<NllLossBackward0>)
# at? control she'glared -.
# , against cart only'well, up
# 367 tensor(5.6323, grad_fn=<NllLossBackward0>)
# on man to circles ty i saw he
# locked into me this it you said to
# 368 tensor(5.7918, grad_fn=<NllLossBackward0>)
# ? was dressed for some me should eve
# between and. in out exclaimed would repairs
# 369 tensor(6.2645, grad_fn=<NllLossBackward0>)
# if a stand doors ` n was this
# , orrra calls ` i'by
# 370 tensor(5.8138, grad_fn=<NllLossBackward0>)
# by'st s thought about an that
# resist'flickered'probably chin my my
# 371 tensor(5.5059, grad_fn=<NllLossBackward0>)
# enough'back'and touched face.
# right. stomach i as arrived wearing both
# 372 tensor(5.4888, grad_fn=<NllLossBackward0>)
# folding on colt you slapped sweat im purposely
# all we an brings he of her sl
# 373 tensor(6.3218, grad_fn=<NllLossBackward0>)
# nail at. regularly be not that glanced
# sliding does, mind a chapter in runs
# 374 tensor(5.6163, grad_fn=<NllLossBackward0>)
# , present : : the matter made was
# cat promised previousgs near wereize into
# 375 tensor(6.5520, grad_fn=<NllLossBackward0>)
# s how metal would each slowing between and
# m features to so the bumps along for
# 376 tensor(6.2882, grad_fn=<NllLossBackward0>)
# ` bed please and at saved..
# no entire he my serena. my,
# 377 tensor(5.4369, grad_fn=<NllLossBackward0>)
# jonathan miles underneath straight her done animals all
# ##n of an tactical assessment like i the
# 378 tensor(6.1321, grad_fn=<NllLossBackward0>)
# ##ogenic together for deathned, around,
# retious? scenery and sink had to
# 379 tensor(6.4253, grad_fn=<NllLossBackward0>)
# trying was more pass cried `has,
# i one into tongue one'his admired
# 380 tensor(5.5408, grad_fn=<NllLossBackward0>)
# that man the the the.ied n
# in woman the i them,.eo
# 381 tensor(6.4623, grad_fn=<NllLossBackward0>)
# around elite elle johnny and ci yes with
# rue'powers, on is anxious on
# 382 tensor(6.5818, grad_fn=<NllLossBackward0>)
# when. but inside, me ',
# i knew to affected., t been
# 383 tensor(5.4838, grad_fn=<NllLossBackward0>)
# thought the leo the was around one though
# ...
# 9869 tensor(5.2016, grad_fn=<NllLossBackward0>)
# and far whom over, though my or
# from ones were fell if with how
# 9870 tensor(5.2387, grad_fn=<NllLossBackward0>)
# ' have before the, been all were
# ' go when his lot for, returned
# 9871 tensor(5.5098, grad_fn=<NllLossBackward0>)
# hard it it.'was'when
# the as this,'one would slap
# 9872 tensor(4.6234, grad_fn=<NllLossBackward0>)
# don body the that knowgan in really
# was breasts his. read. of jolt
# 9873 tensor(4.6967, grad_fn=<NllLossBackward0>)
# probably it he needed. house to to
# not on iv would wasgan to the
# 9874 tensor(5.0946, grad_fn=<NllLossBackward0>)
# ` walk occurred all clownont who.
# `? of pretty business, of intervals
# 9875 tensor(5.2645, grad_fn=<NllLossBackward0>)
# feet d i. girl n at.
# way d i., n to warmed
# 9876 tensor(4.2348, grad_fn=<NllLossBackward0>)
# else., women. pacing into there
# mattered.. carefuldie to the,
# 9877 tensor(5.3689, grad_fn=<NllLossBackward0>)
# then back out that enjoy his we never
# always - away. anything my she ash
# 9878 tensor(4.5545, grad_fn=<NllLossBackward0>)
# a class put if my on our no
# nothing kitchen capture to me with my how
# 9879 tensor(4.2126, grad_fn=<NllLossBackward0>)
# too be notue mornings he i to
# in she sorry through trains well peter to
# 9880 tensor(5.0903, grad_fn=<NllLossBackward0>)
# me yesterday dipped d needed checks opening she
# me trouble was d wanted which being gill
# 9881 tensor(4.9352, grad_fn=<NllLossBackward0>)
# that getting still to to. my '
# is helpless not to. a his loved
# 9882 tensor(4.5844, grad_fn=<NllLossBackward0>)
# shoulder bronze those and and him to circle
# thin the told pretty tried tears ;,
# 9883 tensor(4.7887, grad_fn=<NllLossBackward0>)
# ` n ` ll middle to. did
# ` n yeah and cora to more could
# 9884 tensor(4.3217, grad_fn=<NllLossBackward0>)
# ak myant, but that got
# youam her in hadn of he flipped
# 9885 tensor(4.7922, grad_fn=<NllLossBackward0>)
# ? of entire chosen thorough.. had
# world of body gotten couple youniate
# 9886 tensor(5.5254, grad_fn=<NllLossBackward0>)
# sofia `, been might faint is `
# she `, gone. shooting'`
# 9887 tensor(4.0217, grad_fn=<NllLossBackward0>)
# just the different would room. a in
# at all one daughter s. the his
# 9888 tensor(5.3369, grad_fn=<NllLossBackward0>)
# to myself would. but * quickly she
# to how '. an there i scott
# 9889 tensor(4.1585, grad_fn=<NllLossBackward0>)
# i made d since did'why.
# i she d class filed how of that
# 9890 tensor(4.2629, grad_fn=<NllLossBackward0>)
# krisa as him dock heik.
# the hole. pu bar watched him at
# 9891 tensor(5.4680, grad_fn=<NllLossBackward0>)
# food he `. clever under'it
# * i ` did stories she'the
# 9892 tensor(3.9905, grad_fn=<NllLossBackward0>)
# from you a ` state of their corrugated
# the you. ` bad. them last
# 9893 tensor(4.8150, grad_fn=<NllLossBackward0>)
# here desired me fair why now cabinet only
# aia, to he belt orgasm doubtful
# 9894 tensor(5.4217, grad_fn=<NllLossBackward0>)
# ram is. who is to all animal
# tick'summer sick has to have sex
# 9895 tensor(4.2682, grad_fn=<NllLossBackward0>)
# ,uous. had force please ran they
# to. up this door please she and
# 9896 tensor(5.3902, grad_fn=<NllLossBackward0>)
# my could of.'twenty. like
# to now with.'me and.
# 9897 tensor(3.8799, grad_fn=<NllLossBackward0>)
# the compared it he ` left t if
# as,. his right made t moment
# 9898 tensor(4.5077, grad_fn=<NllLossBackward0>)
# have out i picking martha. relieved a
# have to you only they stared all
# 9899 tensor(5.1970, grad_fn=<NllLossBackward0>)
# tensor([11219,  2354, 25553,  2001, 11876,  2035,  2298,  2060])
# tensor([2079, 2134, 2041, 2113, 2610, 1045, 2131, 2034])
# tensor([ 2079, 11162,  1010,  3300,  6230,  1998,  1005,  2001])
# tensor([2342, 1037, 1010, 2553, 6313, 2102, 1005, 2001])
# tensor([1005, 3342, 2001, 2801, 2292, 1045, 1010, 2657])
# tensor([ 1005,  1005,  2001,  3860,  2641,  1005,  1010, 11922])
# tensor([4858, 9177, 2004, 4788, 4326, 1012, 1012, 1045])
# tensor([2095, 2019, 1012, 1029, 1029, 1012, 1010, 2008])
# tensor([12883,  6366,  2056,  2852,  2519,  3543,  7944,  2583])
# tensor([6064, 2092, 3659, 2032, 4595, 1037, 2182, 2730])
# tensor([2809, 2014, 1012, 2067, 2393, 1010, 2066, 2197])
# tensor([2025, 2416, 2002, 1010, 2202, 2007, 1012, 2295])
# tensor([1012, 2939, 1036, 1005, 1036, 2028, 1997, 1996])
# tensor([2079, 2766, 1036, 1005, 1036, 2000, 1045, 1996])
# tensor([25913,  1012,  1037,  3521,  2149,  1997, 12731,  2477])
# tensor([1036, 2058, 2002, 1997, 2008, 1997, 2000, 2014])
# tensor([2568, 2071, 2441, 2000, 1036, 1045, 1005, 1036])
# tensor([6542, 2018, 2383, 8292, 1036, 1997, 1005, 1036])
# tensor([1005, 6090, 1010, 2129, 1010, 1036, 2562, 2027])
# tensor([2026, 1045, 2012, 2488, 2228, 1036, 2019, 1005])
# Loss at step = 9900 for train data is 0.2359 for val it is 0.2212
# where ` here sort a - - last
# without ` to bad from in feet and
# 9900 tensor(4.2577, grad_fn=<NllLossBackward0>)
# latest still the from up him quiet one
# arms probably his souths her time a
# 9901 tensor(5.4435, grad_fn=<NllLossBackward0>)
# , if ground as d one first much
# took the side ` s just she you
# 9902 tensor(4.4387, grad_fn=<NllLossBackward0>)
# the city home be des his. slowly
# sam of to see and tv into to
# 9903 tensor(5.1612, grad_fn=<NllLossBackward0>)
# iv. i un with now food your
# exs three it she improved alaned
# 9904 tensor(5.5120, grad_fn=<NllLossBackward0>)
# playfully was leaned of. were serena?
# and to ca before, and day again
# 9905 tensor(4.9214, grad_fn=<NllLossBackward0>)
# ocean draw no dev s. can time
# ` buy so knew s usual use last
# 9906 tensor(4.4333, grad_fn=<NllLossBackward0>)
# with eyes that comfort'never one some
# of big exactly give'walked one dinner
# 9907 tensor(4.2757, grad_fn=<NllLossBackward0>)
# . she okay! thand otto drifted
# over mary to, people about keith room
# 9908 tensor(4.2973, grad_fn=<NllLossBackward0>)
# here. his,,, comfortable belief
# way. anythinglyble to the?
# 9909 tensor(5.2447, grad_fn=<NllLossBackward0>)
# was me just, sitting my.,
# smiled me surprised. interested my..
# 9910 tensor(4.6626, grad_fn=<NllLossBackward0>)
# future this can protectsism. out shaping
# life you watched nor ought, our been
# 9911 tensor(5.3786, grad_fn=<NllLossBackward0>)
# but gun he. iszz parlor his
# stopping choice where to workeddre plan with
# 9912 tensor(4.7954, grad_fn=<NllLossBackward0>)
# five felt. want going how sensation her
# the offered drugged have playing ` with a
# 9913 tensor(4.4033, grad_fn=<NllLossBackward0>)
# . bring ` okay psychotic en away.
# , hear and or'i in to
# 9914 tensor(5.1531, grad_fn=<NllLossBackward0>)
# ' ` risesess to aboard.iled
# ' ` for bee tog,uid
# 9915 tensor(5.0210, grad_fn=<NllLossBackward0>)
# the what smoke know. decided for pamphlet
# the where, have sure wasson busy
# 9916 tensor(5.9433, grad_fn=<NllLossBackward0>)
# .en the ph booth away, and
# , quickly this marin voice ', stopped
# 9917 tensor(5.6045, grad_fn=<NllLossBackward0>)
# giant the her ` spinning the tyestra
# puddle a into `ding the before felt
# 9918 tensor(5.0180, grad_fn=<NllLossBackward0>)
# she have from times sight for be eyes
# it prefer her - two. escape eyes
# 9919 tensor(4.6221, grad_fn=<NllLossBackward0>)
# comment we monkeyvie employee had so,
# of ga a male continuity could was from
# 9920 tensor(5.0786, grad_fn=<NllLossBackward0>)
# lady. how and to yesterday ll begins
# knock o you of myy ve '
# 9921 tensor(5.0722, grad_fn=<NllLossBackward0>)
# ' t was unable the a david was
# sighed t chased nothing steered one of was
# 9922 tensor(4.4380, grad_fn=<NllLossBackward0>)
# and a ` she,s the.
# i potential ` after, is the and
# 9923 tensor(5.0310, grad_fn=<NllLossBackward0>)
# , thegree they last shame the its
# ? er to her fact sound of *
# 9924 tensor(5.2695, grad_fn=<NllLossBackward0>)
# ##hearyan performances to'find was '
# ##tib room,'watch joins '
# 9925 tensor(4.2660, grad_fn=<NllLossBackward0>)
# she we, would jump, her to
# so requesting against was ass middle she a
# 9926 tensor(5.0366, grad_fn=<NllLossBackward0>)
# have why looked, in his. she
# uncomfortable? quickly enough herima of she
# 9927 tensor(4.1979, grad_fn=<NllLossBackward0>)
# whole stare two in tuesday to intense george
# business see marines and,, a to
# 9928 tensor(5.3086, grad_fn=<NllLossBackward0>)
# the found re meing seen time to
# how gazed re.. got ancient.
# 9929 tensor(3.9626, grad_fn=<NllLossBackward0>)
# same to floor ` an n white,
# tables theed ` misery n with in
# 9930 tensor(4.3795, grad_fn=<NllLossBackward0>)
# could, thin. both scared i `
# were for it the toll harrison upon
# 9931 tensor(5.0188, grad_fn=<NllLossBackward0>)
# the and. i can the been underlying
# no. it then'like left wall
# 9932 tensor(3.9988, grad_fn=<NllLossBackward0>)
# knows everywhere borne going plenty about have he
# - to undoubtedly just n pi be the
# 9933 tensor(5.2685, grad_fn=<NllLossBackward0>)
# looking is be opened her were name.
# in is have found guided man. down
# 9934 tensor(5.5308, grad_fn=<NllLossBackward0>)
# ` any alcohol she met'now and
# `'control she yet'in to
# 9935 tensor(4.7036, grad_fn=<NllLossBackward0>)
# n said had, ohsh crashed,
# n knew was. ares fromry
# 9936 tensor(5.0321, grad_fn=<NllLossBackward0>)
# ! have as night better promise places und
# he work anguish the both have shifted is
# 9937 tensor(5.8375, grad_fn=<NllLossBackward0>)
# he his, the laughing used and looking
# ` him jeep angles the should but going
# 9938 tensor(4.8404, grad_fn=<NllLossBackward0>)
# ana fact notes door `'being royal
# . service? scents `'return lighter
# 9939 tensor(4.2720, grad_fn=<NllLossBackward0>)
# , n had tree thes lives girls
# people, could type par, grow name
# 9940 tensor(5.2587, grad_fn=<NllLossBackward0>)
# .? any its that noticing you of
# . his to to tri what we.
# 9941 tensor(5.0716, grad_fn=<NllLossBackward0>)
# agreement. t that finished and changes into
# the, t the tapped assert things tiny
# 9942 tensor(5.0061, grad_fn=<NllLossBackward0>)
# from those him guess do as her n
# ' surely catch could i ` the lowered
# 9943 tensor(4.7150, grad_fn=<NllLossBackward0>)
# ' last a the'and m '
# you only'carl '. m '
# 9944 tensor(4.4195, grad_fn=<NllLossBackward0>)
# and gently i make.,'calm
# . then i scott.y'pick
# 9945 tensor(3.9588, grad_fn=<NllLossBackward0>)
# ex com'talking that the step send
# fury of'the absorb the deep yourself
# 9946 tensor(4.2266, grad_fn=<NllLossBackward0>)
# wo n sort one daily a - the
# ' n of and unknown my a the
# 9947 tensor(4.4848, grad_fn=<NllLossBackward0>)
# fresh away. so his'll think
# me this briggs on take'll want
# 9948 tensor(4.4927, grad_fn=<NllLossBackward0>)
# to thought diego for. more shivering late
# , the tole,avian the the
# 9949 tensor(5.5321, grad_fn=<NllLossBackward0>)
# to the hold ` was make loss another
# char stupid not she had go horn a
# 9950 tensor(4.2243, grad_fn=<NllLossBackward0>)
# he came she looked'the go she
# sofia still as in'the hope there
# 9951 tensor(4.7602, grad_fn=<NllLossBackward0>)
# mean was'' white n her being
# acknowledgedg here hear house scale. `
# 9952 tensor(4.3498, grad_fn=<NllLossBackward0>)
# . blew amounts n was a a in
# back. accurate n had two together over
# 9953 tensor(4.4927, grad_fn=<NllLossBackward0>)
# ` ` coordinate on'goes a then
# ` ` bite my! shit open then
# 9954 tensor(4.1730, grad_fn=<NllLossBackward0>)
# i him i destined i to s s
# and him then left of and s ll
# 9955 tensor(4.5804, grad_fn=<NllLossBackward0>)
# fields ve walking for out i it,
# beneath ll still and back she clear further
# 9956 tensor(5.0560, grad_fn=<NllLossBackward0>)
# me when five if obviously it an him
# the an'it'if hitting him
# 9957 tensor(4.2913, grad_fn=<NllLossBackward0>)
# left be tell.'as quiet bull
# blazed take n i'as few storm
# 9958 tensor(4.7563, grad_fn=<NllLossBackward0>)
# flashing. was white itsh it,
# .. to him lightingk out,
# 9959 tensor(5.6116, grad_fn=<NllLossBackward0>)
# appeared whoever there miss eyes turned man hands
# ##fted, to to tongue the steps thigh
# 9960 tensor(4.3030, grad_fn=<NllLossBackward0>)
# behind wanted major kidding? naked everybody behind
# on special when not? tucked the how
# 9961 tensor(5.3447, grad_fn=<NllLossBackward0>)
# here was elbow her? have, only
# with whispered of the, talk who a
# 9962 tensor(5.4383, grad_fn=<NllLossBackward0>)
# one on stay out as us'tiny
# me? trust by cat the'showers
# 9963 tensor(3.9536, grad_fn=<NllLossBackward0>)
# ,illy? t do cane exactly come
# in cr of t fight room do against
# 9964 tensor(4.7572, grad_fn=<NllLossBackward0>)
# arm and'saw. i be '
# arm and ',ast'i '
# 9965 tensor(4.3385, grad_fn=<NllLossBackward0>)
# ,. up him leaving she. rang
# . beside into the religion there,.
# 9966 tensor(4.8382, grad_fn=<NllLossBackward0>)
# not the of. legs'somewhere dinner
# she much of of back '. and
# 9967 tensor(4.3174, grad_fn=<NllLossBackward0>)
# buried i briefly. will sorrow of so
# he tight would, might he every,
# 9968 tensor(4.4500, grad_fn=<NllLossBackward0>)
# him away urge how looked meant her than
# toade twenties meg straightened your the of
# 9969 tensor(4.6008, grad_fn=<NllLossBackward0>)
# .. back had bob. attention they
# ian waiting then was then doll skirt it
# 9970 tensor(4.6814, grad_fn=<NllLossBackward0>)
# walked you ever ',? my asked
# i you my '.? you was
# 9971 tensor(4.1203, grad_fn=<NllLossBackward0>)
# washing.la of ` excited its there
# secured desk stu faces ` attempt the they
# 9972 tensor(5.0730, grad_fn=<NllLossBackward0>)
# joe of all open a as quietly us
# ho, deep. a. much the
# 9973 tensor(4.5522, grad_fn=<NllLossBackward0>)
# ' so,. 9 taste to came
# ''brown, great cutting on looked
# 9974 tensor(5.0363, grad_fn=<NllLossBackward0>)
# her doiko a the too, '
# the know ba. her'they and
# 9975 tensor(4.3416, grad_fn=<NllLossBackward0>)
# f'low people spitting maybe di head
# get'' into the she. way
# 9976 tensor(5.1334, grad_fn=<NllLossBackward0>)
# people theirkat something i real m '
# dragon thoses he something being little '
# 9977 tensor(4.5634, grad_fn=<NllLossBackward0>)
# the on. angela the bright. soil
# `, for, a his to of
# 9978 tensor(4.4565, grad_fn=<NllLossBackward0>)
# off down wine how did.ack that
# to later summer i changed.,.
# 9979 tensor(4.8882, grad_fn=<NllLossBackward0>)
# not for in consuming said raced had.
# off. could drinking asked grin were.
# 9980 tensor(4.6558, grad_fn=<NllLossBackward0>)
# asked. he she covered why hard been
# could to ridiculous. showed n more a
# 9981 tensor(4.1657, grad_fn=<NllLossBackward0>)
# rap practiced he you beneath rise k room
# question became he n. nudged exploded.
# 9982 tensor(4.3386, grad_fn=<NllLossBackward0>)
# ''in with have nothinhh d
# ''her shook have oh is d
# 9983 tensor(4.2951, grad_fn=<NllLossBackward0>)
# cage blue is watched no'so about
# ashes glass off looked a do written broke
# 9984 tensor(5.2638, grad_fn=<NllLossBackward0>)
# said an america strings something mu out for
# said probablytures shining? hejust and
# 9985 tensor(4.5841, grad_fn=<NllLossBackward0>)
# the was he left looked real''
# , did it'slid century''
# 9986 tensor(4.4493, grad_fn=<NllLossBackward0>)
# , tel plan the me where thatmb
# . you other my softly i,lp
# 9987 tensor(5.4330, grad_fn=<NllLossBackward0>)
# was. looked chocolate. that pushing on
# ##e, nick it expect,, from
# 9988 tensor(5.3309, grad_fn=<NllLossBackward0>)
# bastard'plumret muttered? by.
# :'bit with pointed fed to.
# 9989 tensor(4.6015, grad_fn=<NllLossBackward0>)
# sounded such ` i pauses george - while
# was the ` ihun candace fast asleep
# 9990 tensor(4.9910, grad_fn=<NllLossBackward0>)
# but was the his ninja'looks talk
# forage the to of'catches say
# 9991 tensor(4.4527, grad_fn=<NllLossBackward0>)
# something what without hes, especially be
# to their and and and and he demand
# 9992 tensor(5.2994, grad_fn=<NllLossBackward0>)
# , ruins, general. see shivered.
# ,, in only. everyone '.
# 9993 tensor(5.1002, grad_fn=<NllLossBackward0>)
# as this supposed think cops onto, he
# a, brought and house great of baptism
# 9994 tensor(5.2177, grad_fn=<NllLossBackward0>)
# me her wedding a.,? rest
# the on samekes to and write funeral
# 9995 tensor(4.7306, grad_fn=<NllLossBackward0>)
# heart, one wounded on thetel can
# the deck the here on the, did
# 9996 tensor(5.3506, grad_fn=<NllLossBackward0>)
# . those only my decided father was elsewhere
# loves you the his chosesch.
# 9997 tensor(5.2670, grad_fn=<NllLossBackward0>)
# religions. 'less often he in asking
# peopleed ca wires the ` normal going
# 9998 tensor(5.5785, grad_fn=<NllLossBackward0>)
# slow to. kill, that nably
# fast, along be n as cuffzzled
# 9999 tensor(4.4336, grad_fn=<NllLossBackward0>)

# %%
if (not pretrained) or build_pretrained:
    # create a PyTorch optimizer
    # optimizer = torch.optim.AdamW(gen.parameters(), lr=learning_rate, weight_decay=0.01, amsgrad=True)

    for iter in range(iterations):
        try:
            
            if (iter != 0) and (iter % eval_iters == 0):
                losses = estimate_loss()
                train_loss = losses['train']
                val_loss = losses['val']
                print(f'Loss at step = {iter} for train data is {train_loss:.4f} for val it is {val_loss:.4f}')

            # sample a batch of data
            xb, yb = get_batch('train')

            # evaluate the loss
            logits, loss = gen.forward(xb, yb, tokenizer)
            if not torch.isnan(loss).any():
                print(iter, loss)
                optimizer.zero_grad(set_to_none=True)
                loss.backward()
                torch.torch.nn.utils.clip_grad_norm_(gen.parameters(), max_norm=15.0)
                optimizer.step()
            else:
                print('NaN loss')
                print(iter, loss)
                input()
        except:
            pass
# Out:
# by his robyn. of second ',
# in you his kissing the narrow '.
# 0 tensor(4.8115, grad_fn=<NllLossBackward0>)
# heard the syam come then that must
# to so sy cy and in are
# 1 tensor(5.2469, grad_fn=<NllLossBackward0>)
# distance ` ofgging him on on blood
# wonderful when for murmur the and his swift
# 2 tensor(5.3964, grad_fn=<NllLossBackward0>)
# the him took little ` '. fingers
# then'come laugh ` '. head
# 3 tensor(4.4661, grad_fn=<NllLossBackward0>)
# unable flying right attached to regardless, did
# and after then to to but. said
# 4 tensor(5.2018, grad_fn=<NllLossBackward0>)
# green'oh exactlys she ` who
# symbol'but hesitated asked his `s
# 5 tensor(4.4754, grad_fn=<NllLossBackward0>)
# ' beside need. but my called lot
# but to object.'maybe taken shower
# 6 tensor(4.0322, grad_fn=<NllLossBackward0>)
# . it it time almost room her,
# pillars the some rubbed best med you to
# 7 tensor(5.6203, grad_fn=<NllLossBackward0>)
# where the its of now of in and
# least the he. already of along,
# 8 tensor(5.4926, grad_fn=<NllLossBackward0>)
# still, slow - can own. the
# certain returns willing, is'how earth
# 9 tensor(4.1892, grad_fn=<NllLossBackward0>)
# and. fire handwriting he does that.
# like in coaster evil he tails then rann
# 10 tensor(6.4823, grad_fn=<NllLossBackward0>)
# home it priest to somewhere shape ferry fact
# what the guilt to for penultimate version the
# 11 tensor(5.3581, grad_fn=<NllLossBackward0>)
# place and. up, this a bother
# away my had yell him which the like
# 12 tensor(5.4789, grad_fn=<NllLossBackward0>)
# ,n justyiness untiling do
# renede don roaddou outdated. turn
# 13 tensor(5.5043, grad_fn=<NllLossBackward0>)
# river ` ` can mine that would,
# cattle the dev should my a excused.
# 14 tensor(4.1113, grad_fn=<NllLossBackward0>)
# her good back ` me which we wait
# the big. ` the even we please
# 15 tensor(4.5549, grad_fn=<NllLossBackward0>)
# , get intermittent fence answer he, more
# as prove same yard want never none concealed
# 16 tensor(4.4356, grad_fn=<NllLossBackward0>)
# , situation in from rubbing? gasps,
# ,ed., watching asked turned.
# 17 tensor(4.5702, grad_fn=<NllLossBackward0>)
# changes mom to ` to a said horrible
# her virginity n not. the asked fantasy
# 18 tensor(4.4953, grad_fn=<NllLossBackward0>)
# suddenly evan and also fright they know other
# it stood 1 the segregated you see ground
# 19 tensor(5.6985, grad_fn=<NllLossBackward0>)
# and the and caleb, down hood `
# for time, the. ofe `
# 20 tensor(4.7432, grad_fn=<NllLossBackward0>)
# saul slightly, at business real weary the
# sergeant of line that hairs paranoid careful the
# 21 tensor(5.4625, grad_fn=<NllLossBackward0>)
# had could, gown the ignition to if
# looked '.. then way fifty oh
# 22 tensor(5.0291, grad_fn=<NllLossBackward0>)
# gray say couple ` a you of to
# back. lighter where okay you open to
# 23 tensor(4.0553, grad_fn=<NllLossBackward0>)
# thereut. with the know hands o
# whichtpen, and get hair he
# 24 tensor(4.5317, grad_fn=<NllLossBackward0>)
# afraid'war ` natalie was did '
# stolen'words ` luke. heard the
# 25 tensor(4.4207, grad_fn=<NllLossBackward0>)
# ' it n'i back ready liz
# '. have'far resting w not
# 26 tensor(4.5331, grad_fn=<NllLossBackward0>)
# ones being against how add'' up
# island. into we spike `'someplace
# 27 tensor(4.4947, grad_fn=<NllLossBackward0>)
# ##tour you take single a snuck when,
# ##ati you tell knowledge he finished..
# 28 tensor(5.2541, grad_fn=<NllLossBackward0>)
# found his visit asked cells had actuallygs
# stay her be head of she down a
# 29 tensor(5.1069, grad_fn=<NllLossBackward0>)
# . trade my'away legally the '
# . third but are in incredible the see
# 30 tensor(4.6955, grad_fn=<NllLossBackward0>)
# ' too do open nephew this up soaked
# of going know immense back that, shining
# 31 tensor(4.5195, grad_fn=<NllLossBackward0>)
# back'weow'to up talk
# family ', queen'along heart get
# 32 tensor(4.4727, grad_fn=<NllLossBackward0>)
# . not to ; findly, block
# ##ving nothing with bumper be. happened see
# 33 tensor(5.4556, grad_fn=<NllLossBackward0>)
# talk.. been guest of. tells
# the power, as spiritual the drinking heavier
# 34 tensor(5.2360, grad_fn=<NllLossBackward0>)
# ##her door to in. reached pinch of
# up room you along, was felt of
# 35 tensor(4.3168, grad_fn=<NllLossBackward0>)
# 49 ve as brighter with midst. he
# , m she faint smile corner so shock
# 36 tensor(4.9994, grad_fn=<NllLossBackward0>)
# they million'a floor the. at
# but moment ', bucket about about.
# 37 tensor(4.9807, grad_fn=<NllLossBackward0>)
# on eager elm airox just uncleh
# quite shaking but inside ru drive beak evade
# 38 tensor(5.2351, grad_fn=<NllLossBackward0>)
# out him, made on the? inside
# her delicate,. every his up on
# 39 tensor(4.3805, grad_fn=<NllLossBackward0>)
# flap gr no it ', declared i
# he time there myself, to gallant he
# 40 tensor(5.2009, grad_fn=<NllLossBackward0>)
# as'small were he over their you
# ,'pillow flu? my the i
# 41 tensor(4.3014, grad_fn=<NllLossBackward0>)
# insect calling a well you armss emotional
# , that my quickly he hairs killed
# 42 tensor(5.2526, grad_fn=<NllLossBackward0>)
# are.ving much ribs ` hand who
# '. was you trim ` girlfriend needed
# 43 tensor(4.1610, grad_fn=<NllLossBackward0>)
# ben, was what by go shuttleel
# ##sp sites felt new she think look hitchcock
# 44 tensor(5.2781, grad_fn=<NllLossBackward0>)
# '. ` and her andva prepared
# ' of ` maker late she, but
# 45 tensor(5.1356, grad_fn=<NllLossBackward0>)
# hour no and the. chapter `.
# hour but noticed if coat i i.
# 46 tensor(4.1191, grad_fn=<NllLossBackward0>)
# was around. tangle, our of with
# ', of this, to in the
# 47 tensor(4.3915, grad_fn=<NllLossBackward0>)
# centuries thick to to du gently there property
# their few and,fast looked we other
# 48 tensor(5.4105, grad_fn=<NllLossBackward0>)
# his it i, the plenty so al
# her me he'how herself something but
# 49 tensor(4.3250, grad_fn=<NllLossBackward0>)
# thisua infantry and'well it seem
# wereab jim the'if me me
# 50 tensor(5.2694, grad_fn=<NllLossBackward0>)
# front'bastards variations'off as and
# my'evidence of s it only.
# 51 tensor(4.4015, grad_fn=<NllLossBackward0>)
# chest get gorgeous you roses me up.
# neck control loaded my blue what up.
# 52 tensor(4.1058, grad_fn=<NllLossBackward0>)
# not terror the reached on, thinkingima
# more daughter need came and. but?
# 53 tensor(4.6249, grad_fn=<NllLossBackward0>)
# delicious family he, tell asked into.
# lost truth she with tell knew the.
# 54 tensor(4.6310, grad_fn=<NllLossBackward0>)
# shirt ignition key witch majorja stupid ;
# shoulders door hair we own pinnacle she to
# 55 tensor(4.8492, grad_fn=<NllLossBackward0>)
# `. ride.ly'whisper to
# to guard seely trying'tight to
# 56 tensor(4.1374, grad_fn=<NllLossBackward0>)
# n, in oneda i 1.
# n in bu. michael that retirement said
# 57 tensor(4.9471, grad_fn=<NllLossBackward0>)
# and shirt cured. seriously us mm.
# my vantage with, caring them adams my
# 58 tensor(5.4627, grad_fn=<NllLossBackward0>)
# meeting ash did rest come'the from
# overgrown,, spirit have. of as
# 59 tensor(4.5416, grad_fn=<NllLossBackward0>)
# g holy class article hear, ` wade
# would then they twins haves nick to
# 60 tensor(4.4653, grad_fn=<NllLossBackward0>)
# opposed no. she s eddie ` '
# with the. whispered s my ` '
# 61 tensor(4.2170, grad_fn=<NllLossBackward0>)
# kristen - he scrambled at his hips preacher
# a had she in to his friend stone
# 62 tensor(5.5455, grad_fn=<NllLossBackward0>)
# my quarters to sweet ` n you her
# anyone s and had ` love you skin
# 63 tensor(4.5297, grad_fn=<NllLossBackward0>)
# he the miranda does of me have,
# ` nothing turning? in a assume on
# 64 tensor(4.8449, grad_fn=<NllLossBackward0>)
# do to had gamble'see has i
# ask uncomfortable the mother'me happens i
# 65 tensor(4.3413, grad_fn=<NllLossBackward0>)
# was head'but are still measurements.
# would forehead'' if'i or
# 66 tensor(4.2349, grad_fn=<NllLossBackward0>)
# cake i `. the ob'you
# ' he ` after the a'to
# 67 tensor(4.1482, grad_fn=<NllLossBackward0>)
# hand could he in her high her inside
# person returned i. the perfect dart cursed
# 68 tensor(5.4550, grad_fn=<NllLossBackward0>)
# one i he down ease torch and of
# the can we straight first, a spot
# 69 tensor(4.4615, grad_fn=<NllLossBackward0>)
# be in extract the table the face away
# kill others actually bra cavern red head over
# 70 tensor(5.2115, grad_fn=<NllLossBackward0>)
# here ` room table smith'corridor time
# that panting up waistband a'upper staying
# 71 tensor(4.4912, grad_fn=<NllLossBackward0>)
# he. him to shore police,.
# he. take '. rough filled new
# 72 tensor(5.1292, grad_fn=<NllLossBackward0>)
# tasha. emotion my came laughed the back
# above off mistakes them was placed his cell
# 73 tensor(5.5809, grad_fn=<NllLossBackward0>)
# i insistence shared'adjusting. seem together
# i windows had. but brain care.
# 74 tensor(5.0915, grad_fn=<NllLossBackward0>)
# . game,aria a where writing it
# , good of water the took a why
# 75 tensor(4.9325, grad_fn=<NllLossBackward0>)
# the'loose into hers tender no i
# my'up his and he they my
# 76 tensor(4.0635, grad_fn=<NllLossBackward0>)
# forward ship he ` him re eva react
# down a that she a ll brother understand
# 77 tensor(4.2635, grad_fn=<NllLossBackward0>)
# fixedin i the loss had, and
# grasped. roses him regular was to.
# 78 tensor(5.4596, grad_fn=<NllLossBackward0>)
# also'could behind of like he.
# to sometimes was. of need `,
# 79 tensor(4.1800, grad_fn=<NllLossBackward0>)
# ! here more southern the you and.
# we attempting from looking the me eleven.
# 80 tensor(5.1104, grad_fn=<NllLossBackward0>)
# for is. '. in'how
# out simple, that initial if'i
# 81 tensor(3.9292, grad_fn=<NllLossBackward0>)
# on the life him of chair and to
# ; long skin him hanging over. and
# 82 tensor(4.3138, grad_fn=<NllLossBackward0>)
# drinking shed from the chair calm than.
# able nursing on a mic makingo and
# 83 tensor(5.6261, grad_fn=<NllLossBackward0>)
# plunged mask the stood the primitive cheeks happen
# read courthouse silence'the chapter purse do
# 84 tensor(5.3980, grad_fn=<NllLossBackward0>)
# herself boston. getting as ` still to
# my those, an at ve while,
# 85 tensor(4.0713, grad_fn=<NllLossBackward0>)
# going time he if and cl my scene
# okay me were what, pulled he list
# 86 tensor(5.1753, grad_fn=<NllLossBackward0>)
# asque know'forward think be it
# , her know i left do be her
# 87 tensor(3.9844, grad_fn=<NllLossBackward0>)
# like pink know keep ethan ` clearly was
# station. remember pace the one the called
# 88 tensor(4.2077, grad_fn=<NllLossBackward0>)
# the s supposed done ` with thanks hair
# sense stering going ` to through pitched
# 89 tensor(4.3557, grad_fn=<NllLossBackward0>)
# for, with skin your hard ` light
# you,. eyes and intense ` thing
# 90 tensor(4.2958, grad_fn=<NllLossBackward0>)
# . their power with good, yourself she
# ##s you the i like at i it
# 91 tensor(5.1475, grad_fn=<NllLossBackward0>)
# ', it ` music painted the the
# ' that it `'so forced.
# 92 tensor(4.8745, grad_fn=<NllLossBackward0>)
# ' ` wo with to and over and
# ' ` are them. direction with,
# 93 tensor(4.1620, grad_fn=<NllLossBackward0>)
# . asked difficult as her do'pounding
# . rose right and him what '.
# 94 tensor(4.0400, grad_fn=<NllLossBackward0>)
# always spoke the his gloves. and the
# stay asked. hunterooped. theo her
# 95 tensor(4.5823, grad_fn=<NllLossBackward0>)
# is he same ` get feet my and
# . either night ` know mind my '
# 96 tensor(4.0382, grad_fn=<NllLossBackward0>)
# years hims ` by ` the looked
# months emily and ` part ` the,
# 97 tensor(4.2777, grad_fn=<NllLossBackward0>)
# a won ; ordinary peter sound best for
# the resist found gang it officer pathetic.
# 98 tensor(5.4851, grad_fn=<NllLossBackward0>)
# need ask seemed wonder if. the the
# live remembered. stood'will guess.
# 99 tensor(5.5669, grad_fn=<NllLossBackward0>)
# tensor([ 2059, 14015,  4931,  2392, 27136,  1036,   999,  2085])
# tensor([3561, 3239, 6187, 1996, 3480, 1036, 2000, 1012])
# tensor([ 1045,  2010,  1010,  1010,  1010, 18449,  2699,  2014])
# tensor([1045, 1996, 1050, 1012, 2368, 5519, 3241, 2560])
# tensor([2010, 2006, 2751, 1010, 2054, 2002, 3202, 2013])
# tensor([2002, 6167, 2731, 4167, 1996, 2066, 2013, 2005])
# tensor([1036, 8469, 2114, 2282, 2419, 2022, 2044, 4191])
# tensor([ 1036,  2179,  2046,  1997, 25730,  2113,  2053,  2196])
# tensor([1050, 2010, 2033, 2608, 2000, 1012, 1005, 1045])
# tensor([6170, 2006, 1996, 6312, 2114, 1012, 1005, 1998])
# tensor([2392, 2046, 5549, 2579, 2330, 1037, 1056, 6359])
# tensor([2617, 2646, 2026, 7491, 2113, 2057, 1056, 2245])
# tensor([ 1050, 14759,  2091,  2079,  2054,  1012,  1012,  4403])
# tensor([2464, 2040, 1998, 2017, 2002, 1012, 1012, 2091])
# tensor([ 2020,  1008,  2362,  2480,  3124,  2929, 13802,  6846])
# tensor([ 2387,  2401,  1037,  2505,  2723, 17748,  2296,  1005])
# tensor([2939, 2032, 5581, 2055, 1056, 1012, 1045, 1996])
# tensor([18029,  1996,  5871,  1998,  1056,  1005,  1036,  1999])
# tensor([ 1005,  2023,  1012, 13359,  2010,  1037,  1049,  2192])
# tensor([ 1010,  1012, 12207,  2159,  4000,  2183,  2222, 29393])
# Loss at step = 100 for train data is 0.2377 for val it is 0.2154
# temeraire dick?'insurance anymore..
# him first get'at?. think
# 100 tensor(4.5273, grad_fn=<NllLossBackward0>)
# stage out there some the all piece hesitated
# the back there replied each their tooth i
# 101 tensor(5.6355, grad_fn=<NllLossBackward0>)
# him with i attre to no and
# . dress'at corridor, every to
# 102 tensor(3.9305, grad_fn=<NllLossBackward0>)
# an. the lending ', you and
# and to the the they,. before
# 103 tensor(4.7062, grad_fn=<NllLossBackward0>)
# rose finally then they sheets her mark one
# doesn i she joyah mud first day his
# 104 tensor(5.1955, grad_fn=<NllLossBackward0>)
# knew drawn like asking come truth i,
# close and - - hate luxury hiss
# 105 tensor(4.6252, grad_fn=<NllLossBackward0>)
# ? cliff two when my to a `
# ##te frustration news outside as had face `
# 106 tensor(5.0940, grad_fn=<NllLossBackward0>)
# , for he speak under i mostly you
# near still i the one i like the
# 107 tensor(4.9961, grad_fn=<NllLossBackward0>)
# ' and like radiated his trying. and
# '.. showed her, auk
# 108 tensor(4.0880, grad_fn=<NllLossBackward0>)
# s then she her make when..
# s i'open feel love the weapons
# 109 tensor(4.3706, grad_fn=<NllLossBackward0>)
# ` nervous her right.yr ryan strike
# now, that lit youub you the
# 110 tensor(4.4729, grad_fn=<NllLossBackward0>)
# so his and were justgraas his
# ##uous noraette flies justt, turned
# 111 tensor(5.3756, grad_fn=<NllLossBackward0>)
# mania certain f chance up., pity
# voice beginning much very.. with in
# 112 tensor(5.4701, grad_fn=<NllLossBackward0>)
# belt. he'oh felt'-
# master said arms we ` explained'of
# 113 tensor(4.3004, grad_fn=<NllLossBackward0>)
# , to ` opened my m see t
# . he ` narrowed surfaces ve so t
# 114 tensor(3.5691, grad_fn=<NllLossBackward0>)
# why m ` spirit you mutter being into
# you ve ` smoothing there rumbled right down
# 115 tensor(4.1981, grad_fn=<NllLossBackward0>)
# like like slipping he? she touched n
# hum than the him a sitting to n
# 116 tensor(4.7307, grad_fn=<NllLossBackward0>)
# offt, furious bright, is then
# for see i sixth jo he willde
# 117 tensor(5.4139, grad_fn=<NllLossBackward0>)
# smacked cursed that for first youuch,
# knew floor coming but classes online,.
# 118 tensor(5.0149, grad_fn=<NllLossBackward0>)
# with we too sha before looking, he
# and the you all flush sorry, a
# 119 tensor(5.3052, grad_fn=<NllLossBackward0>)
# friends driving was terra any quote once.
# , ited fellows the hot quickly the
# 120 tensor(5.7119, grad_fn=<NllLossBackward0>)
# she me beautiful simon seek the. occasional
# the the man ` had the, town
# 121 tensor(4.6962, grad_fn=<NllLossBackward0>)
# 167 madeline us person anger, and it
# good friday the - histri roads asked
# 122 tensor(5.7353, grad_fn=<NllLossBackward0>)
# d from'start said't daniel
# d calm follows go said't.
# 123 tensor(4.6913, grad_fn=<NllLossBackward0>)
# she me he my they'getting her
# beautiful us i her'' keeping.
# 124 tensor(3.8722, grad_fn=<NllLossBackward0>)
# every and ` and * tell her to
# ##el. `, * have she right
# 125 tensor(4.4704, grad_fn=<NllLossBackward0>)
# nobody she see free'herself know and
# he for be he'hooded think,
# 126 tensor(5.0368, grad_fn=<NllLossBackward0>)
# big possessive,'a them a or
# of it,'here them ml so
# 127 tensor(4.5751, grad_fn=<NllLossBackward0>)
# compelled leave days to warrior the history receiving
# with, people individually study the next.
# 128 tensor(6.0678, grad_fn=<NllLossBackward0>)
# ##ua care to tierney make the t back
# ##ash. to the imagine we t there
# 129 tensor(4.1959, grad_fn=<NllLossBackward0>)
# , high next'gus to. it
# , who flat'' to at handsome
# 130 tensor(4.6212, grad_fn=<NllLossBackward0>)
# ' near? that sanity sun mouthful colleen
# 'lia? i hair clothes couple a
# 131 tensor(4.3103, grad_fn=<NllLossBackward0>)
# st?. took the skinned sand or
# quickly fromk looked? dawn heart,
# 132 tensor(4.9145, grad_fn=<NllLossBackward0>)
# was in oh this, we her could
# started in what me. we. was
# 133 tensor(4.9416, grad_fn=<NllLossBackward0>)
# people. face which. have so,
# folks, eyes. doing was the looked
# 134 tensor(4.6065, grad_fn=<NllLossBackward0>)
# to just how described feeling the portals distinguish
# bare a that vi gathering left moss touch
# 135 tensor(5.2930, grad_fn=<NllLossBackward0>)
# be'the hard'something i of
# make you she big it the water.
# 136 tensor(4.2812, grad_fn=<NllLossBackward0>)
# ' '.'' where on me
# ' 'to'' sometimes her jimmy
# 137 tensor(4.5177, grad_fn=<NllLossBackward0>)
# . had inform you, os it she
# . have receive the. her. the
# 138 tensor(4.8207, grad_fn=<NllLossBackward0>)
# the eve dead am me spite try and
# the bowl lobby appreciate, the she the
# 139 tensor(5.7263, grad_fn=<NllLossBackward0>)
# youth a over mean could feet the '
# system a my want took head the '
# 140 tensor(4.0424, grad_fn=<NllLossBackward0>)
# ' but m interrupting i reply this mari
# can but ve that we soft her feeling
# 141 tensor(4.6161, grad_fn=<NllLossBackward0>)
# him had hates drove their well i i
# her in were did. way'did
# 142 tensor(4.9540, grad_fn=<NllLossBackward0>)
# to to stands of trip ', crawling
# news on made of enough '. then
# 143 tensor(4.3435, grad_fn=<NllLossBackward0>)
# off hear ahead, majority craft that of
# many watch its, miner arrow two others
# 144 tensor(5.6512, grad_fn=<NllLossBackward0>)
# . for, ` points down but.
# before. now ` kissed using ` makeup
# 145 tensor(3.8483, grad_fn=<NllLossBackward0>)
# moment coming eyes you they his was you
# skirt maybe stance it'this was did
# 146 tensor(4.7767, grad_fn=<NllLossBackward0>)
# they say and would whenever fiction i breathing
# ##ser know with was cans terrible so,
# 147 tensor(5.6863, grad_fn=<NllLossBackward0>)
# ! be sweat if, one feral after
# . buy today certainly, pride door the
# 148 tensor(5.0681, grad_fn=<NllLossBackward0>)
# single the had nots what fought of
# two and d? had im must months
# 149 tensor(5.4092, grad_fn=<NllLossBackward0>)
# lungs to right41e years was he
# direction the out suite of occurred ar
# 150 tensor(5.2359, grad_fn=<NllLossBackward0>)
# gaze - knee and my, her am
# hands, evening then go - her s
# 151 tensor(4.5323, grad_fn=<NllLossBackward0>)
# looking m n nowess and her '
# . m n, arms we when '
# 152 tensor(4.1663, grad_fn=<NllLossBackward0>)
# terra ran would sortdown exits when voice
# the monastery for neighbors bedroom on hi nipples
# 153 tensor(5.7588, grad_fn=<NllLossBackward0>)
# did to up sc my'` `
# seems to about mayor,'her `
# 154 tensor(4.5121, grad_fn=<NllLossBackward0>)
# ##t prepare in this down mys to
# ##t were it he the,s to
# 155 tensor(5.4924, grad_fn=<NllLossBackward0>)
# just fled. the and one to men
# bother shaker getting and way for break
# 156 tensor(5.7024, grad_fn=<NllLossBackward0>)
# , psycho scale i there. did hand
# pained previous counter but to she ignored back
# 157 tensor(4.2334, grad_fn=<NllLossBackward0>)
# two now including but leash how day and
# four talk tender rushed altar no ha tooth
# 158 tensor(5.6997, grad_fn=<NllLossBackward0>)
# master ofs looking iv photos ae
# girl from. i he, iae
# 159 tensor(6.1337, grad_fn=<NllLossBackward0>)
# lingering full friend d wolfe comb becoming pregnant
# class caught son d. shower all deposit
# 160 tensor(4.6435, grad_fn=<NllLossBackward0>)
# just flushed i `,'breakfast,
# my getting i quietly of i feel feet
# 161 tensor(4.1936, grad_fn=<NllLossBackward0>)
# ` nodded isabella what relentless ` to sunday
# bums `'its he, brick
# 162 tensor(4.8182, grad_fn=<NllLossBackward0>)
# ##ience.. o i of called chilled
# ##ron,cgor olivia, she so
# 163 tensor(5.0581, grad_fn=<NllLossBackward0>)
# ` him. a let been the other
# george, humans to melted really high perhaps
# 164 tensor(4.7534, grad_fn=<NllLossBackward0>)
# !. i comedies. 11. '
# , and and bedroom? thekin -
# 165 tensor(5.0428, grad_fn=<NllLossBackward0>)
# as things,. it, i us
# . you my the like. as the
# 166 tensor(4.1818, grad_fn=<NllLossBackward0>)
# have with the kn me tears was we
# assume almost the me been she she i
# 167 tensor(4.8064, grad_fn=<NllLossBackward0>)
# looked. meant thought ` tracy my there
# am, was tears he,. doyle
# 168 tensor(4.7542, grad_fn=<NllLossBackward0>)
# figuredbit we'girl. be '
# headeding it'stab? happen if
# 169 tensor(4.4858, grad_fn=<NllLossBackward0>)
# !, give, and skipping can closed
# , meeting drive the their first are school
# 170 tensor(5.2256, grad_fn=<NllLossBackward0>)
# .hat '. the. last to
# . to'that the glass when the
# 171 tensor(5.2404, grad_fn=<NllLossBackward0>)
# raw the her rose ck felt good want
# was and `, *. smooth see
# 172 tensor(4.3913, grad_fn=<NllLossBackward0>)
# to of escape in if beinged of
# ?. rouse one he theered of
# 173 tensor(5.2646, grad_fn=<NllLossBackward0>)
# quiet without foster herself, woman, with
# as as water unseen. habits michael -
# 174 tensor(5.4796, grad_fn=<NllLossBackward0>)
# . there you'here go. a
# ##ling vouro'with say a we
# 175 tensor(5.3212, grad_fn=<NllLossBackward0>)
# ' through courthouse at. circumstances n '
# ' and own.,, n '
# 176 tensor(4.4932, grad_fn=<NllLossBackward0>)
# 3 subject? sort murmured. me into
# she surfer? champagne asked...
# 177 tensor(3.7368, grad_fn=<NllLossBackward0>)
# ` something looks want ve on, amanda
# ` it pushes killed faith at?,
# 178 tensor(4.8015, grad_fn=<NllLossBackward0>)
# ` which his plastic man then to had
# ` some sight seconds sorry and to as
# 179 tensor(4.4969, grad_fn=<NllLossBackward0>)
# really ',ep adopt cough escape?
# subion him just '. husky okay
# 180 tensor(4.2105, grad_fn=<NllLossBackward0>)
# . to harp turned'i herneil
# ##h to spot she last i a has
# 181 tensor(4.4350, grad_fn=<NllLossBackward0>)
# .'first'samantha far. t
# ##d'you'to to colorful t
# 182 tensor(4.4905, grad_fn=<NllLossBackward0>)
# of something flat outlean.dy
# that the ordinary testing knew -. scratched
# 183 tensor(5.3853, grad_fn=<NllLossBackward0>)
# between like could. talk. ear if
# the much are. him, lap my
# 184 tensor(4.4404, grad_fn=<NllLossBackward0>)
# a. blue had navigation one shook realism
# a? breath whip hips you raced '
# 185 tensor(4.8502, grad_fn=<NllLossBackward0>)
# eyes at we'he to legs concerns
# father alien so'heat to fiercely vapor
# 186 tensor(5.3884, grad_fn=<NllLossBackward0>)
# myself these monica office different n ve.
# up the she ex mean that m.
# 187 tensor(3.8929, grad_fn=<NllLossBackward0>)
# and 'co determined want in rightful,
# in'- had'permitted..
# 188 tensor(4.9448, grad_fn=<NllLossBackward0>)
# ifpp go - like shadowst,
# thoughbon went the. gathering reallypu
# 189 tensor(4.7645, grad_fn=<NllLossBackward0>)
# they thighs. and more what anything flip
# katie mistakes you and a everything n.
# 190 tensor(4.7026, grad_fn=<NllLossBackward0>)
# taken weights and'debbie can, it
# truly wisdom team the he see to it
# 191 tensor(5.0703, grad_fn=<NllLossBackward0>)
# . 'ru sniff bath'partners the
# to know, do cover'man her
# 192 tensor(4.4127, grad_fn=<NllLossBackward0>)
# out? write not way sailing your you
# ., give the way.'okay
# 193 tensor(4.0150, grad_fn=<NllLossBackward0>)
# a. up was me as this i
# got ago at from one looked in to
# 194 tensor(4.5281, grad_fn=<NllLossBackward0>)
# was all. ll rested. struck there
# ! hislight re'and still.
# 195 tensor(4.4548, grad_fn=<NllLossBackward0>)
# everyone alexia his in t m and?
# a there on, t ` in we
# 196 tensor(5.6647, grad_fn=<NllLossBackward0>)
# so many. you the. too '
# has long, be she and just always
# 197 tensor(4.0058, grad_fn=<NllLossBackward0>)
# ##lis her. line cleared give second blessed
# ,. dreamer end stood do other it
# 198 tensor(5.1064, grad_fn=<NllLossBackward0>)
# everything,, depending know news as please
# the now. wondering tell o yielded the
# 199 tensor(5.4446, grad_fn=<NllLossBackward0>)
# tensor([2008, 1005, 1037, 2065, 7288, 2234, 1036, 1012])
# tensor([3561, 1005, 2153, 1036, 1999, 5864, 1045, 2076])
# tensor([2001, 2005, 2052, 2245, 2039, 2630, 4086, 1010])
# tensor([2001, 3871, 2734, 2097, 1012, 3139, 1996, 2064])
# tensor([3310, 2000, 8306, 2004, 2003, 1997, 1025, 1037])
# tensor([ 2935,  1010,  3941,  2007,  2038,  1998, 10571,  2010])
# tensor([3122, 1012, 1012, 2330, 2292, 3456, 8373, 2017])
# tensor([17078,  3356,  1998,  2026,  2025,  2376,  2040,  1005])
# tensor([2505, 1012, 4365, 2245, 1005, 2436, 1005, 1012])
# tensor([2008, 1052, 2073, 1996, 1005, 2341, 1045, 2004])
# tensor([2135, 1012, 2067, 1056, 1010, 2085, 1005, 2000])
# tensor([ 2146, 10827,  2408,  1056,  1012,  2004,  1005,  1012])
# tensor([2126, 2022, 1055, 2066, 1996, 2051, 2675, 1005])
# tensor([3611, 2227, 2871, 2197, 1996, 2500, 5236, 1005])
# tensor([1010, 2766, 2000, 1010, 2062, 2196, 1036, 1012])
# tensor([1012, 3592, 1012, 2518, 2748, 8781, 1036, 6402])
# tensor([1050, 6336, 2216, 2018, 2010, 3831, 1012, 2091])
# tensor([2025, 6682, 2009, 2052, 2091, 5848, 1996, 1037])
# tensor([13407,  2000,  3328, 13594,  2227,  2023,  6545,  1012])
# tensor([3096, 2188, 6195, 2298, 3244, 1996, 9313, 2019])
# Loss at step = 200 for train data is 0.2338 for val it is 0.2149
# mere. you suspectedlee to on still
# whisper removed not was. her and frowned
# 200 tensor(5.1689, grad_fn=<NllLossBackward0>)
# ##aith moment closed inn because gates ',
# ##lo way better floor you entire ',
# 201 tensor(4.7086, grad_fn=<NllLossBackward0>)
# turned up s. have on up by
# was at s her shut the dai during
# 202 tensor(4.6055, grad_fn=<NllLossBackward0>)
# it he i one her ` cozy,
# his something'dip. they of.
# 203 tensor(4.6045, grad_fn=<NllLossBackward0>)
# a prick could dave, cry either you
# thister was and to and going you
# 204 tensor(4.3587, grad_fn=<NllLossBackward0>)
# silver up her of * scream i she
# gun him care and kin. it gram
# 205 tensor(4.2408, grad_fn=<NllLossBackward0>)
# kenoch. hiss seemed dead loosened '
# he rod every crooked know then looked '
# 206 tensor(5.1571, grad_fn=<NllLossBackward0>)
# tell back with the'i first doing
# how sho what of'had did him
# 207 tensor(4.3947, grad_fn=<NllLossBackward0>)
# front while for the look one his.
# green or blind boy small he he!
# 208 tensor(5.3376, grad_fn=<NllLossBackward0>)
# ? its.tley that would boring well
# ? twisted of she in and. lost
# 209 tensor(5.3203, grad_fn=<NllLossBackward0>)
# was. i the to fool mainly rage
# would slightly ', around i looked area
# 210 tensor(5.0864, grad_fn=<NllLossBackward0>)
# right heard you nina confirm said'thought
# the thoughta before have yes him forgot
# 211 tensor(4.7219, grad_fn=<NllLossBackward0>)
# ritter? his, - were knot.
# he, his and - as words up
# 212 tensor(5.0890, grad_fn=<NllLossBackward0>)
# how is to.. ram with way
# when'to to intensity table up her
# 213 tensor(4.4177, grad_fn=<NllLossBackward0>)
# private. opener, tonight seat. to
# thunder the even to from timeions to
# 214 tensor(4.5660, grad_fn=<NllLossBackward0>)
# hold he to, a admiral right different
# avoid ty about in a great. around
# 215 tensor(5.2019, grad_fn=<NllLossBackward0>)
# . they eagerly i to intended the fingers
# time said what, bringing far the when
# 216 tensor(5.3575, grad_fn=<NllLossBackward0>)
# managed gaze the air the ` s tears
# all voice hide the his ` s bandages
# 217 tensor(4.0797, grad_fn=<NllLossBackward0>)
# her a ` gale knew course to a
# ` attached ` he had nowhere up our
# 218 tensor(4.3992, grad_fn=<NllLossBackward0>)
# so it. around him marius she,
# too what to grab the a the for
# 219 tensor(4.5198, grad_fn=<NllLossBackward0>)
# that. which,ez. from her
# perhaps'you crazy course, of out
# 220 tensor(4.9712, grad_fn=<NllLossBackward0>)
# here way n i get telling miserable ru
# so circle right her expect worried year yeah
# 221 tensor(4.4350, grad_fn=<NllLossBackward0>)
# again at his spirits of a bali and
# sure, n feelings of try when the
# 222 tensor(4.7273, grad_fn=<NllLossBackward0>)
# look mad bit valentine any tan event powers
# up my ground men it his hundred your
# 223 tensor(5.2466, grad_fn=<NllLossBackward0>)
# ' above. tunnelme and can '
# boys faster, sky, fu igor anything
# 224 tensor(4.9699, grad_fn=<NllLossBackward0>)
# in had asgg something the ss
# than wanted as va doing telling s.
# 225 tensor(4.0111, grad_fn=<NllLossBackward0>)
# . and debating of sake. jerome a
# sideways about pulling was '. we gorgeous
# 226 tensor(4.4503, grad_fn=<NllLossBackward0>)
# still anymore of did andqui stiff help
# past. pulled were to progress air give
# 227 tensor(4.5891, grad_fn=<NllLossBackward0>)
# probably anyway the his may you several would
# was for the sweet was you strips would
# 228 tensor(5.4168, grad_fn=<NllLossBackward0>)
# like he so attending mill the who no
# like your'with computers what. vi
# 229 tensor(4.2183, grad_fn=<NllLossBackward0>)
# into up founding 'ening usual diagonal wheel
# ,. yearning didle pop again mania
# 230 tensor(5.3951, grad_fn=<NllLossBackward0>)
# since he trousers and to t more,
# with the hand stood and t again.
# 231 tensor(4.8851, grad_fn=<NllLossBackward0>)
# she'she those ',. yes
# she'he after '. eternal i
# 232 tensor(4.6100, grad_fn=<NllLossBackward0>)
# nodded'know was. bruises a vi
# the'want needed staring feelings hearing his
# 233 tensor(3.9690, grad_fn=<NllLossBackward0>)
# neatly employees she because'stairs withs
# way summer her?'but. had
# 234 tensor(4.1620, grad_fn=<NllLossBackward0>)
# been end.'' `. without
# been white stop what nod you. `
# 235 tensor(3.9803, grad_fn=<NllLossBackward0>)
# that, was i ', image was
# a quest felt rachel demon away his was
# 236 tensor(4.7255, grad_fn=<NllLossBackward0>)
# re'conference n was we upon '
# re oh mae n died pe for '
# 237 tensor(4.8381, grad_fn=<NllLossBackward0>)
# time hell move.. he..
# and while hide to it you here plot
# 238 tensor(5.5313, grad_fn=<NllLossBackward0>)
# repeat having.e and sheep yourself who
# years to, mother i often a floated
# 239 tensor(5.0820, grad_fn=<NllLossBackward0>)
# hello'grip were dusty board i love
# but i home stepped ` her i blue
# 240 tensor(3.8827, grad_fn=<NllLossBackward0>)
# ##ful. s i one, ` '
# lane. s'all. ` '
# 241 tensor(4.0509, grad_fn=<NllLossBackward0>)
# in forming? show my children as lifted
# - bob sw even his opposite retreated looked
# 242 tensor(5.1233, grad_fn=<NllLossBackward0>)
# again recognizing'seeing i himself desperately?
# for i'pass out for into of
# 243 tensor(4.1143, grad_fn=<NllLossBackward0>)
# n must the all.ilo each you
# thats a in, destroyed cycles a
# 244 tensor(5.1584, grad_fn=<NllLossBackward0>)
# locker s outs the lift through taut
# immediate s the. me was ashley turn
# 245 tensor(4.3367, grad_fn=<NllLossBackward0>)
# tied hoping while heard doc. our be
# heading there! suppose ;. preparing be
# 246 tensor(5.4178, grad_fn=<NllLossBackward0>)
# me from but neck? felt, let
# them she he little the stopped olds
# 247 tensor(5.1711, grad_fn=<NllLossBackward0>)
# cream people his! life of have result
# ##ll steps a, lip had understand still
# 248 tensor(5.5264, grad_fn=<NllLossBackward0>)
# ' able the and he whereabouts i so
# ' planning the the interested surf he t
# 249 tensor(5.6262, grad_fn=<NllLossBackward0>)
# my his behind. i made week `
# my, and asked she no lot `
# 250 tensor(4.3755, grad_fn=<NllLossBackward0>)
# , relax'`. but frowned in
# let'' feeling. like glen the
# 251 tensor(4.4303, grad_fn=<NllLossBackward0>)
# i accuracy wouldable x be, audrey
# in mother had, tristan have on the
# 252 tensor(4.9698, grad_fn=<NllLossBackward0>)
# remembered ),, concept shirtwater.
# ,. told. police green performance.
# 253 tensor(5.4974, grad_fn=<NllLossBackward0>)
# ##ava cop night hebbling dry with,
# a hint quiet becauses heatoise!
# 254 tensor(4.9256, grad_fn=<NllLossBackward0>)
# for had and powerful expressions eat, asking
# done could. deep pressure be to con
# 255 tensor(5.2321, grad_fn=<NllLossBackward0>)
# us that sava my ` my words.
# so the she a ` work minutes.
# 256 tensor(5.0499, grad_fn=<NllLossBackward0>)
# luck. her ` the silver foot these
# but. the ` ` glass kind registration
# 257 tensor(4.5653, grad_fn=<NllLossBackward0>)
# sky go she poor like i cheerfully tracy
# only look i light at you softly you
# 258 tensor(4.7006, grad_fn=<NllLossBackward0>)
# him he touched m whole. know sheath
# about between. m back her oweagger
# 259 tensor(4.4129, grad_fn=<NllLossBackward0>)
# ' voice'was d `. '
# ' face i face s ` to '
# 260 tensor(4.2301, grad_fn=<NllLossBackward0>)
# seven, guess have onshis another
# genuine the didn get weren man. '
# 261 tensor(5.3429, grad_fn=<NllLossBackward0>)
# remembered real existence silence handle empty were wonderful
# took gym. who do city ran back
# 262 tensor(5.0198, grad_fn=<NllLossBackward0>)
# ##dora better an know - doc..
# shuddered bit dans hurry as there afraid,
# 263 tensor(5.2148, grad_fn=<NllLossBackward0>)
# . the speakdie in they youwives
# in sitting applymus again nodding all goodness
# 264 tensor(5.3209, grad_fn=<NllLossBackward0>)
# her nothing out,! looked, `
# . a and, pointed saw ideas `
# 265 tensor(4.8611, grad_fn=<NllLossBackward0>)
# sunday talking lay love anyway the ` too
# . made complained ', let ` n
# 266 tensor(4.4763, grad_fn=<NllLossBackward0>)
# to there never i the as. last
# yesterday i ever yes not raising and out
# 267 tensor(4.1063, grad_fn=<NllLossBackward0>)
# ` the up large issues,.re
# even the shocked captain., enoughm
# 268 tensor(5.0915, grad_fn=<NllLossBackward0>)
# ny forecast mother counts my west `.
# form did face does answer problem ` with
# 269 tensor(4.6424, grad_fn=<NllLossBackward0>)
# , liked. right'called, and
# ##wyn nodded wouldn mind'scream, to
# 270 tensor(4.1987, grad_fn=<NllLossBackward0>)
# and down buckled, freshman have soul larger
# after at history. s have not their
# 271 tensor(4.7734, grad_fn=<NllLossBackward0>)
# to if an an came walked from and
# sister she a obvious. thende just
# 272 tensor(5.2741, grad_fn=<NllLossBackward0>)
# his me what. person warrant grace for
# afternoon his is bulletin i of fault after
# 273 tensor(5.3620, grad_fn=<NllLossBackward0>)
# ' reason.. tired. on they
# ' shell over. water ',,
# 274 tensor(4.9174, grad_fn=<NllLossBackward0>)
# careful ` behind feel secret that ` you
# low ` as thinkene us ` when
# 275 tensor(4.4613, grad_fn=<NllLossBackward0>)
# floor dirty washing in meee'my
# ##tre wife put me the there looked quiet
# 276 tensor(4.5177, grad_fn=<NllLossBackward0>)
# . d first been be was been getting
# . d, never have grew all fine
# 277 tensor(4.2459, grad_fn=<NllLossBackward0>)
# end but home, made'the let
# summer but.cu fan i some get
# 278 tensor(4.3302, grad_fn=<NllLossBackward0>)
# quiet well ` by thisrook ` wiping
# book suit ` bread me yourself jack for
# 279 tensor(4.2641, grad_fn=<NllLossBackward0>)
# better s have night both not burned tore
# and'do way me see 'go
# 280 tensor(4.4129, grad_fn=<NllLossBackward0>)
# dagger high one now weekend sound kind to
# little i bye with hero its fresh he
# 281 tensor(4.5032, grad_fn=<NllLossBackward0>)
# .'fell `, chaos,.
# and'was ` isabella directioned.
# 282 tensor(4.1601, grad_fn=<NllLossBackward0>)
# the to i, appeared? a of
# to today you continued on? found to
# 283 tensor(5.2751, grad_fn=<NllLossBackward0>)
# he. and told victorian at, '
# spending very, said was up and '
# 284 tensor(4.3630, grad_fn=<NllLossBackward0>)
# doorway keeping.!ila feet she the
# time put and the grove nephew she the
# 285 tensor(5.5676, grad_fn=<NllLossBackward0>)
# going rocking her i you as. `
# sure hard with what '.'he
# 286 tensor(3.9924, grad_fn=<NllLossBackward0>)
# type at could said take caught room and
# like people looked finally his burst wild docked
# 287 tensor(4.3616, grad_fn=<NllLossBackward0>)
# , alison she be. of 'ra
# . a she wince.. i us
# 288 tensor(4.1933, grad_fn=<NllLossBackward0>)
# bo bus oh become. eyes agreed power
# ##acle for i fight into eyesl bike
# 289 tensor(4.7698, grad_fn=<NllLossBackward0>)
# beth begin., am doing did um
# said can behind, do mess as if
# 290 tensor(4.7187, grad_fn=<NllLossBackward0>)
# angels just bu temple the at'shifted
# the broughtter next. at'read
# 291 tensor(4.8825, grad_fn=<NllLossBackward0>)
# jon. streamed first the the dare how
# a landscapes ran breath way but he -
# 292 tensor(4.4346, grad_fn=<NllLossBackward0>)
# ,, aboutumble.. a he
# thinkh whenut. past watching he
# 293 tensor(4.5604, grad_fn=<NllLossBackward0>)
# centred nicely grin from. around'joy
# look map empty trial'tocy guilt
# 294 tensor(4.9929, grad_fn=<NllLossBackward0>)
# it '. body last soon '.
# n'have trademark taken he'sweetly
# 295 tensor(4.4586, grad_fn=<NllLossBackward0>)
# ' to'all more. ` haley
# ' less'on stretching. such in
# 296 tensor(4.5016, grad_fn=<NllLossBackward0>)
# to in cook and not susan right of
# weekend to of with even anyway going -
# 297 tensor(3.9469, grad_fn=<NllLossBackward0>)
# with us a,!'get an
# . him only a and. use ba
# 298 tensor(4.9300, grad_fn=<NllLossBackward0>)
# coming for the he tempted havedina wanted
# captain dream the there glad about if '
# 299 tensor(4.6710, grad_fn=<NllLossBackward0>)
# tensor([ 2031,  1045,  1996,  2010,  1012, 28384,  1005,  1045])
# tensor([ 3477,  1045,  2392,  2010,  1012,  2359, 22985,  1045])
# tensor([9515, 2000, 3648, 2021, 7690, 2017, 2052, 2357])
# tensor([ 2111,  2000, 24665,  2000,  2098,  2002,  2020,  2424])
# tensor([ 2795,  9652,  2008, 17454,  2026,  2041,  1012,  4342])
# tensor([ 2694, 10140,  2726,  2274,  1997,  2012,  6151,  4895])
# tensor([1005, 2128, 9141, 1996, 2079, 1045, 2320, 5003])
# tensor([1005, 1040, 3332, 1011, 1005, 2026, 2054, 2905])
# tensor([ 2159,  2074,  2088, 14689,  2026,  2156,  2062, 29098])
# tensor([ 2159, 14163,  2613, 25081,  4474,  2377,  2425, 15238])
# tensor([1029, 1005, 3592, 5689, 2217, 9991, 1996, 1012])
# tensor([ 2035,  1005,  1010,  1996,  2155,  4950, 10006,  1012])
# tensor([3109, 2519, 2007, 2362, 2010, 2056, 1055, 2498])
# tensor([1045, 4301, 2505, 2327, 1045, 2356, 1055, 2428])
# tensor([2054, 1996, 1996, 2026, 1055, 1997, 1010, 5027])
# tensor([ 3637, 26012,  1996,  2092,  1055,  1045,  1010,  2126])
# tensor([1012, 1005, 1045, 1036, 1037, 2182, 2412, 4370])
# tensor([1012, 1005, 1045, 1036, 2215, 4460, 2031, 2288])
# tensor([2830, 1005, 1036, 2428, 6346, 2196, 1005, 2505])
# tensor([1999, 1005, 1036, 9686, 2087, 2471, 2128, 5333])
# Loss at step = 300 for train data is 0.2230 for val it is 0.2233
# it she. her. the his '
# into i you it,t with would
# 300 tensor(4.5028, grad_fn=<NllLossBackward0>)
# next, ache - ryan at but live
# at duff and the we. sending ve
# 301 tensor(5.4211, grad_fn=<NllLossBackward0>)
# baffled is'fell piece not me i
# plastic. '. of she her fever
# 302 tensor(4.8000, grad_fn=<NllLossBackward0>)
# candi warming n it more me they she
# when scared cheat it if see the she
# 303 tensor(3.9344, grad_fn=<NllLossBackward0>)
# was hale to but wide the finally of
# pulled sneered it who a nearly he boo
# 304 tensor(5.7076, grad_fn=<NllLossBackward0>)
# ,, kidnap what well'she pregnant
# '. sleepk everything'someone n
# 305 tensor(4.3888, grad_fn=<NllLossBackward0>)
# t? package personnel, of i.
# twen other,. storm what you
# 306 tensor(4.8123, grad_fn=<NllLossBackward0>)
# stack eyes broughtsar about..,
# administrators. known he to elsewhere not of
# 307 tensor(4.6146, grad_fn=<NllLossBackward0>)
# do fire her noticed why the toward the
# sit few us was rob i with several
# 308 tensor(4.4153, grad_fn=<NllLossBackward0>)
# memory rest i the his wake ',
# hair concert his her the rattle ` as
# 309 tensor(4.5187, grad_fn=<NllLossBackward0>)
# , ` but opened it something she `
# my ` ` rubbed you, ` `
# 310 tensor(3.9562, grad_fn=<NllLossBackward0>)
# boston sayseri regular asked to. in
# the thoughth daymo and cake hard
# 311 tensor(5.3785, grad_fn=<NllLossBackward0>)
# joan and or smile several, to anti
# wash from while voice him ten protect mind
# 312 tensor(5.6426, grad_fn=<NllLossBackward0>)
# the i'had be touch sleep but
# my the doo could have attacking his `
# 313 tensor(4.0118, grad_fn=<NllLossBackward0>)
# ' end the of desk but `,
# deal i him lessons copy for i.
# 314 tensor(4.3923, grad_fn=<NllLossBackward0>)
# to weight child. man today.y
# her eyes ghosts her head been him casting
# 315 tensor(4.4627, grad_fn=<NllLossBackward0>)
# to. said was. one and willow
# my, added did just, nothing other
# 316 tensor(4.2441, grad_fn=<NllLossBackward0>)
# .'shrugged '. know ` need
# . inside him'for'i do
# 317 tensor(4.2764, grad_fn=<NllLossBackward0>)
# hung was ` sc ` little, door
# he was `. ` came, good
# 318 tensor(4.3335, grad_fn=<NllLossBackward0>)
# change '. so theirs x do when
# no.. scowl run. it clothes
# 319 tensor(4.1890, grad_fn=<NllLossBackward0>)
# obviously lit him touch eyeing proceed shower it
# not punchednier noise quite after three its
# 320 tensor(5.3102, grad_fn=<NllLossBackward0>)
# ' has.. despite ` because as
# of owesed the mac ` reports into
# 321 tensor(4.2504, grad_fn=<NllLossBackward0>)
# live.. whether into come boat `
# integrate and gu more bed died show `
# 322 tensor(5.3524, grad_fn=<NllLossBackward0>)
# . the insane iing blinding about their
# with the and youlun was my and
# 323 tensor(5.4566, grad_fn=<NllLossBackward0>)
# you a realized opposite '.!.
# you with could she mention of,.
# 324 tensor(4.2934, grad_fn=<NllLossBackward0>)
# her among. dates jaw to..
# if.s girlfriend almost whatever..
# 325 tensor(4.3944, grad_fn=<NllLossBackward0>)
# years all finally he in brief until,
# years that ` normal. gr. inside
# 326 tensor(4.8923, grad_fn=<NllLossBackward0>)
# now of desk one can and with who
# : sitting, to could and her happen
# 327 tensor(4.8293, grad_fn=<NllLossBackward0>)
# ##sive around or. phones and there '
# skill out wing. information. talk '
# 328 tensor(4.2609, grad_fn=<NllLossBackward0>)
# ,, love floated breath naomi her my
# , transport a exactly eyes i ` and
# 329 tensor(3.9256, grad_fn=<NllLossBackward0>)
# , was. used which i - rolled
# luc sounded around,, a minutes record
# 330 tensor(4.2344, grad_fn=<NllLossBackward0>)
# her ` i was the i maybe,
# this he he? evan i her talked
# 331 tensor(4.1145, grad_fn=<NllLossBackward0>)
# not hearts her killed his saiding s
# over his envy a hisracling s
# 332 tensor(3.9875, grad_fn=<NllLossBackward0>)
# into and mammals to. dim ',
# . decompositionds.. rep speakuet
# 333 tensor(5.6389, grad_fn=<NllLossBackward0>)
# some myz, her bear say `
# , auting, his coward here `
# 334 tensor(4.3785, grad_fn=<NllLossBackward0>)
# quickly ` through gentle her ` be hair
# around ` - n adam ` work alert
# 335 tensor(4.5613, grad_fn=<NllLossBackward0>)
# away hands'andton ` damn no
# upon hand,'where opening..
# 336 tensor(4.1031, grad_fn=<NllLossBackward0>)
# , 'ing said lied friend i the
# the marked. back crawled thing along looks
# 337 tensor(5.6973, grad_fn=<NllLossBackward0>)
# demand robots she and, world the a
# ', `,, minutes motion them
# 338 tensor(4.3576, grad_fn=<NllLossBackward0>)
# doing'to hopesuch road, '
# the did. a settled she breakfast '
# 339 tensor(4.7789, grad_fn=<NllLossBackward0>)
# it ` n you you iwn wife
# you i hung you honestly yeahcup true
# 340 tensor(4.2385, grad_fn=<NllLossBackward0>)
# any with t'comfortable drawing backgled
# a like t'weeks weapons outter
# 341 tensor(4.4556, grad_fn=<NllLossBackward0>)
# parents a. thinking and ski i of
# own continued in pressingrs hungrylock reclamation
# 342 tensor(5.2163, grad_fn=<NllLossBackward0>)
# going n there the ju no'`
# on seen doing a how ` there `
# 343 tensor(4.4528, grad_fn=<NllLossBackward0>)
# hospital was -. him years says `
# fridge the through. something gray that any
# 344 tensor(4.5106, grad_fn=<NllLossBackward0>)
# himself, laugh nation wrong of the stood
# . or favour take the of. to
# 345 tensor(5.7084, grad_fn=<NllLossBackward0>)
# on of disc home.,'frown
# for the better must. thing i two
# 346 tensor(5.0544, grad_fn=<NllLossBackward0>)
# . others. t louie on is the
# lip children path t then careful of of
# 347 tensor(5.5629, grad_fn=<NllLossBackward0>)
# a who. him ` cr lay think
# the,. the ` smug usually the
# 348 tensor(4.2629, grad_fn=<NllLossBackward0>)
# as constant do mounted i. do noise
# as your one had iting need kings
# 349 tensor(5.2881, grad_fn=<NllLossBackward0>)
# frozen saw thisloh to. made voice
# - saw leastele.. stupid voice
# 350 tensor(4.0922, grad_fn=<NllLossBackward0>)
# eyes discovered pain, from dances'of
# whimper could of, never bay'by
# 351 tensor(4.1867, grad_fn=<NllLossBackward0>)
# sorted `. both to human altar.
# done thistructing.,?,.
# 352 tensor(4.7237, grad_fn=<NllLossBackward0>)
# jumped dika had - with lies moonlight
# turned doss when a. are shaft
# 353 tensor(5.1808, grad_fn=<NllLossBackward0>)
# i their in ` out i ` warned
# what simon as ` without smart ` by
# 354 tensor(4.0885, grad_fn=<NllLossBackward0>)
# ,. friend old structure yeah so.
# its she blu was price now. when
# 355 tensor(5.0352, grad_fn=<NllLossBackward0>)
# ' know look n back me i of
# they broke island n against hear trevor i
# 356 tensor(4.2415, grad_fn=<NllLossBackward0>)
# because unstable getting likepd devil of the
# .ony. advancing of other. easily
# 357 tensor(5.2636, grad_fn=<NllLossBackward0>)
# maybe on please anything, were'civilized
# as i i reporting every was'off
# 358 tensor(4.6653, grad_fn=<NllLossBackward0>)
# nina used d what of two did it
# her the ve just onto the wanted experienced
# 359 tensor(4.2177, grad_fn=<NllLossBackward0>)
# shrug were to to way with a best
# wouldn were trained surely flank names me brief
# 360 tensor(5.7118, grad_fn=<NllLossBackward0>)
# ., with help i are oflus
# ., cup knowledge,k echoed said
# 361 tensor(5.4905, grad_fn=<NllLossBackward0>)
# was bitch then his. sister bedroom up
# force'did his pointedly electronics ass is
# 362 tensor(4.0702, grad_fn=<NllLossBackward0>)
# took small silence for ` having! ca
# didn surprisingly that. ` here they hoped
# 363 tensor(5.6264, grad_fn=<NllLossBackward0>)
# . of'ice with house the `
# upon upon was york, view expose she
# 364 tensor(4.7652, grad_fn=<NllLossBackward0>)
# of air fools or scar more hell deliberate
# . goddess embedded? groin to she walls
# 365 tensor(4.4752, grad_fn=<NllLossBackward0>)
# in slipped laughed she ala. said an
# , clasped says now'hospital told his
# 366 tensor(4.1542, grad_fn=<NllLossBackward0>)
# sat being need `. reassure was.
# pulled not have ` i say was up
# 367 tensor(4.3438, grad_fn=<NllLossBackward0>)
# from intense? behind wasilia with never
# home,?. was i were become
# 368 tensor(5.1617, grad_fn=<NllLossBackward0>)
# parent thing was fantastic sending take relaxing surprise
# table thing, held touched recall something man
# 369 tensor(4.5806, grad_fn=<NllLossBackward0>)
# lean, one mental campaign he features on
# so, well savage banks kind waves a
# 370 tensor(5.3428, grad_fn=<NllLossBackward0>)
# christmas - army growing.'warm such
# jamie as bern cold.'the permitted
# 371 tensor(4.9995, grad_fn=<NllLossBackward0>)
# inside fromlab eddieless more she re
# of. of she we.. or
# 372 tensor(4.3058, grad_fn=<NllLossBackward0>)
# a while dropped mike the much. from
# open without in ` a he were.
# 373 tensor(4.9538, grad_fn=<NllLossBackward0>)
# no'most secret small rick s '
# i'six do discussion ah s '
# 374 tensor(4.3431, grad_fn=<NllLossBackward0>)
# back ` the his n this mean felt
# likely ` her. some out hurried he
# 375 tensor(5.0918, grad_fn=<NllLossBackward0>)
# going i came sitting `, ofping
# telling the gust non ` to with of
# 376 tensor(3.7910, grad_fn=<NllLossBackward0>)
# bodies for who found `. have after
# woman. course would `less stop,
# 377 tensor(4.2297, grad_fn=<NllLossBackward0>)
# gr his things the restrainedy! a
# , but publishers it further of like five
# 378 tensor(5.3661, grad_fn=<NllLossBackward0>)
# and, i it is? its lecture
# , coma had the, let he be
# 379 tensor(5.2839, grad_fn=<NllLossBackward0>)
# . it where ` and both'the
# to there dad `. wo'arrived
# 380 tensor(4.3619, grad_fn=<NllLossBackward0>)
# chance would? ; to another ` the
# clip do there as. the ` the
# 381 tensor(4.5958, grad_fn=<NllLossBackward0>)
# probably forget more d next she prepared a
# realized gaze. d day well were.
# 382 tensor(4.5847, grad_fn=<NllLossBackward0>)
# n could sobs like that off'deep
# feel headed iced animal feeling into'hand
# 383 tensor(4.5112, grad_fn=<NllLossBackward0>)
# ##ping from the the to have into capable
# ##ded straight out the to know plate over
# 384 tensor(5.5392, grad_fn=<NllLossBackward0>)
# then clare seemed the two but. re
# then ` drove the apartment '. re
# 385 tensor(5.1823, grad_fn=<NllLossBackward0>)
# glasses works but he cops naked since in
# around is beautiful he files into any tapping
# 386 tensor(4.5835, grad_fn=<NllLossBackward0>)
# . of kind it offer powerful. handed
# out another patterns im keep ` - onto
# 387 tensor(4.9014, grad_fn=<NllLossBackward0>)
# riders bounty. thomas and hard as `
# society statue - still maybe what, `
# 388 tensor(4.6609, grad_fn=<NllLossBackward0>)
# ` yourself it quick looking when wr came
# ...
# breeze eyes. was i stretches number begun
# script eyes, was his paced dress made
# 1021 tensor(4.4193, grad_fn=<NllLossBackward0>)
# household as'so grandpa asked '
# mart caught time why when and, '
# 1022 tensor(4.6855, grad_fn=<NllLossBackward0>)
# i had the of ` air k -
# i had. in ` the ` lighter
# 1023 tensor(4.4374, grad_fn=<NllLossBackward0>)
# ##let. and air her the green a
# west and and saddle for theu done
# 1024 tensor(5.7393, grad_fn=<NllLossBackward0>)
# that that me away the friend of like
# that to a mouth of, of no
# 1025 tensor(5.6001, grad_fn=<NllLossBackward0>)
# ' so her of bit'care.
# ' i it three square'him.
# 1026 tensor(3.8916, grad_fn=<NllLossBackward0>)
# man has when make could can to he
# long was, need wo want and he
# 1027 tensor(4.4776, grad_fn=<NllLossBackward0>)
# la, makes think parents with at caution
# death staring'walk target held down do
# 1028 tensor(4.1465, grad_fn=<NllLossBackward0>)
# sheriff for tar not calming n was preferred
# liver down savage alright a n was out
# 1029 tensor(5.3038, grad_fn=<NllLossBackward0>)
# lesson too, native any there if dell
# greatestistic?? unless they with that
# 1030 tensor(5.7639, grad_fn=<NllLossBackward0>)
# to. dragged. hugh. anythingd
# it of drumming. patti long anything.
# 1031 tensor(5.3182, grad_fn=<NllLossBackward0>)
# n who ourled advances my begins '
# n called his the home you froze never
# 1032 tensor(4.3266, grad_fn=<NllLossBackward0>)
# ' his if between about extra arms i
# ' him if'about what fingers the
# 1033 tensor(4.5656, grad_fn=<NllLossBackward0>)
# the the. were ` s, dolores
# ' :.,'s it and
# 1034 tensor(5.1292, grad_fn=<NllLossBackward0>)
# im was feet wass before to of
# i snapping mother.s for somewhere of
# 1035 tensor(5.1891, grad_fn=<NllLossBackward0>)
# ve had to carry why had s eyes
# re'with be i refused s hand
# 1036 tensor(4.5466, grad_fn=<NllLossBackward0>)
# and choked her note'' but her
# and, ` deck'` with his
# 1037 tensor(4.4725, grad_fn=<NllLossBackward0>)
# as at town.ein the man of
# . progress,.cc they to
# 1038 tensor(5.7076, grad_fn=<NllLossBackward0>)
# ' i'` sure. life you
# . what'of wishing, name i
# 1039 tensor(3.7189, grad_fn=<NllLossBackward0>)
# hole no feel to'the more because
# . even was with'the noticeable,
# 1040 tensor(4.7286, grad_fn=<NllLossBackward0>)
# the'every, have you'have
# get'un. keep i'hurry
# 1041 tensor(4.0721, grad_fn=<NllLossBackward0>)
# man his the old shey the walked
# shoes back their, the singing there.
# 1042 tensor(5.2654, grad_fn=<NllLossBackward0>)
# and come'the card reckless to when
# fra feel'myself josh looking - proud
# 1043 tensor(4.3370, grad_fn=<NllLossBackward0>)
# , the of attention t believe. from
# ' my of fingers t you. me
# 1044 tensor(4.2024, grad_fn=<NllLossBackward0>)
# . i the? searching left sts be
# that other though? needing mother king think
# 1045 tensor(4.1768, grad_fn=<NllLossBackward0>)
# to how i feral '. along smooth
# been ruby ` good'was back places
# 1046 tensor(4.5362, grad_fn=<NllLossBackward0>)
# ic the him'had and swear his
# proud a. had looked, did three
# 1047 tensor(4.6493, grad_fn=<NllLossBackward0>)
# whispered ` entire gap sleep ve ` picture
# said his. being the re ` getting
# 1048 tensor(3.9273, grad_fn=<NllLossBackward0>)
# activated blonde'`.n number car
# took with'`. as urge legs
# 1049 tensor(3.4355, grad_fn=<NllLossBackward0>)
# to the turned do side n the marquez
# back this shifted were bedroom like hisd
# 1050 tensor(4.9318, grad_fn=<NllLossBackward0>)
# weres i ` ` the to the
# wanted in there ` ` the to,
# 1051 tensor(4.5673, grad_fn=<NllLossBackward0>)
# understood. paranoid up pi, in but
# for pants something,go,. is
# 1052 tensor(5.2008, grad_fn=<NllLossBackward0>)
# ,?. head. pinberg '
# .,.. as meantest '
# 1053 tensor(4.0734, grad_fn=<NllLossBackward0>)
# 30 115z urine their land two moment
# oh, was he then created knowledge little
# 1054 tensor(5.1032, grad_fn=<NllLossBackward0>)
# you focused, i no whether it a
# riley shrugged, the but if i every
# 1055 tensor(5.0185, grad_fn=<NllLossBackward0>)
# and our waved, joke he her is
# lina the an cloud the, in doesn
# 1056 tensor(5.2077, grad_fn=<NllLossBackward0>)
# nooe va * and i. the
# already so.uni. i right out
# 1057 tensor(4.7999, grad_fn=<NllLossBackward0>)
# writing they and and head here had his
# over inie, shoulder worldian the
# 1058 tensor(5.0339, grad_fn=<NllLossBackward0>)
# . how. her stage me so week
# annoying he. ` shit me. bathroom
# 1059 tensor(4.0740, grad_fn=<NllLossBackward0>)
# dedicated.ille realisedisdee'n
# the for of. and her how going
# 1060 tensor(5.0422, grad_fn=<NllLossBackward0>)
# have.. telling away. threw pit
# ', court definitely. because knew heat
# 1061 tensor(4.1898, grad_fn=<NllLossBackward0>)
# my torin just doing shell hope a
# the.if that wrong wound hate from
# 1062 tensor(5.0832, grad_fn=<NllLossBackward0>)
# connection with was had her photos gazed
# ##nas when bob already her, fora
# 1063 tensor(5.3020, grad_fn=<NllLossBackward0>)
# ' if can josie n scott ` case
# it she reach he all it ` salon
# 1064 tensor(4.0249, grad_fn=<NllLossBackward0>)
# grew was beg te them species over really
# couldn! were do plans interestui time
# 1065 tensor(5.4269, grad_fn=<NllLossBackward0>)
# ##us there.ing in 'wave my
# ##lli there, him bob 'fl photographs
# 1066 tensor(4.5409, grad_fn=<NllLossBackward0>)
# a direna off her top. slick
# then the onto as in wholeung solution
# 1067 tensor(5.5937, grad_fn=<NllLossBackward0>)
# . mine he cookie. alive his t
# , unusual thousand entire there going you t
# 1068 tensor(4.7530, grad_fn=<NllLossBackward0>)
# . ` i summer but he my.
# . ` `. six she confront from
# 1069 tensor(4.2920, grad_fn=<NllLossBackward0>)
# done that told, once bone through she
# that a murmured byso of as from
# 1070 tensor(4.5057, grad_fn=<NllLossBackward0>)
# know, norman humble i. now.
# do, his their '. it without
# 1071 tensor(5.0884, grad_fn=<NllLossBackward0>)
# things you. ` all here, to
# chocolate you go ` into '. to
# 1072 tensor(4.1613, grad_fn=<NllLossBackward0>)
# pastor going her leaving consider in said my
# world going to fighting day of was sc
# 1073 tensor(4.2127, grad_fn=<NllLossBackward0>)
# casually i here, starting everyone would done
# dad i a to silently voice stuffed trying
# 1074 tensor(4.2131, grad_fn=<NllLossBackward0>)
# a and, what pride a i anxiously
# their., the returned your and her
# 1075 tensor(4.8996, grad_fn=<NllLossBackward0>)
# of ` t dia'lips if the
# university ` t. do. a top
# 1076 tensor(4.5463, grad_fn=<NllLossBackward0>)
# , just place.tz. appeared remember
# , couldn k? and,! so
# 1077 tensor(5.4122, grad_fn=<NllLossBackward0>)
# apparently over started, his if. invisible
# men to are hit dr'away maneuver
# 1078 tensor(5.1703, grad_fn=<NllLossBackward0>)
# ##e grinned, do mouth his our.
# relationship had goofy read shoulder the my adult
# 1079 tensor(5.4664, grad_fn=<NllLossBackward0>)
# '. frankly ` of too''
# ' across my ` in here'to
# 1080 tensor(4.4136, grad_fn=<NllLossBackward0>)
# , earlier taking las can healed that ask
# .omeed? have tongue who have
# 1081 tensor(5.1595, grad_fn=<NllLossBackward0>)
# ren ` old your day this for '
# the ` young n words mag. '
# 1082 tensor(4.2537, grad_fn=<NllLossBackward0>)
# doll what nora to having, stays in
# br he i off telling?'perfectly
# 1083 tensor(3.8549, grad_fn=<NllLossBackward0>)
# shutter agreed how at small. neither though
# more don what later he just the to
# 1084 tensor(5.2318, grad_fn=<NllLossBackward0>)
# , mornings, and it narrow.
# climbed by was.. the shame should
# 1085 tensor(5.3891, grad_fn=<NllLossBackward0>)
# vincent for after cr was in me mental
# he, more second was buildings himself the
# 1086 tensor(5.2746, grad_fn=<NllLossBackward0>)
# and is go been with. her -
# ,. come coated by his she -
# 1087 tensor(4.5878, grad_fn=<NllLossBackward0>)
# you or her had. the me him
# anyone. wrapbbed in competing kiss the
# 1088 tensor(4.5152, grad_fn=<NllLossBackward0>)
# and warped ` hair in'danny was
# the the she fingers in'him need
# 1089 tensor(4.4326, grad_fn=<NllLossBackward0>)
# was think out? in the if,
# brought do rose?wise another they over
# 1090 tensor(5.4894, grad_fn=<NllLossBackward0>)
# - can rolled both could more entire.
# bullets'' have was of couch and
# 1091 tensor(4.3766, grad_fn=<NllLossBackward0>)
# for disbelief, paid clearing been slipping wearing
# to lies and was quad seen the knew
# 1092 tensor(5.3162, grad_fn=<NllLossBackward0>)
# friend, but sierra slide his nodded s
# gift ties'me'bride had s
# 1093 tensor(4.4732, grad_fn=<NllLossBackward0>)
# . shit what - wished 35 out shared
# the care of tres was. me television
# 1094 tensor(4.6280, grad_fn=<NllLossBackward0>)
# ##tial source we. no hadie,
# over curtains iken him wass answer
# 1095 tensor(5.4600, grad_fn=<NllLossBackward0>)
# , arm.. through eastsno
# he breath and help. his.ros
# 1096 tensor(5.0925, grad_fn=<NllLossBackward0>)
# at distance the, aw decided t kept
# than blood would. as began t read
# 1097 tensor(5.4845, grad_fn=<NllLossBackward0>)
# like out t eating to the. *
# . head t fleeting'him as *
# 1098 tensor(4.3071, grad_fn=<NllLossBackward0>)
# . me,ink.. on.
# . my forua far. desperate.
# 1099 tensor(4.3578, grad_fn=<NllLossBackward0>)
# tensor([ 2074,  2256,  1010,  2217,  1050, 21555,  2500,  2052])
# tensor([ 2119,  1996,  3240,  1996,  4417, 18740,  2084,  3031])
# tensor([5131, 1045, 1045, 1036, 2042, 1012, 2006, 1997])
# tensor([2341, 2053, 1045, 1036, 2042, 1997, 1011, 1997])
# tensor([ 1005,  1010,  2010,  2667,  1036,  2020,  2584, 19381])
# tensor([1005, 1010, 1996, 1037, 1036, 2514, 1005, 1005])
# tensor([ 3124, 12883, 12780,  2032,  1005,  1998,  1012,  2087])
# tensor([9715, 2010, 2002, 2009, 1005, 2015, 1012, 2093])
# tensor([ 2464,  2032,  2010, 10293,  1050,  2014,  2077,  1050])
# tensor([2641, 2014, 2002, 2378, 1037, 1036, 1012, 1050])
# tensor([1998, 9348, 2079, 1998, 1037, 2045, 2310, 1010])
# tensor([1012, 1045, 2001, 1037, 1037, 2006, 2128, 2237])
# tensor([2173, 2053, 1997, 3868, 2016, 2292, 1037, 1010])
# tensor([ 4824,  1036,  1997,  1998,  2125,  1012, 10137,  2000])
# tensor([ 1998,  4782,  7671,  2398,  1998,  2051, 15116,  4207])
# tensor([6212, 3184, 2253, 2219, 1999, 2217, 8724, 2069])
# tensor([ 2681,  2326,  2018,  2054,  1012, 20786,  2003,  2001])
# tensor([ 9652,  2158, 18551,  2117, 12020,  2004,  5320,  2001])
# tensor([2010, 2125, 2100, 1056, 2031, 1012, 2279, 2005])
# tensor([2026, 1010, 2341, 1056, 2079, 1996, 5023, 1010])
# Loss at step = 1100 for train data is 0.2306 for val it is 0.2203
# ##ery the extends `ti action not with
# ##an theich `ag of merely phone
# 1100 tensor(4.8824, grad_fn=<NllLossBackward0>)
# minutes ` brokeie,, one the
# days ` blasts, had ser happiness his
# 1101 tensor(4.8114, grad_fn=<NllLossBackward0>)
# ? are answered. out their. stomach
# to need a. amount a, absence
# 1102 tensor(5.2171, grad_fn=<NllLossBackward0>)
# to cradled much you to get. `
# been over i'his say spat i
# 1103 tensor(4.4497, grad_fn=<NllLossBackward0>)
# ''a added finished demanded skyscraper by
# ' boss you saidni naomi western.
# 1104 tensor(4.6613, grad_fn=<NllLossBackward0>)
# from in herself'me his up think
# launch glass memory'a jumper'are
# 1105 tensor(4.8810, grad_fn=<NllLossBackward0>)
# jerusalem the flooded circled heavy ` '.
# . the was seven uncertain `'with
# 1106 tensor(4.3535, grad_fn=<NllLossBackward0>)
# of again ve cold man weakly see of
# a the m rumble sniper their the '
# 1107 tensor(4.8947, grad_fn=<NllLossBackward0>)
# i who ', kat property've
# painter runes '. he fiery had m
# 1108 tensor(4.8803, grad_fn=<NllLossBackward0>)
# thought that monster wasboard, you i
# would e spoon turned. my you?
# 1109 tensor(4.7614, grad_fn=<NllLossBackward0>)
# ##idal ve s for of before. he
# ##un'' of side ', `
# 1110 tensor(5.1642, grad_fn=<NllLossBackward0>)
# as'called for back. n drawing
# ,'grins. me, n had
# 1111 tensor(4.4158, grad_fn=<NllLossBackward0>)
# . reward of france with he i now
# dug hunts since talk toe only i
# 1112 tensor(4.4842, grad_fn=<NllLossBackward0>)
# ##con s last distance eden when'began
# ##test s ones stroke s kind'presents
# 1113 tensor(4.4782, grad_fn=<NllLossBackward0>)
# my ` a waste'her he if
# everything the asosi'a ` i
# 1114 tensor(5.1056, grad_fn=<NllLossBackward0>)
# . wo. it hers lucky to takes
# old know for at as back to isn
# 1115 tensor(4.9261, grad_fn=<NllLossBackward0>)
# she? glancing which got the. ev
# a who her button'her. them
# 1116 tensor(4.4223, grad_fn=<NllLossBackward0>)
# and to not you is do the at
# loop working participating we of have turn.
# 1117 tensor(5.2198, grad_fn=<NllLossBackward0>)
# my the sign replied else t ` dominate
# to the wai mean more t ` her
# 1118 tensor(4.6978, grad_fn=<NllLossBackward0>)
# the wondered what over danger eat grabbed goat
# he dreamed never pm lounge sebastian ten close
# 1119 tensor(4.9046, grad_fn=<NllLossBackward0>)
# ' down the., mug be '
# ' reach over., gaze catch '
# 1120 tensor(4.2890, grad_fn=<NllLossBackward0>)
# prove. because that said to between his
# tell to of they thought the as me
# 1121 tensor(4.0423, grad_fn=<NllLossBackward0>)
# . its hand now dammit people had that
# toward the.? wasting history set to
# 1122 tensor(4.5304, grad_fn=<NllLossBackward0>)
# opened. computerupt a has stated mono
# was over grand3 those she said yeah
# 1123 tensor(4.9788, grad_fn=<NllLossBackward0>)
# ,.car departure '. would that
# . lu was mind'be to for
# 1124 tensor(4.3788, grad_fn=<NllLossBackward0>)
# the, as you just `. of
# the. ago? n dante. of
# 1125 tensor(4.1827, grad_fn=<NllLossBackward0>)
# there feeling from he'through from he
# then mum. two and determined be she
# 1126 tensor(4.8318, grad_fn=<NllLossBackward0>)
# had the ipy brandy at himself he
# had him effect humans guest far elvis her
# 1127 tensor(5.4100, grad_fn=<NllLossBackward0>)
# ` thought, with it understand. share
# ` were a. up hesitate as destroy
# 1128 tensor(4.1075, grad_fn=<NllLossBackward0>)
# into room an there are consuming and count
# his brothel said stayches suited until purposes
# 1129 tensor(5.9034, grad_fn=<NllLossBackward0>)
# . fiddle cracking her was the all wanted
# . dil embarrassment thisx don the?
# 1130 tensor(5.4706, grad_fn=<NllLossBackward0>)
# began be of that were like truck in
# finds hear reflections why for not. done
# 1131 tensor(5.2219, grad_fn=<NllLossBackward0>)
# the'peek's. even wait
# the'movement he s. he be
# 1132 tensor(4.2614, grad_fn=<NllLossBackward0>)
# make,. staff good ` shots he
# know up. where relentless ` asked servicing
# 1133 tensor(4.6603, grad_fn=<NllLossBackward0>)
# would iway. ` me her like
# away no and else ` this another thank
# 1134 tensor(3.9839, grad_fn=<NllLossBackward0>)
# the found getting they he. the,
# worried really a i he on? and
# 1135 tensor(4.3772, grad_fn=<NllLossBackward0>)
# , so glass. clung disclose positive all
# you justine unwilling six was speak anything time
# 1136 tensor(5.2522, grad_fn=<NllLossBackward0>)
# but purchase too t but up i in
# its turn just t ifed he from
# 1137 tensor(5.4474, grad_fn=<NllLossBackward0>)
# as lawsuit occasionally some in like linked stars
# like work, doing and outfitd had
# 1138 tensor(5.1665, grad_fn=<NllLossBackward0>)
# lit okay pictures, understanding labs that entire
# threw made of, the af who image
# 1139 tensor(5.4809, grad_fn=<NllLossBackward0>)
# `.'` escaping bray she made
# ` my'` mele forms bent
# 1140 tensor(4.5163, grad_fn=<NllLossBackward0>)
# ` condom top all more she ` the
# she dresses her the so ` ` the
# 1141 tensor(4.1681, grad_fn=<NllLossBackward0>)
# ##er up and of at for. do
# on be down _ to for mind don
# 1142 tensor(5.0591, grad_fn=<NllLossBackward0>)
# over in '. thighs. her,
# in keep'i attach, to.
# 1143 tensor(4.8140, grad_fn=<NllLossBackward0>)
# never tell all her adjusted an ta to
# never do made a'a bad to
# 1144 tensor(4.4206, grad_fn=<NllLossBackward0>)
# moderator not came. often n turned grade
# back with ga and knew more a if
# 1145 tensor(4.7004, grad_fn=<NllLossBackward0>)
# ##rama.. a the earth funeral was
# the the. the it, with.
# 1146 tensor(5.2342, grad_fn=<NllLossBackward0>)
# someone to'' n any hear to
# were,'this been to do to
# 1147 tensor(3.9812, grad_fn=<NllLossBackward0>)
# cloud shadow mayor into monk kisseding regular
# ##ness `ar within kei wanted to provinces
# 1148 tensor(4.6672, grad_fn=<NllLossBackward0>)
# t. soon as, he and a
# t. voice. to how and polka
# 1149 tensor(4.2012, grad_fn=<NllLossBackward0>)
# por i probably magic and. another.
# of a n few the that a and
# 1150 tensor(5.0911, grad_fn=<NllLossBackward0>)

# %%
if (not pretrained) or build_pretrained:
    with open('text_generator.pkl', 'wb') as handler:
        pickle.dump(gen, handler)

# %%
if pretrained:
    with open('text_generator.pkl', 'rb') as handler:
        gen = pickle.load(handler)

# %%
prompt = 'She was going to do it, but'

# %%
prompt_ids = tokenizer(prompt, return_tensors='pt', add_special_tokens=False).input_ids
prompt_ids

# %%
generated_ids = gen.generate(prompt_ids.to(device), max_new_tokens=10)
generated_ids

# %%
tokenizer.decode(generated_ids[0])
