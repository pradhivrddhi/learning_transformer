# %%
from transformer.config import FetchFromPretrained as ConfigFromPretrained

# %%
from transformer.tokenizer import FetchFromPretrained as TokenizerFromPretrained

# %%
from datasets import load_dataset

# %%
import torch

# %%
device = 'cuda' if torch.cuda.is_available() else 'cpu'
device = 'cpu'
device
# Out:
# 'cpu'

# %%
data = load_dataset('AlekseyKorshuk/books')
data
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['text'],
#         num_rows: 741
#     })
# })

# %%
model_ckpt = 'bert-base-uncased'

# %%
config = ConfigFromPretrained(model_ckpt=model_ckpt).fetch()
config
# Out:
# BertConfig {
#   "_name_or_path": "bert-base-uncased",
#   "architectures": [
#     "BertForMaskedLM"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "classifier_dropout": null,
#   "gradient_checkpointing": false,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "layer_norm_eps": 1e-12,
#   "max_position_embeddings": 512,
#   "model_type": "bert",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "pad_token_id": 0,
#   "position_embedding_type": "absolute",
#   "transformers_version": "4.39.2",
#   "type_vocab_size": 2,
#   "use_cache": true,
#   "vocab_size": 30522
# }

# %%
config.hidden_size = 128
config.intermediate_size = 1024 * 2
config.max_position_embeddings = 128
config.num_attention_heads = 64
config.num_hidden_layers = 16
config.device = device
config.dtype = torch.float32

# %%
batch_size = 8

# %%
tokenizer = TokenizerFromPretrained(model_ckpt=model_ckpt).fetch()
tokenizer
# Out:
# BertTokenizerFast(name_or_path='bert-base-uncased', vocab_size=30522, model_max_length=512, is_fast=True, padding_side='right', truncation_side='right', special_tokens={'unk_token': '[UNK]', 'sep_token': '[SEP]', 'pad_token': '[PAD]', 'cls_token': '[CLS]', 'mask_token': '[MASK]'}, clean_up_tokenization_spaces=True),  added_tokens_decoder={
# 	0: AddedToken("[PAD]", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	100: AddedToken("[UNK]", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	101: AddedToken("[CLS]", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	102: AddedToken("[SEP]", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	103: AddedToken("[MASK]", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# }

# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
import numpy as np

# %%
import os

# %%
import pickle

# %%
import random

# %%
import re

# %%
files_count = len(data['train'])
files_count
# Out:
# 741

# %%
split_index_1, split_index_2 = int(files_count * 0.8), int(files_count * 0.9)
split_index_1, split_index_2
# Out:
# (592, 666)

# %%
def get_data_from_random_files(split):
    indices = []
    if split == 'train':
        file_id = random.randint(0, split_index_1)
    elif split == 'test':
        file_id = random.randint(split_index_1, split_index_2)
    elif split == 'val':
        file_id = random.randint(split_index_2, files_count)

    file = data['train'][file_id]['text']

    input_ids = tokenizer(file, return_tensors='pt', add_special_tokens=False).input_ids[0]
    return input_ids

# %%
def get_batch(split):
    input_ids = get_data_from_random_files(split=split)
    ix = torch.randint(len(input_ids) - config.max_position_embeddings, (batch_size,))
    x = torch.stack([input_ids[i:i + config.max_position_embeddings] for i in ix])
    y = torch.stack([input_ids[i + 1:i + config.max_position_embeddings + 1] for i in ix])
    x, y = x.to(torch.int64).to(device), y.to(torch.int64).to(device)
    return x, y

# %%
get_data_from_random_files('train')
# Out:
# Token indices sequence length is longer than the specified maximum sequence length for this model (1354976 > 512). Running this sequence through the model will result in indexing errors
# tensor([1036, 1036, 3198,  ..., 2086, 3283, 1029])

# %%
get_batch('train')
# Out:
# (tensor([[ 1996,  2540,  3145,  ..., 25933, 10270,  2271],
#          [25070,  1051, 18153,  ..., 10047,  9524,  9336],
#          [ 1996,  2034,  2000,  ...,  1996,  3492,  2611],
#          ...,
#          [ 2033,  2046,  7276,  ...,  2449,  2203,  1997],
#          [ 1045,  3631,  1037,  ...,  2793,  2003,  4803],
#          [ 1996,  2273,  2007,  ...,  2018, 19461, 27586]]),
#  tensor([[ 2540,  3145,   999,  ..., 10270,  2271,  3368],
#          [ 1051, 18153,  2063,  ...,  9524,  9336,  2102],
#          [ 2034,  2000,  2360,  ...,  3492,  2611,  1012],
#          ...,
#          [ 2046,  7276,  4465,  ...,  2203,  1997,  2026],
#          [ 3631,  1037, 19395,  ...,  2003,  4803,   999],
#          [ 2273,  2007,  2032,  ..., 19461, 27586,  2389]]))

# %%
from transformer.head.text_generator_decoder_only import TextGenerator

# %%
generator = TextGenerator(config)

# %%
gen = generator.to(device)

# %%
eval_iters = 100

# %%
eval_iter_ticks = 5

# %%
X, Y = get_batch('train')
logits, loss = gen(X, Y, tokenizer)
logits, logits.size(), loss
# Out:
# ##hor insisted hardin toni keeps translitchaft hawthorne
# ##thi the had.. that deadly could
# (tensor([[-0.6201, -0.4167, -0.1482,  ...,  0.5508,  0.2300, -0.2200],
#          [-0.3544, -1.0222, -0.8640,  ...,  0.3704,  0.6170, -0.3816],
#          [ 0.6972,  0.4416,  0.2256,  ..., -0.3638,  0.5547, -0.8706],
#          ...,
#          [ 0.0706, -0.2483, -0.4540,  ..., -0.1054,  0.1064, -0.9024],
#          [ 1.1845, -0.8941,  0.3462,  ..., -0.6019,  1.3436, -0.7249],
#          [ 0.4633, -0.0675,  0.4198,  ...,  0.2016,  1.2000, -0.5350]],
#         grad_fn=<SliceBackward0>),
#  torch.Size([8, 30522]),
#  tensor(10.4464, grad_fn=<NllLossBackward0>))

# %%
pretrained = False

# %%
build_pretrained = False

# %%
@torch.no_grad()
def estimate_loss():
    out = {}
    if (not pretrained) or build_pretrained:
        with open('text_generator.pkl', 'wb') as handler:
            pickle.dump(gen, handler)
    gen.eval()
    for split in ['train', 'val']:
        losses = torch.zeros(eval_iters)
        for k in range(eval_iter_ticks):
            X, Y = get_batch(split)
            logits, loss = gen(X, Y)
            losses[k] = loss.item()
        out[split] = losses.mean()
    gen.train()
    return out

# %%
learning_rate = 5e-4

# %%
iterations = 10000

# %%
if (not pretrained) or build_pretrained:
    # create a PyTorch optimizer
    optimizer = torch.optim.AdamW(gen.parameters(), lr=learning_rate, weight_decay=0.01, amsgrad=True)

    for iter in range(iterations):
        try:
            
            if (iter != 0) and (iter % eval_iters == 0):
                losses = estimate_loss()
                train_loss = losses['train']
                val_loss = losses['val']
                print(f'Loss at step = {iter} for train data is {train_loss:.4f} for val it is {val_loss:.4f}')

            # sample a batch of data
            xb, yb = get_batch('train')

            # evaluate the loss
            logits, loss = gen.forward(xb, yb, tokenizer)
            if not torch.isnan(loss).any():
                print(iter, loss)
                optimizer.zero_grad(set_to_none=True)
                loss.backward()
                torch.torch.nn.utils.clip_grad_norm_(gen.parameters(), max_norm=15.0)
                optimizer.step()
            else:
                print('NaN loss')
                print(iter, loss)
                input()
        except Exception as e:
            print(e)
# Out:
# lorraine jorge twenty20ospherepg death vishnulogists
# , been scent dusty into, for,
# 0 tensor(10.4765, grad_fn=<NllLossBackward0>)
# zenith brokenweekdae midday futures lame raked
# inter on he work human n coming brought
# 1 tensor(10.1642, grad_fn=<NllLossBackward0>)
# ##heater ɫ cocaine 葉 [unused431]rco vt ruler
# exclusive's her a,. -
# 2 tensor(9.6891, grad_fn=<NllLossBackward0>)
# ##taking until joanna pacific lunged lame enterprisescey
# . floor if good,ion starbucks t
# 3 tensor(9.7375, grad_fn=<NllLossBackward0>)
# ##np transportation creaked あ 139 yokohama'prophecy
# other the grow that raked minutes'covered
# 4 tensor(9.8085, grad_fn=<NllLossBackward0>)
# biketore goldstein freighterrove bayern tailored shaft
# mo you straight handle the for then next
# 5 tensor(9.8376, grad_fn=<NllLossBackward0>)
# 46th arteries jonas 2000 piazza theorem 1999.
# , family princess to a cavern i alone
# 6 tensor(9.9625, grad_fn=<NllLossBackward0>)
# ##wn married underneath davey mocked attire ranchdhi
# no assess she addressing was agree justice lot
# 7 tensor(9.5175, grad_fn=<NllLossBackward0>)
# nelsonハ returned slovak hummed ‚ reno schooling
# of yesless said my a'a
# 8 tensor(8.7660, grad_fn=<NllLossBackward0>)
# 331 beach might'` and hypothesis freeing
# he t. the in to bones man
# 9 tensor(8.5759, grad_fn=<NllLossBackward0>)
# letterman smallest ulster fished lithium gypsy fu '
# ? him feel theaters in now ` '
# 10 tensor(8.4040, grad_fn=<NllLossBackward0>)
# glasses chased, obtaintur aiding surrender pertaining
# dave t has. i, me been
# 11 tensor(8.4276, grad_fn=<NllLossBackward0>)
# now 211 ≥ preferring|天 ending regretted
# i sense retreat. she sos dallas
# 12 tensor(9.2293, grad_fn=<NllLossBackward0>)
# bravo still strengthened selangor ricky carvings shifts knew
# eyes dali his evenly pick pull `
# 13 tensor(7.9975, grad_fn=<NllLossBackward0>)
# rbi the shortstop elects ` mana boom delegate
# ##ked. up, ` paused was `
# 14 tensor(7.8140, grad_fn=<NllLossBackward0>)
# ##bner torres predictals 29 iifolia mate
# i she, a :? bare tiny
# 15 tensor(8.4280, grad_fn=<NllLossBackward0>)
# `. equally still missiles the? deficit
# a he any joshua a line and.
# 16 tensor(8.1243, grad_fn=<NllLossBackward0>)
# african'sms the hazardous [unused458] the pork
# rattle mum what the the these the characteristics
# 17 tensor(8.1530, grad_fn=<NllLossBackward0>)
# pushwg except gets coupled translation 148 '
# hold to plus he even relationship my and
# 18 tensor(8.3958, grad_fn=<NllLossBackward0>)
# bernardo more ᄂب to startled well recreation
# and a it was a them out and
# 19 tensor(8.0001, grad_fn=<NllLossBackward0>)
# .and hines health her 590 even cisco
# rode perhaps the old.. mission sparkled
# 20 tensor(7.3148, grad_fn=<NllLossBackward0>)
# other to might one can arm irony going
# they had'flight strict this feel to
# 21 tensor(7.5345, grad_fn=<NllLossBackward0>)
# patient inzong slender ton hair `.
# back make to in teacher * sah
# 22 tensor(7.9243, grad_fn=<NllLossBackward0>)
# chiefly insane chance neglect a rudolf samson attraction
# understand woman the products ago and, corn
# 23 tensor(7.5558, grad_fn=<NllLossBackward0>)
# . - the meadows village york,.
# . no there legs. herself known the
# 24 tensor(7.0423, grad_fn=<NllLossBackward0>)
# ##hair storeista s far except horn and
# . foot, ` followed funeral professional left
# 25 tensor(7.0841, grad_fn=<NllLossBackward0>)
# sixteenth been clungally saved squeak was,
# ' he the used week a he a
# 26 tensor(6.9157, grad_fn=<NllLossBackward0>)
# . you'thelag what?.
# watching speak all of a that.,
# 27 tensor(7.3975, grad_fn=<NllLossBackward0>)
# . hand front is to wolf him the
# to a them doing somewhat get works and
# 28 tensor(7.0212, grad_fn=<NllLossBackward0>)
# as baroness. her welch early theaters little
# does trail the med warm i it flower
# 29 tensor(7.2379, grad_fn=<NllLossBackward0>)
# ultimate hedra work grabbed. votes in
# too ` hate boss. king. grunt
# 30 tensor(6.4939, grad_fn=<NllLossBackward0>)
# looked was this move.ui on blow
# '. the '. delicious,,
# 31 tensor(6.4840, grad_fn=<NllLossBackward0>)
# he ` a know'of moderator her
# the realization and. you huge left barbie
# 32 tensor(6.8255, grad_fn=<NllLossBackward0>)
# that and sans felt i the in `
# has be at nose and.. `
# 33 tensor(6.3108, grad_fn=<NllLossBackward0>)
# ' in to forest. ought ` and
# ##bat ` shoulder it, go you `
# 34 tensor(6.5484, grad_fn=<NllLossBackward0>)
# you she the climax the i would,
# well d'damon maybe better, been
# 35 tensor(6.3859, grad_fn=<NllLossBackward0>)
# of emitted folded'cried cablespre.
# is would. d needs that she beside
# 36 tensor(6.5599, grad_fn=<NllLossBackward0>)
# ` her that gocend would place.
# angel woman., * to sleep three
# 37 tensor(6.3032, grad_fn=<NllLossBackward0>)
# ? i ` trigger twenty with killings d
# tend of ` will was d cock '
# 38 tensor(6.9717, grad_fn=<NllLossBackward0>)
# look 81 byte to. endured than.
# ##rin a rose allowing. to said be
# 39 tensor(6.2377, grad_fn=<NllLossBackward0>)
# ##anger. d spirit victims. ` from
# .n on her wandered os ` high
# 40 tensor(6.4299, grad_fn=<NllLossBackward0>)
# anger assemblies with and : attached half that
# had glenn probably feet? that seemed work
# 41 tensor(6.9422, grad_fn=<NllLossBackward0>)
# ` and i rose smoke, going oh
# it soon ` i of of couldrun
# 42 tensor(5.8105, grad_fn=<NllLossBackward0>)
# ' realizing gram banking with lore innovations ll
# ' the add ` and, affected man
# 43 tensor(6.4522, grad_fn=<NllLossBackward0>)
# of. noticed murphy of the a thoughts
# ' her.n better'of he
# 44 tensor(6.6817, grad_fn=<NllLossBackward0>)
# that ` love ` simited, your
# i ', at courset wrappedsty
# 45 tensor(6.4622, grad_fn=<NllLossBackward0>)
# . several a early lego ` get your
# ##ed. the me heard a aits
# 46 tensor(7.1041, grad_fn=<NllLossBackward0>)
# ' dinosaur of couch are products ` ragged
# was else - swept ', ` was
# 47 tensor(5.9649, grad_fn=<NllLossBackward0>)
# reunited familiar abandoned 'ович t stay,
# cows great eyes it rest we seven as
# 48 tensor(7.0754, grad_fn=<NllLossBackward0>)
# `ayan watchedboat it the collect my
# i carrying _ tell. her with.
# 49 tensor(6.1394, grad_fn=<NllLossBackward0>)
# was յ s the but, had eastman
# . tomorrow ` unique hisange kat '
# 50 tensor(5.9976, grad_fn=<NllLossBackward0>)
# . as'victory'aboutptic that
# ..bs how just whatever down two
# 51 tensor(6.1506, grad_fn=<NllLossBackward0>)
# shouts a it'for. them and
# homage n.'to'back and
# 52 tensor(6.3349, grad_fn=<NllLossBackward0>)
# you foster on shook? ofwai mongolia
# what give, made. of of loved
# 53 tensor(6.7519, grad_fn=<NllLossBackward0>)
# oh foremost against. at, living that
# pencil t, at made lucius matter neither
# 54 tensor(7.1191, grad_fn=<NllLossBackward0>)
# `.. commentary medals hands, parental
# re before and brow had. she he
# 55 tensor(5.9226, grad_fn=<NllLossBackward0>)
# his tumbling someone 'и'ncede
# body.'she sally i as i
# 56 tensor(6.0054, grad_fn=<NllLossBackward0>)
# ##mmol ` lizard,'thentman
# ##case ax on escort anyone he togs
# 57 tensor(6.6756, grad_fn=<NllLossBackward0>)
# ##cu shirt deeper to a you '.
# warmth you leave just. too was '
# 58 tensor(6.1124, grad_fn=<NllLossBackward0>)
# . one horse sister. carpathian'lo
# a did that,fire and meant then
# 59 tensor(6.6655, grad_fn=<NllLossBackward0>)
# ''a as to abuse. here
# ' m with braden it up looking.
# 60 tensor(5.8582, grad_fn=<NllLossBackward0>)
# my `'not mine he orsonn
# he doubted '. `, give n
# 61 tensor(6.2722, grad_fn=<NllLossBackward0>)
# the from war said him things it until
# germain, the also but if broken are
# 62 tensor(6.9998, grad_fn=<NllLossBackward0>)
# ##are commerce walkedmvance the school belfast
# ' bastard his to sam even. ready
# 63 tensor(6.0872, grad_fn=<NllLossBackward0>)
# jumped troy * producers get do it exam
# will. keep four the we does that
# 64 tensor(5.7457, grad_fn=<NllLossBackward0>)
# the flash help love ity necessity.
# of the. something. the, the
# 65 tensor(6.6140, grad_fn=<NllLossBackward0>)
# .'saw form her toith `
# hairox - me her sea, he
# 66 tensor(6.6542, grad_fn=<NllLossBackward0>)
# to himself. festivals slade stuff gain i
# ##hh or have thea on engine for
# 67 tensor(7.4438, grad_fn=<NllLossBackward0>)
# foody th bedroom and'settle power
# to the made in,'was guard
# 68 tensor(6.6977, grad_fn=<NllLossBackward0>)
# one the food dakota him work know weeks
# lowering.trom cool which moment through felt
# 69 tensor(6.9650, grad_fn=<NllLossBackward0>)
# the to to but a clear super it
# and of back but detect my into -
# 70 tensor(6.5735, grad_fn=<NllLossBackward0>)
# bathroom the, no, sure. the
# love let family ` n with'the
# 71 tensor(6.2402, grad_fn=<NllLossBackward0>)
# of, could, my and ',
# her being one. spinning book had each
# 72 tensor(6.3849, grad_fn=<NllLossBackward0>)
# that the, was slammed youperson that
# the sc.ph waitedw other a
# 73 tensor(7.0323, grad_fn=<NllLossBackward0>)
# hands i that pretty.. be on
# her school way so upstairs n grateful better
# 74 tensor(6.1984, grad_fn=<NllLossBackward0>)
# ` slowly d a regardless sawline so
# and head s cute before not comes around
# 75 tensor(5.8463, grad_fn=<NllLossBackward0>)
# eve seem feel breath sirhar playful here
# . head know, ` more in sidewalk
# 76 tensor(5.9478, grad_fn=<NllLossBackward0>)
# sky, her sleep see on neo my
# ledge atkins power order, the while you
# 77 tensor(6.7355, grad_fn=<NllLossBackward0>)
# , if. released? something all them
# twitched time,iff. had appeared possible
# 78 tensor(6.3590, grad_fn=<NllLossBackward0>)
# ' sam the'to because of where
# t go `'felt went you point
# 79 tensor(6.0121, grad_fn=<NllLossBackward0>)
# they on best '. feel. day
# voice, have'out ` mercer him
# 80 tensor(5.8566, grad_fn=<NllLossBackward0>)
# think minutes get the call and flea in
# to that return. up and the he
# 81 tensor(7.0542, grad_fn=<NllLossBackward0>)
# ' that rep him perpetual it fingers and
# have michael abigail mind ` the you that
# 82 tensor(6.0908, grad_fn=<NllLossBackward0>)
# eye heection giving toblock learn galaxy
# , the we not. wasn sending enjoy
# 83 tensor(6.9919, grad_fn=<NllLossBackward0>)
# ' then time did living small, white
# to he own christy. snapped of '
# 84 tensor(6.7347, grad_fn=<NllLossBackward0>)
# number be relies'from good'she
# physically drop was'over nothing'`
# 85 tensor(5.6693, grad_fn=<NllLossBackward0>)
# ##d for raul s lincolnshire her my sorry
# metal je the to black loved to the
# 86 tensor(6.2857, grad_fn=<NllLossBackward0>)
# and felt t interviewed.hein whenily
# , history s has into it his,
# 87 tensor(6.5107, grad_fn=<NllLossBackward0>)
# ##end and going men'opposite n '
# '. light prey m. the m
# 88 tensor(5.8809, grad_fn=<NllLossBackward0>)
# you i wide spoke say'' his
# glancing'sound knees next't,
# 89 tensor(5.8677, grad_fn=<NllLossBackward0>)
# almost,'recognised t'be his
# really right that look ` she is with
# 90 tensor(5.4080, grad_fn=<NllLossBackward0>)
# but the to photos they'something few
# and type into mansion maybe so noting the
# 91 tensor(6.6908, grad_fn=<NllLossBackward0>)
# said king, been ` steaming a [unused661]
# then some is of, would actually land
# 92 tensor(7.0262, grad_fn=<NllLossBackward0>)
# house i and yes n,. the
# coins lucas they we how stepping unless.
# 93 tensor(6.7312, grad_fn=<NllLossBackward0>)
# sat woman taking come ; then of was
# of getting the, before the eyes.
# 94 tensor(6.7349, grad_fn=<NllLossBackward0>)
# inn yearsdlow them, all the of
# are toward'not ` nodded to a
# 95 tensor(6.3626, grad_fn=<NllLossBackward0>)
# - ` would family and and how here
# . do'it side jane'him
# 96 tensor(6.0935, grad_fn=<NllLossBackward0>)
# a saw she her monday was. a
# not said content stupid still you on i
# 97 tensor(5.7184, grad_fn=<NllLossBackward0>)
# ' i probably running of other went first
# rounded s attention. target he started n
# 98 tensor(6.6923, grad_fn=<NllLossBackward0>)
# he me responding skirmish she common venus every
# his thating fear.e if ears
# 99 tensor(6.8456, grad_fn=<NllLossBackward0>)
# tensor([1005, 3244, 2035, 2009, 2486, 2002, 1010, 1050])
# tensor([1005, 1029, 1050, 1037, 2235, 4600, 2055, 1010])
# tensor([7086, 2064, 1012, 7064, 7722, 2021, 2332, 3610])
# tensor([ 2007,  2000,  6148, 15818,  1012,  4025,  6682,  3945])
# tensor([3147, 3271, 1005, 2214, 1005, 2707, 7116, 3929])
# tensor([ 2211,  1996,  1005, 19146,  1055,  5112, 16661,  1029])
# tensor([ 2248,  2009,  2000,  2572,  4788, 16792,  2000,  1005])
# tensor([2431, 1010, 1005, 1010, 2069, 1010, 1010, 1012])
# tensor([10045,  1005,  2032,  1036,  2207,  1056,  3869,  1998])
# tensor([20322,  1005,  2115,  1036,  2019,  2002,  1999,  2009])
# tensor([ 1045,  1005,  1045,  2524,  1998, 30101,  2015,  2026])
# tensor([1010, 1005, 1005, 2013, 2437, 3102, 3043, 1996])
# tensor([ 2016,  1012,  6510,  1036,  2106, 25677,  2061,  2000])
# tensor([ 3108,  2157,  2016,  2054,  2027,  2881,  2002, 15660])
# tensor([1037, 1996, 4366, 2598, 2607, 4911, 1005, 2126])
# tensor([5578, 3345, 2751, 2000, 1012, 3310, 1055, 4016])
# tensor([ 3663,  2085,  2008, 15527, 29132,  1996,  8555,  2617])
# tensor([ 5127,  1996,  1010,  1012,  2000,  1997, 20552,  1029])
# tensor([10749,  1005,  1050,  3044,  2002,  1036,  2014,  2079])
# tensor([5899, 1005, 2001, 1996, 2021, 2007, 2190, 2464])
# Loss at step = 100 for train data is 0.3152 for val it is 0.3045
# hard will? and road n'other
# share becomes have and through! and laptop
# 100 tensor(6.7694, grad_fn=<NllLossBackward0>)
# .'there ` really'' the
# him a both oh he n t,
# 101 tensor(6.3679, grad_fn=<NllLossBackward0>)
# away lebanon to vocabulary sure. footprints its
# believe suttonbbed thick.'is the
# 102 tensor(6.4518, grad_fn=<NllLossBackward0>)
# vent you fat had ` my rest
# ` choose why frustrating getting well the figure
# 103 tensor(6.0735, grad_fn=<NllLossBackward0>)
# ##glers. word, sam life as '
# but facing around away good. an down
# 104 tensor(6.3698, grad_fn=<NllLossBackward0>)
# a much give so phone?. heaved
# irritation to, a business the i?
# 105 tensor(5.9776, grad_fn=<NllLossBackward0>)
# he but we bang continuing'i democracy
# comb needed shawn her'''brushed
# 106 tensor(6.0187, grad_fn=<NllLossBackward0>)
# i you'' to of mornings,
# to mikhail fucking smile thinking that much '
# 107 tensor(5.7063, grad_fn=<NllLossBackward0>)
# hand.'as but it all of
# wholey ', robes `. and
# 108 tensor(5.9419, grad_fn=<NllLossBackward0>)
# like you diagonal face anything let up n
# ! lush main collection the do a i
# 109 tensor(6.8981, grad_fn=<NllLossBackward0>)
# for '. as t ve long across
# time'does eyes'` iv
# 110 tensor(5.9298, grad_fn=<NllLossBackward0>)
# strength'ty'felt whatever glanced george
# .'though i'better t from
# 111 tensor(6.1291, grad_fn=<NllLossBackward0>)
# bed scene.'focus, open most
# . to he s some, to you
# 112 tensor(6.0259, grad_fn=<NllLossBackward0>)
# and the permit provide electrical over as realize
# the'a. job her republic s
# 113 tensor(5.9645, grad_fn=<NllLossBackward0>)
# had her thinking marshall'head, `
# ,'expression ` ` harleyre you
# 114 tensor(5.8920, grad_fn=<NllLossBackward0>)
# more and rage inconsistent at. books,
# i voice as why guilt fine out `
# 115 tensor(6.5257, grad_fn=<NllLossBackward0>)
# hear good i.. before binoculars humor
# this up then find shelves my my various
# 116 tensor(5.8466, grad_fn=<NllLossBackward0>)
# there n with afraid to thebner me
# knowledge her ja very danger'want i
# 117 tensor(6.0541, grad_fn=<NllLossBackward0>)
# heat she you to at childhood was the
# faa he their implying exam papers their
# 118 tensor(6.6854, grad_fn=<NllLossBackward0>)
# coins seemed this that without stop did `
# velvet it'he.. t '
# 119 tensor(5.7375, grad_fn=<NllLossBackward0>)
# years this i you to betterr going
# head you meda fast open had.
# 120 tensor(5.9002, grad_fn=<NllLossBackward0>)
# gentle the! things popping simplicity. out
# slice i oh ` only my me like
# 121 tensor(6.6121, grad_fn=<NllLossBackward0>)
# fear you as business the large in to
# ##ned the und the. whole of yes
# 122 tensor(6.4544, grad_fn=<NllLossBackward0>)
# , fine ex'door'did those
# said., s happy'i,
# 123 tensor(5.4752, grad_fn=<NllLossBackward0>)
# melovic, maybe instead the for that
# the, problem ` ronan a knewy
# 124 tensor(6.4565, grad_fn=<NllLossBackward0>)
# seat, staff on joke while as the
# ##k bent station did. sad met as
# 125 tensor(6.0477, grad_fn=<NllLossBackward0>)
# con telling with vamp 'ciful. desire
# a sound the lets i guesscha if
# 126 tensor(6.5018, grad_fn=<NllLossBackward0>)
# view, there played.d. to
# storm smarter should to sense what stroked maria
# 127 tensor(5.8469, grad_fn=<NllLossBackward0>)
# to feel you do her. wings should
# in cheek the wouldn death not thumb fever
# 128 tensor(6.4814, grad_fn=<NllLossBackward0>)
# the. right vol i downward you s
# if me belly of ` his in `
# 129 tensor(5.6479, grad_fn=<NllLossBackward0>)
# that the shoved. and as of standing
# of the questioned,'said road conversation
# 130 tensor(5.7948, grad_fn=<NllLossBackward0>)
# miss you or next all the concerned how
# five to her'juliahn, i
# 131 tensor(6.1877, grad_fn=<NllLossBackward0>)
# ' beth shu, she was ` karl
# to issue neck efforts love was'respond
# 132 tensor(5.6132, grad_fn=<NllLossBackward0>)
# genie, told voice as nered,
# their.. swans doing in of just
# 133 tensor(6.4959, grad_fn=<NllLossBackward0>)
# s'fairly all his me,.
# d to and ` his, barbara was
# 134 tensor(6.2804, grad_fn=<NllLossBackward0>)
# she wednesday t the ` do asked un
# . been befores, down im.
# 135 tensor(6.6112, grad_fn=<NllLossBackward0>)
# so anguish `'are teaching 1850.
# some there the her had, very mist
# 136 tensor(5.8304, grad_fn=<NllLossBackward0>)
# me clearly other grange if demanded and warm
# . on bean, t do ` she
# 137 tensor(5.5942, grad_fn=<NllLossBackward0>)
# so, ` in been i questions the
# s jp'stead gently him was at
# 138 tensor(5.7655, grad_fn=<NllLossBackward0>)
# expert around going that why thumbs ty the
# arms. wash you ago front blanket shredded
# 139 tensor(6.8797, grad_fn=<NllLossBackward0>)
# d. for time behind,'precisely
# she at by they in,, head
# 140 tensor(5.9422, grad_fn=<NllLossBackward0>)
# afraid hit they 110, we ` '
# her scarlet she n scared him isaac s
# 141 tensor(5.8213, grad_fn=<NllLossBackward0>)
# were'why taken across in gambiasso
# give s ke big that of confused,
# 142 tensor(6.0389, grad_fn=<NllLossBackward0>)
# ones spoken i tel hopemmel, s
# blood leslie and they listening golden this something
# 143 tensor(6.7143, grad_fn=<NllLossBackward0>)
# und determination i simply my gloss ve,
# than is yes he went that'in
# 144 tensor(6.2352, grad_fn=<NllLossBackward0>)
# ` coffee over., until, a
# some ` working out a every? whatever
# 145 tensor(5.8567, grad_fn=<NllLossBackward0>)
# by allow anything drummond ` panic'discussion
# from place the called like by ` hand
# 146 tensor(5.8885, grad_fn=<NllLossBackward0>)
# a ` only should they d back lose
# widened then our why my d in a
# 147 tensor(5.8306, grad_fn=<NllLossBackward0>)
# a small'manage tiffany handful were `
# onqui'chocolate waist with meanwhile mach
# 148 tensor(6.4687, grad_fn=<NllLossBackward0>)
# giveᆨ? kill with ages thisest
# her.. right. the..
# 149 tensor(5.7393, grad_fn=<NllLossBackward0>)
# but. until told quietly winning headed '
# thersa do support saw wanted unconscious but
# 150 tensor(6.2988, grad_fn=<NllLossBackward0>)
# stated from it strewn alexander carg.
# ! do one time be said it quinn
# 151 tensor(5.8519, grad_fn=<NllLossBackward0>)
# ##ing, the her was'until?
# of eye sasin slipped reluctantly stood and
# 152 tensor(6.6367, grad_fn=<NllLossBackward0>)
# anyone at the a by repeated a,
# into the and dimension was in wore him
# 153 tensor(6.6498, grad_fn=<NllLossBackward0>)
# ##eurs for emma clothes post'the vo
# ' me. outmana. clothes about
# 154 tensor(5.8315, grad_fn=<NllLossBackward0>)
# if two drew, it seen a were
# any she graceful mel what was aity
# 155 tensor(6.5153, grad_fn=<NllLossBackward0>)
# been at couch leaving something someone you her
# without hates thick words there. wasve
# 156 tensor(6.4387, grad_fn=<NllLossBackward0>)
# of. connection ` was the i the
# ,. one i. breathing it want
# 157 tensor(5.8833, grad_fn=<NllLossBackward0>)
# . and or n. ` much before
# ##ers whichever but the'bridge almost been
# 158 tensor(6.1716, grad_fn=<NllLossBackward0>)
# halt led shout touch to status one no
# it next bad had was know another we
# 159 tensor(6.6082, grad_fn=<NllLossBackward0>)
# crowley that on, felt lucius now in
# ran next have, and mothers was enough
# 160 tensor(6.3630, grad_fn=<NllLossBackward0>)
# i his silk the in if i 公
# at j aiden in - she everyone '
# 161 tensor(6.0632, grad_fn=<NllLossBackward0>)
# just companions it and maternity drove you pressing
# ., and let'diamonds with.
# 162 tensor(5.6878, grad_fn=<NllLossBackward0>)
# with t one the. seeing discovered.
# . s coal her make '.eti
# 163 tensor(6.3055, grad_fn=<NllLossBackward0>)
# the man s get time this looking put
# ' acts ` `. abigail of was
# 164 tensor(5.9555, grad_fn=<NllLossBackward0>)
# statute here gotten, ative of right
# was small you there any kitchen and bright
# 165 tensor(6.3126, grad_fn=<NllLossBackward0>)
# from her tonesspre had out his
# , the her n no had her third
# 166 tensor(6.0070, grad_fn=<NllLossBackward0>)
# ? hope included they sts wrapped'assert
# * `, we and call is -
# 167 tensor(5.9616, grad_fn=<NllLossBackward0>)
# , still ignition than ways was oh its
# of jim new'official are clothes all
# 168 tensor(6.7269, grad_fn=<NllLossBackward0>)
# butch at herming of touched he.
# he by. im comfortably capable beck of
# 169 tensor(6.5762, grad_fn=<NllLossBackward0>)
# n poisonrin `, you'nature
# been actedns `, i produce be
# 170 tensor(6.1330, grad_fn=<NllLossBackward0>)
# yeah chance, ion this circling.
# re s, t, said. his
# 171 tensor(5.5598, grad_fn=<NllLossBackward0>)
# seven ca'for'to quietly '
# are. are see death of away s
# 172 tensor(5.5018, grad_fn=<NllLossBackward0>)
# so'n downma you. realized
# he i sexy. ` i me his
# 173 tensor(5.4325, grad_fn=<NllLossBackward0>)
# . confused n t ` more.clave
# been into you d de her. him
# 174 tensor(5.6866, grad_fn=<NllLossBackward0>)
# you his n her iting - d
# wait little great a consumedru, micah
# 175 tensor(6.3000, grad_fn=<NllLossBackward0>)
# tred! is repair flex you else
# ' the done only, scoffed climbed -
# 176 tensor(5.6390, grad_fn=<NllLossBackward0>)
# do cried on that beautiful,fu the
# lot them me struggled her else his love
# 177 tensor(6.1659, grad_fn=<NllLossBackward0>)
# d and'' eyes ringing the,
# t held can could lips he while dragged
# 178 tensor(5.5921, grad_fn=<NllLossBackward0>)
# crowd t crusader we lackedt more,
# way'blade no ba out through.
# 179 tensor(6.1555, grad_fn=<NllLossBackward0>)
# occurs18 derek say do he whyt
# crazy they nodded their pulled ne one to
# 180 tensor(6.1828, grad_fn=<NllLossBackward0>)
# cave same in he him first it t
# few eyes - time throw sl and '
# 181 tensor(6.2582, grad_fn=<NllLossBackward0>)
# ,med which at cold thetower bastard
# for definitely those into anyone faint her `
# 182 tensor(6.1663, grad_fn=<NllLossBackward0>)
# texted, father poor. same. feel
# twigs, e had creep supposedly i pic
# 183 tensor(6.9304, grad_fn=<NllLossBackward0>)
# my obvious seen ɔ someone in heard i
# the listening in doing, disconnected honestly but
# 184 tensor(6.2251, grad_fn=<NllLossBackward0>)
# ₇ inside not were do further, a
# face anothert and position colours of close
# 185 tensor(6.9366, grad_fn=<NllLossBackward0>)
# truck symptoms was still * been ` up
# were red up a acknowledged time'her
# 186 tensor(5.7840, grad_fn=<NllLossBackward0>)
# doing to sends?s. you,
# my! to. theer'squeak
# 187 tensor(6.3538, grad_fn=<NllLossBackward0>)
# - her ` rapidlyt ` i?
# sounding each how bland. but this beyond
# 188 tensor(6.0084, grad_fn=<NllLossBackward0>)
# of around first said but s one
# a fear,.? s. f
# 189 tensor(5.9052, grad_fn=<NllLossBackward0>)
# ...hell ville ` furthertis
# , myselfing fist in'to up
# 190 tensor(5.5529, grad_fn=<NllLossBackward0>)
# smaller as stay a when 龍. again
# bridge looking. always allows winter blush,
# 191 tensor(6.7818, grad_fn=<NllLossBackward0>)
# but and me one she of n it
# eyes then away.'to exactly my
# 192 tensor(5.3417, grad_fn=<NllLossBackward0>)
# black t ` by foil pry travel im
# was'' that. sides said like
# 193 tensor(5.8550, grad_fn=<NllLossBackward0>)
# our adorned but later'ultrasound, but
# a easily god'they stranger mirror and
# 194 tensor(6.2071, grad_fn=<NllLossBackward0>)
# and her to him house though, '
# joking bear ali shadows youdur a entered
# 195 tensor(6.3606, grad_fn=<NllLossBackward0>)
# let not to grin feeling afterer must
# those to. station and if, and
# 196 tensor(6.0836, grad_fn=<NllLossBackward0>)
# and going shiver. out ofcal road
# sir world his and good. waited twisted
# 197 tensor(6.6033, grad_fn=<NllLossBackward0>)
# he two ` se? soerted was
# ` master word legitimate between solid him got
# 198 tensor(6.3047, grad_fn=<NllLossBackward0>)
# re this and n in him dark.
# t to the pouring raped and tpa
# 199 tensor(6.0239, grad_fn=<NllLossBackward0>)
# tensor([ 2008, 18531,  1005,  2012,  1996,  4283,  1012,  1055])
# tensor([1037, 1996, 2002, 2017, 2425, 2001, 1012, 1005])
# tensor([4283, 2046, 5251, 1012, 2115, 1012, 2247, 1005])
# tensor([2009, 2085, 2879, 1010, 2007, 1012, 1996, 1005])
# tensor([ 9686,  2801,  1005,  1997,  3773, 12021,  2098,  3773])
# tensor([ 1012,  2674,  1045,  7826, 12762,  2002,  1996,  1005])
# tensor([ 3606,  1012,  1012,  2000,  2056, 23883,  1010,  2021])
# tensor([2022, 2061, 1029, 6471, 3184, 5472, 1029, 2165])
# tensor([2376, 4137, 4427, 2001, 2502, 2020, 1996, 2004])
# tensor([ 2183,  2000, 12259,  2253,  2438,  2293,  1049,  2514])
# Invalid key: 741 is out of bounds for size 741
# someonerm box '. time ` would
# ittor smell'the moment they must
# 201 tensor(6.1717, grad_fn=<NllLossBackward0>)
# had - both the he sunrise to even
# inve. get ill lo above clive
# 202 tensor(6.6346, grad_fn=<NllLossBackward0>)
# the. nodded might everyone i ga t
# long done the. to it''
# 203 tensor(6.5471, grad_fn=<NllLossBackward0>)
# would more s `'land over the
# holmes. ` ` ` and, hell
# 204 tensor(5.5667, grad_fn=<NllLossBackward0>)
# last sideways verge doors art only `r
# in to in, ` was have its
# 205 tensor(5.7491, grad_fn=<NllLossBackward0>)
# he voice had side. coa this stuck
# , head, herbs is king n taxis
# 206 tensor(5.7133, grad_fn=<NllLossBackward0>)
# did in meant the over like hat the
# up teeth a, to, this my
# 207 tensor(5.7115, grad_fn=<NllLossBackward0>)
# ` opens of in those is away re
# what teammates there'of words again '
# 208 tensor(5.3736, grad_fn=<NllLossBackward0>)
# , find. can she. n of
# ara do stared besides of say two
# 209 tensor(6.3914, grad_fn=<NllLossBackward0>)
# , ` over i, in ground curls
# in lo so i never black stream eyes
# 210 tensor(6.2968, grad_fn=<NllLossBackward0>)
# i'softly shoot ah big slap?
# you 'nsation'about anything like
# 211 tensor(5.8968, grad_fn=<NllLossBackward0>)
# kade to to scrolls scott i then spectacle
# should my. whicheli'people shriek
# 212 tensor(6.1046, grad_fn=<NllLossBackward0>)
# s boats her have cold i went `
# s never of be to, pick `
# 213 tensor(5.5136, grad_fn=<NllLossBackward0>)
# going and innocent would displaying respond there was
# to aff was needed their they anyway
# 214 tensor(6.4778, grad_fn=<NllLossBackward0>)
# can colton'not that t it not
# swore mill 4?. re olds he
# 215 tensor(5.7562, grad_fn=<NllLossBackward0>)
# wearing kings a perhaps anyone no. though
# walked battle our towards that so, and
# 216 tensor(6.5676, grad_fn=<NllLossBackward0>)
# s connecticut at at'look my needed
# ` a, wrong me teeth to wrapped
# 217 tensor(5.5730, grad_fn=<NllLossBackward0>)
# she who he pulled just forgotten palm anyone
# on my'enters.'plans had
# 218 tensor(5.6874, grad_fn=<NllLossBackward0>)
# the of someone calling of'beneath did
# the only at food he'the knew
# 219 tensor(6.3896, grad_fn=<NllLossBackward0>)
# `'on ` from in hurt '
# ` s lifted theseny the how were
# 220 tensor(5.6367, grad_fn=<NllLossBackward0>)
# ',. the through, when then
# could, otter the too wai it jack
# 221 tensor(6.2828, grad_fn=<NllLossBackward0>)
# were, right.'third of my
# minutes so to? iten to drifting
# 222 tensor(6.1889, grad_fn=<NllLossBackward0>)
# for'me your athens s describe.
# who'table needles plan t lingered,
# 223 tensor(6.6821, grad_fn=<NllLossBackward0>)
# offense alien not what overhaul of sky board
# ##rate far, ` men eat around beast
# 224 tensor(6.1360, grad_fn=<NllLossBackward0>)
# okay'senator - `'he meeting
# like nice wolves ` there it i.
# 225 tensor(5.3659, grad_fn=<NllLossBackward0>)
# say think n meantt womenp?
# loved.'turning. hardness moon i
# 226 tensor(5.5163, grad_fn=<NllLossBackward0>)
# ' the of a, as tugging os
# ' sure.,.. it `
# 227 tensor(6.0573, grad_fn=<NllLossBackward0>)
# , ve over d,ing. t
# ##ding i i i with. we ignored
# 228 tensor(5.4804, grad_fn=<NllLossBackward0>)
# . but it will and 86. '
# him a rain, corrected heady m
# 229 tensor(5.5377, grad_fn=<NllLossBackward0>)
# all and fan shook definitely his and even
# pace sur outsider. vista fasteroids a
# 230 tensor(6.6681, grad_fn=<NllLossBackward0>)
# to ` to absence to ` bag what
# really the to head tingle ` would `
# 231 tensor(5.7624, grad_fn=<NllLossBackward0>)
# grunt. could, onι road much
# sword time was were wallshend mini glanced
# 232 tensor(6.4256, grad_fn=<NllLossBackward0>)
# 'lb breathoms if. it my
# theyldon ` on quiet it we for
# 233 tensor(5.8733, grad_fn=<NllLossBackward0>)
# suspicion,'the had and andaka
# slightly'', wrestled he son.
# 234 tensor(6.5839, grad_fn=<NllLossBackward0>)
# they he ready showed is their like man
# ready is illustrations, hear'so prize
# 235 tensor(6.1696, grad_fn=<NllLossBackward0>)
# him she up. soft this ta n
# a hadn did aboutpour, said of
# 236 tensor(6.0292, grad_fn=<NllLossBackward0>)
# he.s may in ` pen '
# i up against placed we travelling better celia
# 237 tensor(6.2616, grad_fn=<NllLossBackward0>)
# ledge like `, you himself trees '
# kid cameron ` to activated re ` at
# 238 tensor(5.9665, grad_fn=<NllLossBackward0>)
# ' e but both fast'' could
# , chest'ready to her, lifted
# 239 tensor(5.8704, grad_fn=<NllLossBackward0>)
# of my you, event wall of war
# for. ` again never emotion of.
# 240 tensor(5.1878, grad_fn=<NllLossBackward0>)
# ve she and the did has when offer
# s scream he he had generator that had
# 241 tensor(6.7233, grad_fn=<NllLossBackward0>)
# ., exciting this would him the so
# than my gerard obtain her of her night
# 242 tensor(5.6235, grad_fn=<NllLossBackward0>)
# ##light then but rover to xii. care
# . the ` was. to she the
# 243 tensor(5.4795, grad_fn=<NllLossBackward0>)
# it at. plates n did we he
# aside let! alone so doubted he ethan
# 244 tensor(5.6924, grad_fn=<NllLossBackward0>)
# that. if in to over'a
# moved. much, or course s needing
# 245 tensor(5.5954, grad_fn=<NllLossBackward0>)
# should. he. the. to at
# notlen, legs fresh. my.
# 246 tensor(6.4077, grad_fn=<NllLossBackward0>)
# ?w you someone ` the them thing
# who by ` you and trailed other hands
# 247 tensor(5.3543, grad_fn=<NllLossBackward0>)
# ##lings. research dream become arrested there coaching
# assure up whispered the no of lurking was
# 248 tensor(6.7296, grad_fn=<NllLossBackward0>)
# substitute to ` could the burke her enjoying
# `, ` was tell life must the
# 249 tensor(5.1543, grad_fn=<NllLossBackward0>)
# voice up. it was perform on inside
# to they or all held ear,.
# 250 tensor(5.2561, grad_fn=<NllLossBackward0>)
# by our ` natalie placed. as.
# . shutoss him,30 he very
# 251 tensor(5.8056, grad_fn=<NllLossBackward0>)
# s the to but was an with `
# d x. she ` steam ended the
# 252 tensor(6.0155, grad_fn=<NllLossBackward0>)
# t stuff think. where'the her
# d ` na,, you catch
# 253 tensor(5.6631, grad_fn=<NllLossBackward0>)
# swollen'` be ni, detective `
# n. heaven become voice, course `
# 254 tensor(5.7828, grad_fn=<NllLossBackward0>)
# , giving of have going just head.
# for, i said, d for we
# 255 tensor(5.9119, grad_fn=<NllLossBackward0>)
# ##e than clothes. a d are and
# though you lounge to runs t ago robb
# 256 tensor(6.0435, grad_fn=<NllLossBackward0>)
# ' have'my'had hereeme
# `t ` why ` asked thomas to
# 257 tensor(6.4250, grad_fn=<NllLossBackward0>)
# like * became itssc through slightly.
# she'around ` only had headed sara
# 258 tensor(5.2069, grad_fn=<NllLossBackward0>)
# tally.. `,? of three
# off children information ` as thislit less
# 259 tensor(6.2735, grad_fn=<NllLossBackward0>)
# the you fit them one speaking snarled he
# s now'his them the'`
# 260 tensor(5.7727, grad_fn=<NllLossBackward0>)
# ... he'war you.
# , only to like 'en of.
# 261 tensor(5.7420, grad_fn=<NllLossBackward0>)
# to.pedt in born, all
# hungry questions wanted to, enthusiasm you hands
# 262 tensor(6.3489, grad_fn=<NllLossBackward0>)
# at not, you that..pl
# `, had what them andeak vampires
# 263 tensor(5.5723, grad_fn=<NllLossBackward0>)
# over, green corners ` maneuvers ` `
# hands was my any a ` fear `
# 264 tensor(5.9527, grad_fn=<NllLossBackward0>)
# itado llntly smirkudence quiet '
# it that answered at he do. could
# 265 tensor(5.3419, grad_fn=<NllLossBackward0>)
# be. there her on fromries love
# disturb. dimensions cash. legs. mrs
# 266 tensor(5.7119, grad_fn=<NllLossBackward0>)
# night was - away ran concacaf ttion
# hair made, jealous andt'heart
# 267 tensor(5.5794, grad_fn=<NllLossBackward0>)
# had in not pressed. excuse turn and
# read. steel were, - come.
# 268 tensor(6.2348, grad_fn=<NllLossBackward0>)
# precisely propagation when '. watched up melancholy
# to bitter. bo of do day did
# 269 tensor(5.7371, grad_fn=<NllLossBackward0>)
# . then no the to n n,
# but the sure or things n i and
# 270 tensor(5.3064, grad_fn=<NllLossBackward0>)
# ' walks need no, anything best re
# fingered floor dance him going get mind '
# 271 tensor(5.1735, grad_fn=<NllLossBackward0>)
# from n proved for. had'was
# cleanup from. and and, these remembers
# 272 tensor(6.2852, grad_fn=<NllLossBackward0>)
# she - deep friend syy world they
# hissed the mom backbbing f friend is
# 273 tensor(5.3225, grad_fn=<NllLossBackward0>)
# the but tomorrow afraid her taste of,
# , it for. child?. really
# 274 tensor(6.0726, grad_fn=<NllLossBackward0>)
# those my `s she. ` was
# probably remain i to ` to ` you
# 275 tensor(5.7163, grad_fn=<NllLossBackward0>)
# ##ister what dickffi a and of n
# only ` face camera foundrac of get
# 276 tensor(5.7027, grad_fn=<NllLossBackward0>)
# rogue'skills in and ask each sustainability
# ##ur patricia a bedroom frustrated the bas n
# 277 tensor(6.3985, grad_fn=<NllLossBackward0>)
# it ` p see ken determined. fit
# ` ` conventional'things my been myself
# 278 tensor(5.2367, grad_fn=<NllLossBackward0>)
# thinking time dc back, ` ` `
# with er by armsled they'well
# 279 tensor(5.7708, grad_fn=<NllLossBackward0>)
# , as walnut deal of of been few
# privately then kitchen cl,.. visitor
# 280 tensor(6.1140, grad_fn=<NllLossBackward0>)
# to leigh missed duncan she suffer that to
# servant saddle mistake had beth water imagine followed
# 281 tensor(6.3250, grad_fn=<NllLossBackward0>)
# this until in knew three lips remember man
# - the till would off her walked i
# 282 tensor(6.3346, grad_fn=<NllLossBackward0>)
# . herself at are no to t of
# za knew for well i my again,
# 283 tensor(5.3538, grad_fn=<NllLossBackward0>)
# back also lock. twitched is them forcing
# - machine little. the in police alleged
# 284 tensor(6.1866, grad_fn=<NllLossBackward0>)
# , a and.'` grew -
# . the himvered'king privately was
# 285 tensor(5.6428, grad_fn=<NllLossBackward0>)
# now to, discover in, the he
# ` on onto of his. the ve
# 286 tensor(5.3618, grad_fn=<NllLossBackward0>)
# ', the'learned. morely
# m between up'this the ised
# 287 tensor(5.7277, grad_fn=<NllLossBackward0>)
# i on'amazing would. s fall
# ' handsome blazed young got without'are
# 288 tensor(5.8890, grad_fn=<NllLossBackward0>)
# kingdom thought did of must house as it
# man need the her past anatr off
# 289 tensor(5.9306, grad_fn=<NllLossBackward0>)
# meant month like ワ jealousy with and.
# learn no, ladder warmth - rec,
# 290 tensor(6.3132, grad_fn=<NllLossBackward0>)
# don assisted room thorns my air archer fuck
# herillae even on rightero at
# 291 tensor(6.1893, grad_fn=<NllLossBackward0>)
# have'first of up his kind n
# rain if. part end pest goes n
# 292 tensor(5.8315, grad_fn=<NllLossBackward0>)
# she asked bonnet a'project ` has
# called it wes can us i wants
# 293 tensor(6.1644, grad_fn=<NllLossBackward0>)
# or any t served and let stared i
# ` shut ` nonstop lucy still''
# 294 tensor(5.5674, grad_fn=<NllLossBackward0>)
# pulled theously why door the bet proud
# open curious,uh bag the corpse argument
# 295 tensor(5.7543, grad_fn=<NllLossBackward0>)
# arms niceole brilliant began been offers who
# hair carefully put void in his cheering i
# 296 tensor(5.8361, grad_fn=<NllLossBackward0>)
# equally i car meek, of,.
# on, shit and they. with of
# 297 tensor(5.7553, grad_fn=<NllLossBackward0>)
# following he gathered and thank, around deep
# seat the,? of. or tremendous
# 298 tensor(6.3433, grad_fn=<NllLossBackward0>)
# ' asset ` some ` ago,,
# do random some wink ` him pl,
# 299 tensor(5.4814, grad_fn=<NllLossBackward0>)
# tensor([ 1012,  2132, 25102,  1012,  2482,  1997,  3366,  2435])
# tensor([2123, 5025, 2448, 1012, 3827, 1010, 2000, 1012])
# tensor([6417, 1998, 2129, 1012, 1012, 3891, 2191, 2026])
# tensor([10850,  1010,  1045,  2024,  1012,  2010,  2001,  2012])
# tensor([1005, 1012, 2222, 2000, 1011, 1005, 1036, 6167])
# tensor([ 1005, 12635,  1036,  2438,  2055,  1005,  1005,  9220])
# tensor([ 2227,  2014, 21146, 13675,  2155,  2052,  5466,  2292])
# tensor([ 5723,  1012,  2015,  1010,  2386,  2001,  2409, 16220])
# tensor([1005, 2292, 2282, 2067, 1036, 1996, 2102, 6802])
# tensor([25265,  2026, 16232,  3528,  1036,  1997,  9700,  2017])
# tensor([14961,  2106,  2017,  1012,  2938,  1012,  1012,  1036])
# tensor([2017, 1997, 2182, 2009, 2354, 1011, 2016, 2821])
# tensor([1005, 2000, 1036, 5820, 1010, 2027, 1055, 1005])
# tensor([7078, 2000, 2024, 2001, 2001, 1997, 2002, 1005])
# tensor([7618, 4826, 1036, 4627, 2054, 6854, 1029, 1010])
# tensor([ 1996,  2593,  1996,  1005,  1037,  2518, 11585,  2261])
# tensor([ 2222,  2001,  2107, 28616,  2031,  1998,  1005,  1005])
# tensor([ 1040,  2938,  2884, 21737, 10107,  1045,  2032,  1005])
# tensor([2017, 6046, 1996, 1012, 3657, 7343, 1030, 2039])
# tensor([ 2058,  2395,  9906,  3244, 14213,  1998, 10345,  1998])
# Loss at step = 300 for train data is 0.2925 for val it is 0.2801
# ##xton i and `'show. squealed
# n downward. want is inside you solid
# 300 tensor(5.8957, grad_fn=<NllLossBackward0>)
# witnesses in got word mel the when '
# asks. wrong fingers school time did saw
# 301 tensor(5.8208, grad_fn=<NllLossBackward0>)
# tonight going, she,dable lock it
# youth the on he many that mat agreeing
# 302 tensor(6.5396, grad_fn=<NllLossBackward0>)
# i she joe when'hit clapped hurt
# about of that he said, my dangerous
# 303 tensor(6.4387, grad_fn=<NllLossBackward0>)
# kyle'vain some effort'thumb chao
# creatures't book governors, re its
# 304 tensor(6.6245, grad_fn=<NllLossBackward0>)
# in tip a me. zach the '
# the and with'belonged. behind jamie
# 305 tensor(5.6665, grad_fn=<NllLossBackward0>)
# .. sea shows plate let would was
# i elle, besides be need okay,
# 306 tensor(5.6242, grad_fn=<NllLossBackward0>)
# a n. special mrs, ` bring
# several n ofly they her ` a
# 307 tensor(6.1915, grad_fn=<NllLossBackward0>)
# ; guy. their we,.,
# gun and she unsure make.ham.
# 308 tensor(6.5072, grad_fn=<NllLossBackward0>)
# problem,, anywhere mine butt greek,
# on. comingshoo father map.
# 309 tensor(5.3851, grad_fn=<NllLossBackward0>)
# in best pointed.'he that need
# to. was portion had sle stood
# 310 tensor(5.7427, grad_fn=<NllLossBackward0>)
# `rina you i before i blew met
# `,. myave though can `
# 311 tensor(5.4458, grad_fn=<NllLossBackward0>)
# i to ` n was until, herself
# me genius his breathing thank toni up
# 312 tensor(5.9446, grad_fn=<NllLossBackward0>)
# trouble from'have under musts.
# prism n either drawn ` have. you
# 313 tensor(5.7357, grad_fn=<NllLossBackward0>)
# heard at are n.. in her
# felt and closedeli he. she very
# 314 tensor(6.4069, grad_fn=<NllLossBackward0>)
# that need having mystery right cassidy her saw
# and said a that look problem easily felt
# 315 tensor(6.5293, grad_fn=<NllLossBackward0>)
# ##les escape to sam conscience anguspping and
# that was sure. villages returning caught '
# 316 tensor(6.3768, grad_fn=<NllLossBackward0>)
# temple athot before said? beer have
# ze under suddenly but mind. - said
# 317 tensor(6.2874, grad_fn=<NllLossBackward0>)
# i they a and needed in. left
# he s silence questioning could he wondering corner
# 318 tensor(5.6047, grad_fn=<NllLossBackward0>)
# only? i no andrim her time
# , he sometimes ` oh how boy figure
# 319 tensor(5.7129, grad_fn=<NllLossBackward0>)
# the.. steps the the ve here
# from under duty you, near'near
# 320 tensor(6.2139, grad_fn=<NllLossBackward0>)
# i from the day merrill freaking as to
# she except'him ground are him jealous
# 321 tensor(5.9081, grad_fn=<NllLossBackward0>)
# ##os he judgement an holding ` way across
# more the would either people a very that
# 322 tensor(6.1748, grad_fn=<NllLossBackward0>)
# was mature `? like invited coin ease
# did murderer and of companies. was.
# 323 tensor(6.1615, grad_fn=<NllLossBackward0>)
# ata believe of s be in light she
# they been through t would twenty. was
# 324 tensor(5.6489, grad_fn=<NllLossBackward0>)
# this'ars as'it. va
# that was he said ` two me that
# 325 tensor(5.5095, grad_fn=<NllLossBackward0>)
# the some the, his family brown yes
# . and were to name., i
# 326 tensor(6.6826, grad_fn=<NllLossBackward0>)
# . looked handed me that judas slip were
# water was, promised was front short were
# 327 tensor(6.2985, grad_fn=<NllLossBackward0>)
# the clip her his in got turn sign
# would. to to crush felt down a
# 328 tensor(6.1506, grad_fn=<NllLossBackward0>)
# him re him. i quite merial
# the ll., could stabbed wrath be
# 329 tensor(5.7383, grad_fn=<NllLossBackward0>)
# his working wasn 2 we place the the
# she! said in door place cr test
# 330 tensor(5.8890, grad_fn=<NllLossBackward0>)
# expected hisyr my ` glimpse the '
# ##t fin considering climb'your im '
# 331 tensor(5.9470, grad_fn=<NllLossBackward0>)
# ?. very such `.'the
# , saying kiss courtyard thank to `.
# 332 tensor(5.0218, grad_fn=<NllLossBackward0>)
# ##ima -uche?.table hauling me
# ##ter to he! the to'and
# 333 tensor(5.4927, grad_fn=<NllLossBackward0>)
# ' this i tonight the green my i
# was wall why bike nearby mouths some except
# 334 tensor(5.6898, grad_fn=<NllLossBackward0>)
# wasving stripring act. reading eight
# ,! through had wasant hardlyes
# 335 tensor(6.1701, grad_fn=<NllLossBackward0>)
# thick thinks. and jackson they sawve
# his to '. decide an moved,
# 336 tensor(5.8878, grad_fn=<NllLossBackward0>)
# . i still chapter on ` fought some
# be'realized - and `. a
# 337 tensor(5.6673, grad_fn=<NllLossBackward0>)
# your 幸 anxiety my. closer and.
# , but heart. night, a to
# 338 tensor(5.2769, grad_fn=<NllLossBackward0>)
# eyes he ve could surprised wanted, t
# place by i was and'to d
# 339 tensor(5.3341, grad_fn=<NllLossBackward0>)
# where. as'her coulded hopes
# too in? tilted she kind a plan
# 340 tensor(5.6894, grad_fn=<NllLossBackward0>)
# do last the she guy and chest,
# what street to not table. to.
# 341 tensor(6.2031, grad_fn=<NllLossBackward0>)
# ' him fair needed. n you?
# was having that paused must really knocking on
# 342 tensor(6.2964, grad_fn=<NllLossBackward0>)
# . on there of settled about here keys
# new dia so her turn because everyone window
# 343 tensor(5.4198, grad_fn=<NllLossBackward0>)
# innocent will her at to client she t
# he hands i the.. she re
# 344 tensor(5.9277, grad_fn=<NllLossBackward0>)
# anger was'of here hears it a
# all had conversation. you confusion if feet
# 345 tensor(6.3084, grad_fn=<NllLossBackward0>)
# be you i somewhere to'' laid
# expectmm down out only'' kind
# 346 tensor(5.6277, grad_fn=<NllLossBackward0>)
# todd would and sp being answer deeper as
# that do to we would i how.
# 347 tensor(5.4579, grad_fn=<NllLossBackward0>)
# empty at her said sa ; a it
# remainder head to could i only his with
# 348 tensor(6.2122, grad_fn=<NllLossBackward0>)
# .,t want ned rid '
# of fell france started almost them had hadn
# 349 tensor(6.3431, grad_fn=<NllLossBackward0>)
# rear she, okay from been guerra that
# is we. that and to pal he
# 350 tensor(6.6661, grad_fn=<NllLossBackward0>)
# apologies added t just a'mach her
# th of yeah he'her server chad
# 351 tensor(5.6483, grad_fn=<NllLossBackward0>)
# . iv of, patrons him stayed chickens
# looks advice.. seats tighten times stage
# 352 tensor(6.4824, grad_fn=<NllLossBackward0>)
# truck matter the morning i was,t
# he way shock into thank been not eyes
# 353 tensor(6.5230, grad_fn=<NllLossBackward0>)
# i ve. ` another, the of
# .'that ava finding'the like
# 354 tensor(5.8824, grad_fn=<NllLossBackward0>)
# ##gingly together. in and meetingsized.
# doing fee or let, larger she in
# 355 tensor(6.9034, grad_fn=<NllLossBackward0>)
# father was because would of. is feet
# ca often to, pack so where ways
# 356 tensor(6.0620, grad_fn=<NllLossBackward0>)
# his do. ladies in i'hits
# ##oder should symbols ship a we'was
# 357 tensor(5.8976, grad_fn=<NllLossBackward0>)
# ` still was here you the is to
# ` you wanted deacon. he ',
# 358 tensor(5.2816, grad_fn=<NllLossBackward0>)
# and our could. t, red '
# suddenly the gave but d of warmth a
# 359 tensor(5.4443, grad_fn=<NllLossBackward0>)
# hot sighed was of wanted ', a
# vast were. destroyed ran `, her
# 360 tensor(5.9519, grad_fn=<NllLossBackward0>)
# his john mon closed thepro and laugh
# des she showing this away slowly and.
# 361 tensor(6.3926, grad_fn=<NllLossBackward0>)
# `, `'by ` backwards called
# mounting of ` m being i she spots
# 362 tensor(5.7913, grad_fn=<NllLossBackward0>)
# road asked they would could until. `
# side a nicolas laughed me as were i
# 363 tensor(6.2508, grad_fn=<NllLossBackward0>)
# something and my were. her unknown of
# the in we myself well into mine an
# 364 tensor(5.7792, grad_fn=<NllLossBackward0>)
# ', crooked propped wall still little own
# s,torts twenty tone hush el
# 365 tensor(6.0749, grad_fn=<NllLossBackward0>)
# ? ca seeing up shook guy turning,
# feet willing friends lost and tonguesnco
# 366 tensor(6.9271, grad_fn=<NllLossBackward0>)
# s snake s soon floor'was me
# tud re cooked date t remained his
# 367 tensor(5.9245, grad_fn=<NllLossBackward0>)
# ##ffi fingers, vaultvira alreadyddle been
# , sky recognize from said called'disappeared
# 368 tensor(5.7954, grad_fn=<NllLossBackward0>)
# nose. slides stepped `, chapter which
# and wear go'` where d breakfast
# 369 tensor(5.5796, grad_fn=<NllLossBackward0>)
# . boring new a i. n set
# going prospect to real ` stern a `
# 370 tensor(5.4134, grad_fn=<NllLossBackward0>)
# behind killed'what, you. water
# he tricky'while said n slender hard
# 371 tensor(5.0925, grad_fn=<NllLossBackward0>)
# that not and let y ', whispered
# me quarters waiting her his s her inclined
# 372 tensor(5.7916, grad_fn=<NllLossBackward0>)
# 'era any truly ` time swords them
# ' relief. lay `? mutual better
# 373 tensor(6.0114, grad_fn=<NllLossBackward0>)
# ##ification t'on their dinner'`
# ?'` sent he flushed eddie `
# 374 tensor(5.7937, grad_fn=<NllLossBackward0>)
# based glare future have who weaver place '
# ` them way so know him from destroyed
# 375 tensor(5.2217, grad_fn=<NllLossBackward0>)
# beinghor us you will emerged were come
# , out eighteen was engulfed with enjoying surrounded
# 376 tensor(6.6469, grad_fn=<NllLossBackward0>)
# because life there wass'` '
# know the. once buried'' it
# 377 tensor(5.5868, grad_fn=<NllLossBackward0>)
# ##e it d refrigeratorwood ` so jammed
# of tell t the bad his the and
# 378 tensor(5.2485, grad_fn=<NllLossBackward0>)
# ##nged never to, housekeeper thingfounded the
# vi can is over came later irritated two
# 379 tensor(5.2535, grad_fn=<NllLossBackward0>)
# the'what strange lost'' in
# one bra and he heard slowly in to
# 380 tensor(5.4161, grad_fn=<NllLossBackward0>)
# . would tonight drawn bony 'ily obvious
# ##ure would ava of for'charities already
# 381 tensor(6.6561, grad_fn=<NllLossBackward0>)
# need had had west he a i '
# channels. has the for a, `
# 382 tensor(5.4428, grad_fn=<NllLossBackward0>)
# do a rubbing his had was very might
# we silence that up, could'energy
# 383 tensor(5.6036, grad_fn=<NllLossBackward0>)
# before with ; off aunt of that about
# once ofino of you device you arched
# 384 tensor(6.2661, grad_fn=<NllLossBackward0>)
# do fr, learned or n. '
# nothing sat is sounded. safe them why
# 385 tensor(6.0655, grad_fn=<NllLossBackward0>)
# wait planning'as, deep s can
# his sent the but dat have'tragic
# 386 tensor(6.2492, grad_fn=<NllLossBackward0>)
# toward j part her one'mouth.
# her asked our, scream mary on glimpse
# 387 tensor(5.7032, grad_fn=<NllLossBackward0>)
# that the sites wearing hint? what and
# ` you ` wet oneoc ` beginning
# 388 tensor(5.5582, grad_fn=<NllLossBackward0>)
# up was was. this sam at halfway
# ., out her liability won hert
# 389 tensor(6.0708, grad_fn=<NllLossBackward0>)
# , your you, sheep blue ` just
# ' slipped youbu and my ` hear
# 390 tensor(5.3998, grad_fn=<NllLossBackward0>)
# with evil too the on and the `
# fire it. worlds in maintenance i arriving
# 391 tensor(6.6697, grad_fn=<NllLossBackward0>)
# buddy. not. her beth arm they
# leasing evil until boomed you it gathered,
# 392 tensor(6.2960, grad_fn=<NllLossBackward0>)
# .'' handles d 'ly sheath
# it'' an she s blamed i
# 393 tensor(5.5447, grad_fn=<NllLossBackward0>)
# force have they downstairs there besides shoulder molten
# chest owned long up as the driver your
# 394 tensor(6.5773, grad_fn=<NllLossBackward0>)
# `, need they a to'or
# ...
# ,t willed tucking homeing over.
# is all lost floor you, in for
# 2225 tensor(5.2943, grad_fn=<NllLossBackward0>)
# her. chair he he matter'us
# to dead bit it it walk'golden
# 2226 tensor(4.7001, grad_fn=<NllLossBackward0>)
# down. getting told asked year the from
# with any his certainly, meal ` heartbeat
# 2227 tensor(4.5355, grad_fn=<NllLossBackward0>)
# . and'he perceived helpless gu she
# . with would composing je embrace su next
# 2228 tensor(5.9572, grad_fn=<NllLossBackward0>)
# at there he wasn big. at fifteen
# and that the was she away waters his
# 2229 tensor(6.0328, grad_fn=<NllLossBackward0>)
# if that'ashh had stone my
# ' we. that - lost a jake
# 2230 tensor(4.3469, grad_fn=<NllLossBackward0>)
# brother who so traitor had disappeared s a
# cigar connect greatass do dropped s the
# 2231 tensor(4.5402, grad_fn=<NllLossBackward0>)
# i. and the back. her i
# how and as first again occasion front flea
# 2232 tensor(4.9536, grad_fn=<NllLossBackward0>)
# a was the it the on'supposed
# ##okra the gentlemen more up'sure
# 2233 tensor(5.6391, grad_fn=<NllLossBackward0>)
# said quick inch on kaitlyn car kill her
# have together of with the sites he the
# 2234 tensor(5.5793, grad_fn=<NllLossBackward0>)
# nothing ve for pained - they ` spider
# were ll scar lyric, i `.
# 2235 tensor(4.2587, grad_fn=<NllLossBackward0>)
# worst love out zombies had up that locks
# lines life rid i closed she.,
# 2236 tensor(4.7754, grad_fn=<NllLossBackward0>)
# ' whose hadities avoid what he touched
# where meant opened. see that marc gone
# 2237 tensor(5.0928, grad_fn=<NllLossBackward0>)
# get moving his the went '. her
# stay. putting the dropped'want,
# 2238 tensor(4.1513, grad_fn=<NllLossBackward0>)
# right, here mrs so his have '
# crank it anti.., stayd
# 2239 tensor(4.9392, grad_fn=<NllLossBackward0>)
# ' of worked and.op i from
# ' from noticed., row the.
# 2240 tensor(5.5949, grad_fn=<NllLossBackward0>)
# the broke and we'thought glance,
# minutes bent eye'think as themcit
# 2241 tensor(5.9923, grad_fn=<NllLossBackward0>)
# asked any you past crushed stumbled was if
# ##vyn she of air theion felt in
# 2242 tensor(4.8998, grad_fn=<NllLossBackward0>)
# as frost vanished beds his to saveded
# . class new sides the above was23
# 2243 tensor(5.7284, grad_fn=<NllLossBackward0>)
# status again ` ts hated `ed n
# own. i, wondered ` and the
# 2244 tensor(4.4401, grad_fn=<NllLossBackward0>)
# was. general both other and didn had
# . a by had me our prepare knew
# 2245 tensor(5.5849, grad_fn=<NllLossBackward0>)
# n hung on had the in looking '
# n tenderly with on that flipping looking talk
# 2246 tensor(4.5524, grad_fn=<NllLossBackward0>)
# i flesh dropping writing i to girls you
# but mother morley intention it beside have as
# 2247 tensor(5.1018, grad_fn=<NllLossBackward0>)
# was to his and. she result that
# asked who long., or tall that
# 2248 tensor(5.5365, grad_fn=<NllLossBackward0>)
# her'' this kind if m that
# she'' but,. d.
# 2249 tensor(4.3061, grad_fn=<NllLossBackward0>)
# ieit n life,'write we
# .ues totally poor persist ` my much
# 2250 tensor(4.8915, grad_fn=<NllLossBackward0>)
# the'i thought higher the of long
# he'''way offer the night
# 2251 tensor(4.8585, grad_fn=<NllLossBackward0>)
# ` being and i one pain a he
# she i had ', biceps i i
# 2252 tensor(4.4571, grad_fn=<NllLossBackward0>)
# die you'i i ` n `
# worry things'it was i about `
# 2253 tensor(4.6941, grad_fn=<NllLossBackward0>)
# luckilyials were second ` sealed electrified outside
# i, they cautious so unpopular and desperate
# 2254 tensor(5.0281, grad_fn=<NllLossBackward0>)
# ##unb from door being no to rest
# . star at black inch you down dogs
# 2255 tensor(4.7148, grad_fn=<NllLossBackward0>)
# ' survive. thatuc michelle better `
# is running. a through girls the `
# 2256 tensor(4.9462, grad_fn=<NllLossBackward0>)
# hands it?, time after, '
# got shy shoving delicate door it tonight you
# 2257 tensor(4.6274, grad_fn=<NllLossBackward0>)
# take i counter'school. look him
# know. couch'and. then to
# 2258 tensor(4.5205, grad_fn=<NllLossBackward0>)
# .mise an matt wanted deal n.
# anie the ` ca new never out
# 2259 tensor(4.9102, grad_fn=<NllLossBackward0>)
# of the sense but. she what je
# of. looked on steady released carried in
# 2260 tensor(5.9998, grad_fn=<NllLossBackward0>)
# her her sick. she. i '
# , pinch bloody. present. do '
# 2261 tensor(4.7405, grad_fn=<NllLossBackward0>)
# a shook a smashed as them abandoned '
# the were thatlent rang our points '
# 2262 tensor(4.7608, grad_fn=<NllLossBackward0>)
# crawl in it to a ` chest was
# the to, himself stopped ` before ever
# 2263 tensor(4.8480, grad_fn=<NllLossBackward0>)
# did. felt glancing threat drunk when `
# can when thought she dial served styled jack
# 2264 tensor(4.8144, grad_fn=<NllLossBackward0>)
# ##n blast nodded compare,., she
# ##cy chink kill without, sit it
# 2265 tensor(4.8920, grad_fn=<NllLossBackward0>)
# , was even on - offito ship
# will is imagination tight kind, open time
# 2266 tensor(5.1250, grad_fn=<NllLossBackward0>)
# ` reached ` bright then. him that
# when, i floors and. ryan to
# 2267 tensor(4.7502, grad_fn=<NllLossBackward0>)
# he s explained it winked take'the
# don, raised promising that which had world
# 2268 tensor(5.7030, grad_fn=<NllLossBackward0>)
# felt, door laughed ca as all as
# even wins bed these guess cr tighten unfair
# 2269 tensor(4.5874, grad_fn=<NllLossBackward0>)
# years bounced thated else eagle be.
# brilliant, voicesy byi.isman
# 2270 tensor(5.2391, grad_fn=<NllLossBackward0>)
# ` the do we had six of kiev
# ` and '. sucked '. he
# 2271 tensor(4.6387, grad_fn=<NllLossBackward0>)
# get by ` to there'into i
# stop on ` to habitat'that it
# 2272 tensor(4.3023, grad_fn=<NllLossBackward0>)
# ##v thigh otherwise second quantity voice trust now
# ja head uniquely moment. tremor be.
# 2273 tensor(5.0785, grad_fn=<NllLossBackward0>)
# your call.s ear encounter identified in
# it will at came per persons that then
# 2274 tensor(5.8113, grad_fn=<NllLossBackward0>)
# to the - it so it babe '
# to my bike many name. ser were
# 2275 tensor(4.9561, grad_fn=<NllLossBackward0>)
# . waste step evan the massacre on this
# to okay once think the, the you
# 2276 tensor(4.3852, grad_fn=<NllLossBackward0>)
# outside - room.ble at ill story
# ailo bag landedrun you i pit
# 2277 tensor(5.7106, grad_fn=<NllLossBackward0>)
# ##r genes be walked five ` that sleeping
# closer affected the and you he toy
# 2278 tensor(5.9345, grad_fn=<NllLossBackward0>)
# he ` threw the time,, `
# kid ` eyes? evil were place '
# 2279 tensor(4.4852, grad_fn=<NllLossBackward0>)
# missed to know, ` body had `
# seen of stand with was bonfire pulling `
# 2280 tensor(4.4187, grad_fn=<NllLossBackward0>)
# troy ` to know the ` opened on
# . ` came do the ` could,
# 2281 tensor(5.1253, grad_fn=<NllLossBackward0>)
# ##s the ustor observe the her has
# to that me his the he his beck
# 2282 tensor(6.1630, grad_fn=<NllLossBackward0>)
# looks s be going ` meal she to
# who forward er getting ` to n to
# 2283 tensor(4.6967, grad_fn=<NllLossBackward0>)
# you them,. ventured as with hand
# ' our. either does.f arm
# 2284 tensor(4.7930, grad_fn=<NllLossBackward0>)
# he the was wash has with again in
# he only! saw were winners. until
# 2285 tensor(5.7995, grad_fn=<NllLossBackward0>)
# another said checked skin `? look.
# the gasp await as'he thinkion
# 2286 tensor(5.2043, grad_fn=<NllLossBackward0>)
# , they. invel a with
# ##low one swarm! hislas spiritual now
# 2287 tensor(5.8141, grad_fn=<NllLossBackward0>)
# her at the stford n'`
# ##re i court'started n'starting
# 2288 tensor(4.7338, grad_fn=<NllLossBackward0>)
# how hers, ` the.fi rest
# he from was i the. than case
# 2289 tensor(4.7212, grad_fn=<NllLossBackward0>)
# so you if the,'batteredday
# tentatively perhaps it ` on did ` few
# 2290 tensor(5.4042, grad_fn=<NllLossBackward0>)
# me. werewolf began gabrielle was a eu
# take. appalachian leaving said read the big
# 2291 tensor(5.7321, grad_fn=<NllLossBackward0>)
# a long he mly normally garden if
# ' young. d car. driver and
# 2292 tensor(4.3421, grad_fn=<NllLossBackward0>)
# . the special to nearby damn little of
# tos best her defendant maybe. of
# 2293 tensor(4.7805, grad_fn=<NllLossBackward0>)
# or combination were ; plume be said but
# child back in off go react can have
# 2294 tensor(5.2906, grad_fn=<NllLossBackward0>)
# him subjects to guys `y try ted
# ##ly state a. my. charles you
# 2295 tensor(4.5640, grad_fn=<NllLossBackward0>)
# ,ma indeed men a did.rest
# diversion, in moment n school, so
# 2296 tensor(5.1615, grad_fn=<NllLossBackward0>)
# the the the trembled much under the do
# a us she mounted a the the slant
# 2297 tensor(5.5162, grad_fn=<NllLossBackward0>)
# . when kill ` into to his in
# , like go he within if her pressed
# 2298 tensor(4.4686, grad_fn=<NllLossBackward0>)
# my in car. in asher why `
# fall of for and he, we `
# 2299 tensor(4.9337, grad_fn=<NllLossBackward0>)
# I/O operation on closed file.
# armed. hell closer. to that the
# you,. in. it there behold
# 2301 tensor(5.5134, grad_fn=<NllLossBackward0>)
# . he's `, asweight
# . growing '. `. in now
# 2302 tensor(4.6953, grad_fn=<NllLossBackward0>)
# ' whitelles'' her was eyes
# christian, pushed'' a ignored almost
# 2303 tensor(4.5310, grad_fn=<NllLossBackward0>)
# . to'my an! the when
# piled ;'the, johnnyir but
# 2304 tensor(5.3336, grad_fn=<NllLossBackward0>)
# ##s demanded no forms, one t chance
# . came a of, other t reminder
# 2305 tensor(4.7203, grad_fn=<NllLossBackward0>)
# - meal shouted it continued'rose her
# risk giant'i need. brand.
# 2306 tensor(4.3470, grad_fn=<NllLossBackward0>)
# and with thieves punch i. satellite her
# to talented workout exit you were but as
# 2307 tensor(5.5333, grad_fn=<NllLossBackward0>)
# for pointed others whilef he? he
# furthern prophecy agatha assessment ih that
# 2308 tensor(5.4396, grad_fn=<NllLossBackward0>)
# like and t more to s s had
# found. d? them s s cl
# 2309 tensor(4.8053, grad_fn=<NllLossBackward0>)
# teeth of on the off t. *
# ##tt thatfk ` of t as g
# 2310 tensor(4.7266, grad_fn=<NllLossBackward0>)
# settle ridley future same do had with been
# got connor us beauty must paused. known
# 2311 tensor(4.9301, grad_fn=<NllLossBackward0>)
# university raise too insiders sucked and killed
# his or, and hands watchedh to
# 2312 tensor(5.5629, grad_fn=<NllLossBackward0>)
# givings honeymoon collect. whole kiss the
# alive my world the waist drops helping me
# 2313 tensor(5.4239, grad_fn=<NllLossBackward0>)
# my but rebecca surprising tia hart do t
# perfect to ` megan, make me t
# 2314 tensor(4.3525, grad_fn=<NllLossBackward0>)
# helene they for ` was sc aotho
# a lightning back ` was a going i
# 2315 tensor(5.2047, grad_fn=<NllLossBackward0>)
# . now ` n, and'walking
# or things ` is, just make that
# 2316 tensor(5.2993, grad_fn=<NllLossBackward0>)
# no puzzle house 'ar ` to answer
# gossip. railing '. dan it care
# 2317 tensor(4.8238, grad_fn=<NllLossBackward0>)
# great woman judgments ea he on'the
# tomorrow regular right it ` from failing a
# 2318 tensor(5.3902, grad_fn=<NllLossBackward0>)
# don. school. the on guys when
# saw give their sooner she'about after
# 2319 tensor(4.5320, grad_fn=<NllLossBackward0>)
# probably mane to honestly and morning them door
# find system area. z. as cried
# 2320 tensor(4.8557, grad_fn=<NllLossBackward0>)
# n will with ` skinned smiling. '
# ##bbling has this exceptho ka that '
# 2321 tensor(4.8913, grad_fn=<NllLossBackward0>)
# to. very as i his saw sometimes
# down of with fiercely, mentioning reached not
# 2322 tensor(5.0690, grad_fn=<NllLossBackward0>)
# then the '. eyes wheel a slim
# the theza? plea into you why
# 2323 tensor(4.7531, grad_fn=<NllLossBackward0>)
# . conjecture of how sir, seegon
# , dad intoting surprisedened know.
# 2324 tensor(4.7136, grad_fn=<NllLossBackward0>)
# she it you king checked typing forgive '
# that him'that said she going will
# 2325 tensor(4.6075, grad_fn=<NllLossBackward0>)
# opened the my least trying want s stopped
# did this insane vet making had s did
# 2326 tensor(4.1277, grad_fn=<NllLossBackward0>)
# , all was heart tall in, m
# only top was thoughts solid,land re
# 2327 tensor(4.7508, grad_fn=<NllLossBackward0>)
# swelling the suggested november the.. son
# . ins said addition them. our garage
# 2328 tensor(5.1894, grad_fn=<NllLossBackward0>)
# body.'particularly, why was played
# so. off finisheduc are knew up
# 2329 tensor(5.1579, grad_fn=<NllLossBackward0>)
# but to stalled - was been the said
# ition sliced - began some the was
# 2330 tensor(6.1437, grad_fn=<NllLossBackward0>)
# ` myind, say warmer might my
# ` thatw. where of kept society
# 2331 tensor(4.5691, grad_fn=<NllLossBackward0>)
# . lucan attention.. comes `.
# treated what signs he of? `.
# 2332 tensor(5.3250, grad_fn=<NllLossBackward0>)
# ` caught sleep smiling was against to un
# ` got the they was to to.
# 2333 tensor(4.4442, grad_fn=<NllLossBackward0>)
# her just pool summers thick she of the
# many and ` tommy ranger they knee on
# 2334 tensor(6.0327, grad_fn=<NllLossBackward0>)
# any, being in that finger last our
# the picks one was, purple lot that
# 2335 tensor(4.7621, grad_fn=<NllLossBackward0>)
# to could the dylan where your dimension want
# . met when helen. this of bid
# 2336 tensor(4.9384, grad_fn=<NllLossBackward0>)
# , after the then the innate now
# at ty zane the he back comes ty
# 2337 tensor(4.6658, grad_fn=<NllLossBackward0>)
# water and adrenaline were in change snarled to
# em and that were. one was his
# 2338 tensor(5.7216, grad_fn=<NllLossBackward0>)
# the done, ` nodded'division '
# ##ui specified, ` say.. '
# 2339 tensor(4.3618, grad_fn=<NllLossBackward0>)
# . more scar going to damn come felt
# because lying world able always'work admitted
# 2340 tensor(4.8105, grad_fn=<NllLossBackward0>)
# their parking crack `z sharpened suggested before
# like holidays on `,the told upon
# 2341 tensor(5.6704, grad_fn=<NllLossBackward0>)
# ands ofwn is himcer holidays
# had. ands wasn she and
# 2342 tensor(5.8052, grad_fn=<NllLossBackward0>)
# t bu to that. t of if
# t shower quiet, had t ago she
# 2343 tensor(4.8456, grad_fn=<NllLossBackward0>)
# did toooped night creature comet s
# care did i here. you. s
# 2344 tensor(4.7482, grad_fn=<NllLossBackward0>)
# coming had,. the s trunk you
# of took,, and s rows it
# 2345 tensor(5.1647, grad_fn=<NllLossBackward0>)
# calmly the the givest children salem far
# wear? nobody maureent told first the
# 2346 tensor(5.4645, grad_fn=<NllLossBackward0>)
# life his thing mass how or did objects
# priorities back thing champion in we helplessly,
# 2347 tensor(5.6216, grad_fn=<NllLossBackward0>)
# , s * i some looked have holden
# enjoyed s * i down was speak '
# 2348 tensor(4.4310, grad_fn=<NllLossBackward0>)
# little down a about that her. i
# sort in theded water.? she
# 2349 tensor(5.6074, grad_fn=<NllLossBackward0>)
# one the game with bed her matter '
# her right past up smile she -ator
# 2350 tensor(4.8736, grad_fn=<NllLossBackward0>)
# supposed,vet n telling i placed i
# wanted. strolled neck twisting a tugged my
# 2351 tensor(4.4708, grad_fn=<NllLossBackward0>)
# then please fl weeks well.'to
# ` maybe hurt days.. ',
# 2352 tensor(4.8383, grad_fn=<NllLossBackward0>)
# late know `, voice `, done
# struggling take `. mother ` of like
# 2353 tensor(4.8709, grad_fn=<NllLossBackward0>)
# they raf bastard maybe boys you or.
# ka but races they university thes for
# 2354 tensor(5.6816, grad_fn=<NllLossBackward0>)
# ' had superior colored ways sir experienced reginald
# whispered leaving, whenever. me in one
# 2355 tensor(5.0724, grad_fn=<NllLossBackward0>)
# he wants opened the then broke anxious maybe
# towardhale looked him go hatred you mc
# 2356 tensor(5.4719, grad_fn=<NllLossBackward0>)
# took were? something., me they
# took to doing correct, you some close
# 2357 tensor(4.7140, grad_fn=<NllLossBackward0>)
# artworkowed. the thera call some
# elbows of on knee me men am never
# 2358 tensor(4.5566, grad_fn=<NllLossBackward0>)
# that you ground ob of murmured grazing other
# from you icton. from res.
# 2359 tensor(5.7772, grad_fn=<NllLossBackward0>)
# ##t random believe him sweetheart in backled
# ##t actress exist her a only one other
# 2360 tensor(5.7246, grad_fn=<NllLossBackward0>)
# he but ` i learn of sitting mocked
# the but ` they sail. - never
# 2361 tensor(5.2345, grad_fn=<NllLossBackward0>)
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
if (not pretrained) or build_pretrained:
    # create a PyTorch optimizer
    # optimizer = torch.optim.AdamW(gen.parameters(), lr=learning_rate, weight_decay=0.01, amsgrad=True)

    for iter in range(iterations):
        try:
            
            if (iter != 0) and (iter % eval_iters == 0):
                losses = estimate_loss()
                train_loss = losses['train']
                val_loss = losses['val']
                print(f'Loss at step = {iter} for train data is {train_loss:.4f} for val it is {val_loss:.4f}')

            # sample a batch of data
            xb, yb = get_batch('train')

            # evaluate the loss
            logits, loss = gen.forward(xb, yb, tokenizer)
            if not torch.isnan(loss).any():
                print(iter, loss)
                optimizer.zero_grad(set_to_none=True)
                loss.backward()
                torch.torch.nn.utils.clip_grad_norm_(gen.parameters(), max_norm=15.0)
                optimizer.step()
            else:
                print('NaN loss')
                print(iter, loss)
                input()
        except:
            pass

# %%
if (not pretrained) or build_pretrained:
    with open('text_generator.pkl', 'wb') as handler:
        pickle.dump(gen, handler)

# %%
if pretrained:
    with open('text_generator.pkl', 'rb') as handler:
        gen = pickle.load(handler)

# %%
prompt = 'She was going to do it, but'

# %%
prompt_ids = tokenizer(prompt, return_tensors='pt', add_special_tokens=False).input_ids
prompt_ids

# %%
generated_ids = gen.generate(prompt_ids.to(device), max_new_tokens=10)
generated_ids

# %%
tokenizer.decode(generated_ids[0])
