# %%
from transformer.config import FetchFromPretrained as ConfigFromPretrained

# %%
from transformer.tokenizer import FetchFromPretrained as TokenizerFromPretrained

# %%
from datasets import load_dataset

# %%
import torch

# %%
device = 'cuda' if torch.cuda.is_available() else 'cpu'
# device = 'cpu'
device
# Out:
# 'cuda'

# %%
data = load_dataset('AlekseyKorshuk/books')
data
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['text'],
#         num_rows: 741
#     })
# })

# %%
model_ckpt = 'google-bert/bert-base-uncased'

# %%
config = ConfigFromPretrained(model_ckpt=model_ckpt).fetch()
config
# Out:
# BertConfig {
#   "_name_or_path": "google-bert/bert-base-uncased",
#   "architectures": [
#     "BertForMaskedLM"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "classifier_dropout": null,
#   "gradient_checkpointing": false,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "layer_norm_eps": 1e-12,
#   "max_position_embeddings": 512,
#   "model_type": "bert",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "pad_token_id": 0,
#   "position_embedding_type": "absolute",
#   "transformers_version": "4.39.3",
#   "type_vocab_size": 2,
#   "use_cache": true,
#   "vocab_size": 30522
# }

# %%
config.hidden_size = 1024
config.intermediate_size = 128
config.compress_layer_size = 128
config.max_position_embeddings = 256
config.num_attention_heads = 8
config.num_hidden_layers = 8
config.device = device
config.dtype = torch.float32

# %%
batch_size = 8

# %%
tokenizer = TokenizerFromPretrained(model_ckpt=model_ckpt).fetch()
tokenizer
# Out:
# BertTokenizerFast(name_or_path='google-bert/bert-base-uncased', vocab_size=30522, model_max_length=512, is_fast=True, padding_side='right', truncation_side='right', special_tokens={'unk_token': '[UNK]', 'sep_token': '[SEP]', 'pad_token': '[PAD]', 'cls_token': '[CLS]', 'mask_token': '[MASK]'}, clean_up_tokenization_spaces=True),  added_tokens_decoder={
# 	0: AddedToken("[PAD]", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	100: AddedToken("[UNK]", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	101: AddedToken("[CLS]", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	102: AddedToken("[SEP]", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	103: AddedToken("[MASK]", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# }

# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
import numpy as np

# %%
import os

# %%
import pickle

# %%
import random

# %%
import re

# %%
files_count = len(data['train'])
files_count
# Out:
# 741

# %%
split_index_1, split_index_2 = int(files_count * 0.8), int(files_count * 0.9)
split_index_1, split_index_2
# Out:
# (592, 666)

# %%
def get_data_from_random_files(split):
    indices = []
    if split == 'train':
        file_id = random.randint(0, split_index_1)
    elif split == 'test':
        file_id = random.randint(split_index_1, split_index_2)
    elif split == 'val':
        file_id = random.randint(split_index_2, files_count)

    file = data['train'][file_id]['text']

    input_ids = tokenizer(file, return_tensors='pt', add_special_tokens=False).input_ids[0]
    if len(input_ids) < config.max_position_embeddings + 2*batch_size:
        return get_data_from_random_files(split)
    return input_ids

# %%
def get_batch(split):
    input_ids = get_data_from_random_files(split=split)
    ix = torch.randint(len(input_ids) - config.max_position_embeddings, (batch_size,))
    x = torch.stack([input_ids[i:i + config.max_position_embeddings] for i in ix])
    y = torch.stack([input_ids[i + 1:i + config.max_position_embeddings + 1] for i in ix])
    x, y = x.to(torch.int64).to(device), y.to(torch.int64).to(device)
    return x, y

# %%
get_data_from_random_files('train')
# Out:
# Token indices sequence length is longer than the specified maximum sequence length for this model (1337710 > 512). Running this sequence through the model will result in indexing errors
# tensor([4656, 2246, 2039,  ..., 2010, 5001, 1012])

# %%
get_batch('train')
# Out:
# (tensor([[ 2002,  2921,  2010,  ...,  2071,  4089,  3342],
#          [ 1029,  2073,  2079,  ...,  1010,  1998,  6877],
#          [ 2320,  2016,  2001,  ...,  1036,  2054,  2038],
#          ...,
#          [25201,  3507,  2012,  ...,  7753,  3578,  2098],
#          [ 7514,  1010,  2079,  ...,  1996,  3096,  1997],
#          [ 2010,  2793,  5829,  ..., 15583,  2032,  2005]], device='cuda:0'),
#  tensor([[ 2921,  2010,  2132,  ...,  4089,  3342,  2010],
#          [ 2073,  2079,  2017,  ...,  1998,  6877,  2071],
#          [ 2016,  2001,  2908,  ...,  2054,  2038,  2002],
#          ...,
#          [ 3507,  2012,  1996,  ...,  3578,  2098,  3174],
#          [ 1010,  2079, 15265,  ...,  3096,  1997,  2014],
#          [ 2793,  5829,  3435,  ...,  2032,  2005,  7302]], device='cuda:0'))

# %%
from transformer.head.text_generator_decoder_only import TextGenerator

# %%
generator = TextGenerator(config)

# %%
gen = generator.to(device)

# %%
eval_iters = 100

# %%
eval_iter_ticks = 5

# %%
X, Y = get_batch('train')
logits, loss = gen(X, Y, tokenizer)
logits, logits.size(), loss
# Out:
# (tensor([[[-2.9826e-01, -3.3975e-01, -4.1917e-01,  ..., -8.2622e-01,
#             9.8238e-01, -6.6574e-02],
#           [ 6.7641e-02,  6.0552e-02,  1.7264e-01,  ...,  6.0807e-01,
#            -8.3629e-01,  2.7148e-01],
#           [-4.9022e-01,  1.3766e+00,  4.4577e-01,  ...,  2.9313e-01,
#             8.2492e-01,  1.3530e-01],
#           ...,
#           [ 7.5198e-01,  6.3796e-02,  1.3477e-01,  ..., -9.1082e-02,
#            -2.5998e-01,  2.2136e-02],
#           [-1.0625e+00,  1.6012e-01, -4.0552e-01,  ..., -3.6616e-01,
#            -7.6066e-01, -3.7680e-01],
#           [ 2.5929e-01,  3.8800e-01,  2.4807e-01,  ..., -3.2450e-01,
#            -1.6820e-01, -3.9306e-02]],
#
#          [[ 2.4795e-02,  5.7552e-01, -2.8587e-01,  ...,  6.7478e-01,
#             1.7043e-01,  1.2594e-01],
#           [ 6.0724e-02,  5.2643e-01, -2.4513e-01,  ...,  5.3861e-01,
#            -3.3589e-01,  6.4324e-01],
#           [-1.0408e-01,  1.2433e+00,  2.2106e-01,  ...,  2.8994e-01,
#             2.6490e-01, -1.5885e-01],
#           ...,
#           [ 4.2111e-01, -6.3780e-01,  2.2764e-01,  ...,  8.1006e-01,
#             1.7636e-01,  3.8048e-01],
#           [-6.0029e-01, -3.6643e-02, -5.0825e-01,  ..., -3.5088e-01,
#            -3.8146e-01,  7.1774e-01],
#           [ 4.1620e-01, -7.9523e-01,  3.2509e-01,  ..., -4.9443e-01,
#             5.7221e-01,  5.7602e-02]],
#
#          [[-1.6009e-01, -4.8503e-01, -8.4401e-01,  ..., -1.8746e-01,
#             9.1081e-01, -1.7093e-01],
#           [-9.5193e-01, -2.3276e-01,  1.2094e-01,  ...,  1.3885e+00,
#            -6.4180e-02, -4.1340e-02],
#           [ 3.6399e-01,  2.5270e-01, -3.8377e-01,  ..., -5.0364e-03,
#             5.0937e-01, -6.0299e-01],
#           ...,
#           [ 3.5560e-01, -7.0317e-01,  5.6887e-01,  ...,  3.5270e-01,
#            -1.7572e-01,  2.6696e-01],
#           [-5.8058e-01, -1.0608e+00, -4.2816e-01,  ..., -5.2803e-01,
#            -9.0302e-03,  9.6383e-02],
#           [ 4.9150e-01,  2.2372e-01, -6.6047e-01,  ...,  3.0350e-01,
#             5.1093e-01, -2.7635e-01]],
#
#          ...,
#
#          [[-1.1930e-01, -6.3934e-01, -3.4209e-01,  ..., -2.5853e-01,
#             7.2383e-01,  8.8458e-01],
#           [ 4.0407e-01, -2.2219e-01,  7.2000e-02,  ..., -1.3708e-01,
#             3.7761e-01,  1.0048e+00],
#           [-3.2146e-01,  1.3852e-01, -3.1679e-01,  ...,  1.1788e+00,
#            -6.8916e-02, -2.5652e-02],
#           ...,
#           [ 4.6375e-01, -1.8578e-01,  6.4565e-01,  ...,  9.1877e-01,
#             4.6615e-02, -2.1499e-01],
#           [ 8.7709e-01, -3.9435e-01, -5.9157e-01,  ..., -4.2199e-01,
#            -1.7774e-01,  2.1707e-01],
#           [ 2.8150e-01, -6.2503e-01,  3.5494e-01,  ..., -7.1775e-01,
#            -7.3596e-01, -3.8120e-01]],
#
#          [[-7.6656e-03, -5.1409e-01, -5.7412e-02,  ..., -6.8269e-01,
#             2.6977e-01,  6.3321e-01],
#           [ 1.2871e-02,  8.4879e-02, -2.7485e-01,  ...,  5.1462e-02,
#            -6.9924e-01,  5.9493e-01],
#           [-2.9670e-01,  1.5438e-01,  7.9257e-02,  ...,  6.5533e-02,
#             1.4641e-01, -3.8201e-01],
#           ...,
#           [ 9.8674e-01, -1.1042e-01, -3.9522e-01,  ...,  9.7754e-01,
#             6.1883e-01,  6.8942e-02],
#           [ 4.6729e-01, -2.3323e-01, -5.5958e-01,  ..., -3.4808e-01,
#            -1.8966e-01,  1.6595e-01],
#           [-2.4589e-01, -2.1902e-01,  2.3925e-01,  ..., -2.8773e-01,
#            -5.4400e-01, -4.7410e-01]],
#
#          [[ 2.0354e-01, -1.9642e-01, -8.4975e-01,  ...,  3.1358e-01,
#             3.0812e-01,  8.5066e-01],
#           [ 1.1490e-02, -7.7661e-01, -1.4129e-01,  ...,  5.2168e-01,
#             1.9773e-01,  5.6910e-01],
#           [ 1.7442e-01,  1.6969e-01, -1.8722e-01,  ...,  3.0607e-01,
#             1.0692e+00,  9.1765e-02],
#           ...,
#           [ 5.7050e-01, -3.0895e-01, -7.3633e-01,  ...,  4.2908e-01,
#             1.3323e-01, -2.9631e-01],
#           [-3.9550e-01, -3.1353e-01,  1.7712e-01,  ...,  2.7736e-01,
#            -2.7918e-01,  1.9494e-01],
#           [ 4.0050e-01,  5.3296e-01, -3.2881e-01,  ..., -1.8879e-01,
#            -6.8619e-04, -6.7560e-01]]], device='cuda:0',
#         grad_fn=<ViewBackward0>),
#  torch.Size([8, 256, 30522]),
#  tensor(10.4447, device='cuda:0', grad_fn=<NllLossBackward0>))

# %%
pretrained = False

# %%
build_pretrained = False

# %%
sum(p.numel() for p in gen.parameters())
# Out:
# 100893498

# %%
def test(prompt='She was going to '):
    prompt_ids = tokenizer(prompt, return_tensors='pt', add_special_tokens=False).input_ids
    generated_ids = gen.generate(prompt_ids.to(device), max_new_tokens=20)
    result = tokenizer.decode(generated_ids[0])
    print(result)

# %%
def test_deep(logits, targets):
    # focus only on the last time step
    logits = logits[:, -1, :] # becomes (B, C)
    # apply softmax to obtain probabilities
    probs = torch.nn.functional.softmax(logits, dim=-1).to(config.device) # (B, C)
    index_next = torch.multinomial(probs, num_samples=1) # (B, C)

    print(tokenizer.decode(index_next.squeeze(-1)))
    print(tokenizer.decode(targets[:, -1]))

# %%
@torch.no_grad()
def estimate_loss():
    out = {}
    if (not pretrained) or build_pretrained:
        with open('text_generator.pkl', 'wb') as handler:
            pickle.dump(gen, handler)
    gen.eval()
    for split in ['train', 'val']:
        losses = torch.zeros(eval_iters)
        for k in range(eval_iter_ticks):
            X, Y = get_batch(split)
            logits, loss = gen(X, Y)
            losses[k] = loss.item()
            test_deep(logits, Y)
        out[split] = losses.mean()
    gen.train()
    return out

# %%
learning_rate = 5e-3

# %%
iterations = 1000000

# %%
if build_pretrained:
    with open('text_generator.pkl', 'wb') as handler:
        pickle.dump(gen, handler)

# %%
if (not pretrained) or build_pretrained:
    # create a PyTorch optimizer
    optimizer = torch.optim.AdamW(gen.parameters(), lr=learning_rate, weight_decay=0.01, amsgrad=True)

    for iter in range(iterations):
        try:
            
            if (iter != 0) and (iter % eval_iters == 0):
                losses = estimate_loss()
                train_loss = losses['train']
                val_loss = losses['val']
                print(f'Loss at step = {iter} for train data is {train_loss:.4f} for val it is {val_loss:.4f}')

            # sample a batch of data
            xb, yb = get_batch('train')

            # evaluate the loss
            logits, loss = gen.forward(xb, yb, tokenizer)

            if not torch.isnan(loss).any():
                test_deep(logits, yb)
                print(iter, loss)
                optimizer.zero_grad(set_to_none=True)
                loss.backward()
                # torch.torch.nn.utils.clip_grad_norm_(gen.parameters(), max_norm=15.0)
                optimizer.step()
            else:
                print('NaN loss')
                print(iter, loss)
                input()
        except Exception as e:
            print(e)
# Out:
# preface questioned ware scooped tracy shrinking [unused631] [unused12]
# , not okay her with human the he
# 0 tensor(10.4416, device='cuda:0', grad_fn=<NllLossBackward0>)
# .. elbow supermarket. anticipation. the
# stab, he glasses got few, where
# 1 tensor(10.7319, device='cuda:0', grad_fn=<NllLossBackward0>)
# 四. ས 四 palestinian 1729 exemptrelli
# and n are his of so on at
# 2 tensor(22.7131, device='cuda:0', grad_fn=<NllLossBackward0>)
# ##sb puresbificationsb although 四sb
# watching say nightie crush dart his.
# 3 tensor(101.2283, device='cuda:0', grad_fn=<NllLossBackward0>)
# ........
# ##s. stink'none short was his
# 4 tensor(1418.4895, device='cuda:0', grad_fn=<NllLossBackward0>)
# studied walk walk walk walk walk walk walk
# ##ro blue... a me against
# 5 tensor(1421.7917, device='cuda:0', grad_fn=<NllLossBackward0>)
# burn burn burn burn burn burn burn burn
# opened wolf on smiling spirit t then goose
# 6 tensor(385.3386, device='cuda:0', grad_fn=<NllLossBackward0>)
# walk walk walk walk shirt wanted walk walk
# the the, quickly. something. take
# 7 tensor(1511.2253, device='cuda:0', grad_fn=<NllLossBackward0>)
# quite quite quite quite quite quite quite quite
# ##uit obstacles fear.? a black kind
# 8 tensor(627.7538, device='cuda:0', grad_fn=<NllLossBackward0>)
# let let chest let let let let chest
# we,., surviving swung and her
# 9 tensor(606.3702, device='cuda:0', grad_fn=<NllLossBackward0>)
# bare bare bare bare bare bare bare bare
# who lethal really had off down answer her
# 10 tensor(1904.0950, device='cuda:0', grad_fn=<NllLossBackward0>)
# against against against against must against against against
# moment them mrss'members'what
# 11 tensor(668.3157, device='cuda:0', grad_fn=<NllLossBackward0>)
# necks necks necks necks necks necks necks necks
# had smile feeto was my. the
# 12 tensor(2701.1189, device='cuda:0', grad_fn=<NllLossBackward0>)
# .. taken.....
# my are something this? i. '
# 13 tensor(556.1198, device='cuda:0', grad_fn=<NllLossBackward0>)
# bare bare bare bare bare bare bare bare
# wanted whatever ` had ` find like i
# 14 tensor(2086.8076, device='cuda:0', grad_fn=<NllLossBackward0>)
# come her her her come her come come
# then ; could? you. im are
# 15 tensor(2855.4517, device='cuda:0', grad_fn=<NllLossBackward0>)
# walk walk walk walk walk walk walk walk
# to but the qu thembil she his
# 16 tensor(3717.3647, device='cuda:0', grad_fn=<NllLossBackward0>)
# ' he he he she he he he
# he mountain'always. several at,
# 17 tensor(3118.3843, device='cuda:0', grad_fn=<NllLossBackward0>)
# ,, behind behind took took,,
# forgive of. he duty'to going
# 18 tensor(2810.9148, device='cuda:0', grad_fn=<NllLossBackward0>)
# ale ale ale ale ale ale some some
# how thank '. hand so will and
# 19 tensor(2662.0962, device='cuda:0', grad_fn=<NllLossBackward0>)
# himself himself suggested himself himself himself himself edge
# his also looked caught men badly you did
# 20 tensor(2657.3723, device='cuda:0', grad_fn=<NllLossBackward0>)
# burn walkinger more having their moreer
# ' monica'cia me alone asking fell
# 21 tensor(2088.3860, device='cuda:0', grad_fn=<NllLossBackward0>)
# did last last giving giving giving neck giving
# dating intensely out i never up you finger
# 22 tensor(1735.4529, device='cuda:0', grad_fn=<NllLossBackward0>)
# pushed already theyg they bare seen they
# on josh it to nope consumed wrongrs
# 23 tensor(1655.7592, device='cuda:0', grad_fn=<NllLossBackward0>)
# ##trip polite pieces pieces iv against grinned bare
# ceilingz abbey it gotve, the
# 24 tensor(2993.1340, device='cuda:0', grad_fn=<NllLossBackward0>)
# ` ` ` such ` s ` `
# . had and of'time in s
# 25 tensor(2571.1963, device='cuda:0', grad_fn=<NllLossBackward0>)
# heard nonsense nonsense mort she want great against
# brad bill. kate west it a,
# 26 tensor(2046.7306, device='cuda:0', grad_fn=<NllLossBackward0>)
# too one enough one himself one one as
# i had then. me would by his
# 27 tensor(2196.8513, device='cuda:0', grad_fn=<NllLossBackward0>)
# bare against double bareig chains bare bare
# to rougha in this was didn so
# 28 tensor(4048.0378, device='cuda:0', grad_fn=<NllLossBackward0>)
# that would that could that that that that
# getbid asked it. to, rub
# 29 tensor(4805.6777, device='cuda:0', grad_fn=<NllLossBackward0>)
# quick quick is those powerful those quickther
# wanted,,. can bed how tender
# 30 tensor(3128.1628, device='cuda:0', grad_fn=<NllLossBackward0>)
# legs hands start breast second start care nothing
# dimension do me his. closed her the
# 31 tensor(2283.8015, device='cuda:0', grad_fn=<NllLossBackward0>)
# looking with myself myselfp seat black i
# call my, eyes imbled. had
# 32 tensor(1908.3431, device='cuda:0', grad_fn=<NllLossBackward0>)
# our which which moved which a sure white
# shia its girl the him his
# 33 tensor(2078.1589, device='cuda:0', grad_fn=<NllLossBackward0>)
# stupid thanks fast was asks there stupid asks
# that lands i and. out his,
# 34 tensor(2100.3247, device='cuda:0', grad_fn=<NllLossBackward0>)
# his what words m when asking t soft
# go, and. months `ck down
# 35 tensor(1929.8422, device='cuda:0', grad_fn=<NllLossBackward0>)
# headed leaving pounds narrowedna chicago headed headed
# and in un come ray big from prime
# 36 tensor(2503.1838, device='cuda:0', grad_fn=<NllLossBackward0>)
# do ` ` `? ` tell?
# ##ing prince ` m, just his but
# 37 tensor(3002.3462, device='cuda:0', grad_fn=<NllLossBackward0>)
# been but i and and but and and
# percent double to would when ship exactly wide
# 38 tensor(3968.8904, device='cuda:0', grad_fn=<NllLossBackward0>)
# shadows commentserun comment comment lifting miracle
# up blankets shed events with to and room
# 39 tensor(4225.1650, device='cuda:0', grad_fn=<NllLossBackward0>)
# somehow forced hurriedly forced forced jumped forced jumped
# . and wait about the protect, pulled
# 40 tensor(3863.1843, device='cuda:0', grad_fn=<NllLossBackward0>)
# him bed him face face him the out
# to ala of piece arch s williams of
# 41 tensor(4769.1089, device='cuda:0', grad_fn=<NllLossBackward0>)
# girls girls girls girls scar replies girls girls
# overwhelming resistance before girl dee wanted you and
# 42 tensor(4877.9258, device='cuda:0', grad_fn=<NllLossBackward0>)
# hell opponentlp that cares that hell hell
# to to, the ravi happened..
# 43 tensor(3655.7463, device='cuda:0', grad_fn=<NllLossBackward0>)
# idea, including jeremy,! faced!
# great they broughts specials use br
# 44 tensor(3130.3010, device='cuda:0', grad_fn=<NllLossBackward0>)
# was to was was to to to was
# . say smallest much no. smiled factions
# 45 tensor(3438.9045, device='cuda:0', grad_fn=<NllLossBackward0>)
# offered cared walked offered offered cared cared offered
# lot '. were sometimezed my me
# 46 tensor(3532.2280, device='cuda:0', grad_fn=<NllLossBackward0>)
# ##t time before help held before both know
# her, ` lips dad so, texas
# 47 tensor(2657.9265, device='cuda:0', grad_fn=<NllLossBackward0>)
# stay? last mis glasses glasses last last
# n answers he there.'n s
# 48 tensor(3443.1560, device='cuda:0', grad_fn=<NllLossBackward0>)
# read have him do blade and into are
# gray fool i first town her in just
# 49 tensor(2630.1912, device='cuda:0', grad_fn=<NllLossBackward0>)
# ##on playing closed and andon and nice
# among cha chuckled she some dare felt me
# 50 tensor(2552.3416, device='cuda:0', grad_fn=<NllLossBackward0>)
# of there very gravely it thanks after beneath
# sourcetion i, veryrum a sex
# 51 tensor(2361.1438, device='cuda:0', grad_fn=<NllLossBackward0>)
# call consider mad allow your because, pain
# ii before that you cheek have abby
# 52 tensor(2221.4233, device='cuda:0', grad_fn=<NllLossBackward0>)
# m meal? about d m stared about
# ##test your she of k,, behind
# 53 tensor(2610.4512, device='cuda:0', grad_fn=<NllLossBackward0>)
# wow reference wow squeeze girls pinning spreads however
# then apart pedestrian ze -. them she
# 54 tensor(2986.3513, device='cuda:0', grad_fn=<NllLossBackward0>)
# his my my remember my his will a
# ' question her wolf usual? was the
# 55 tensor(3086.8674, device='cuda:0', grad_fn=<NllLossBackward0>)
# which barely answers which. which succession toward
# and they, of respond. like.
# 56 tensor(3113.0706, device='cuda:0', grad_fn=<NllLossBackward0>)
# warehousered right greene divine in ` marching
# suite stars there'me been ` master
# 57 tensor(3029.3188, device='cuda:0', grad_fn=<NllLossBackward0>)
# the n were nothing green we who were
# . `ia getting 27 you. he
# 58 tensor(3157.6914, device='cuda:0', grad_fn=<NllLossBackward0>)
# that but to d nothing being to if
# merlin waves he t, made from i
# 59 tensor(2954.1841, device='cuda:0', grad_fn=<NllLossBackward0>)
# move read which felt watched vampires woman fixed
# it underway thing where to she and know
# 60 tensor(3241.9243, device='cuda:0', grad_fn=<NllLossBackward0>)
# handed just just and and turning anyone replied
# to shirt the but end you thatmis
# 61 tensor(2716.1899, device='cuda:0', grad_fn=<NllLossBackward0>)
# sq grin sometime lets grin benches grin grin
# hospital bit were his the, have it
# 62 tensor(2908.0876, device='cuda:0', grad_fn=<NllLossBackward0>)
# sounds never cross their their responsev the
# that to adopted - and thought, the
# 63 tensor(2791.9016, device='cuda:0', grad_fn=<NllLossBackward0>)
# i blind a private nevercr blind of
# chile werebly and a if? mom
# 64 tensor(2736.2588, device='cuda:0', grad_fn=<NllLossBackward0>)
# could entrance is believe james grin supposed struggle
# here shan until that `, takes like
# 65 tensor(2532.7136, device='cuda:0', grad_fn=<NllLossBackward0>)
# then then precious truly a whole found there
# copper the was an crunch now burn these
# 66 tensor(2711.1575, device='cuda:0', grad_fn=<NllLossBackward0>)
# well re bad bad ve black making almost
# a leading but i. you ` in
# 67 tensor(2387.6797, device='cuda:0', grad_fn=<NllLossBackward0>)
# gas ana stretched stretched bend gas orchestra i
# the to catch, a allowed for i
# 68 tensor(2610.9844, device='cuda:0', grad_fn=<NllLossBackward0>)
# even in even perfect at the not the
# legion give too why begin s did fire
# 69 tensor(3178.7524, device='cuda:0', grad_fn=<NllLossBackward0>)
# nodded flew marble flashing flashing life nightbbling
# fucking nice him something. da at glass
# 70 tensor(3568.4280, device='cuda:0', grad_fn=<NllLossBackward0>)
# probably a. a. maybe. saw
# tell down dropped, a magic to their
# 71 tensor(3855.9697, device='cuda:0', grad_fn=<NllLossBackward0>)
# jagged fixedsto tirensns faint days
# dh i, it i sink which
# 72 tensor(3544.1455, device='cuda:0', grad_fn=<NllLossBackward0>)
# like to like put like like now like
# balance a be are his days man not
# 73 tensor(4376.8042, device='cuda:0', grad_fn=<NllLossBackward0>)
# trim coast trim coast due trim turret coast
# to'assignment. i to for `
# 74 tensor(5679.2769, device='cuda:0', grad_fn=<NllLossBackward0>)
# never t t t me t t me
# '. of likelihood doctor the `,
# 75 tensor(3598.1650, device='cuda:0', grad_fn=<NllLossBackward0>)
# condition though though though n condition cleaning cleaning
# this to braffin. its is
# 76 tensor(3340.3142, device='cuda:0', grad_fn=<NllLossBackward0>)
# bows gone at emotion i from usual i
# , down. detail'i same he
# 77 tensor(2352.0142, device='cuda:0', grad_fn=<NllLossBackward0>)
# punch slung familiar then threatening punch minister through
# collection that something strong.? okay coffee
# 78 tensor(2505.7751, device='cuda:0', grad_fn=<NllLossBackward0>)
# feeling old suck suck gently feeling old now
# on shrill are it into. so?
# 79 tensor(2406.8936, device='cuda:0', grad_fn=<NllLossBackward0>)
# wo were next were wo be were or
# isabel i impact write ofwi table been
# 80 tensor(2562.6047, device='cuda:0', grad_fn=<NllLossBackward0>)
# relax comforting me altogether relax relax recounted drank
# might okay i'con. whats
# 81 tensor(2948.8179, device='cuda:0', grad_fn=<NllLossBackward0>)
# of god says you i god you of
# '. of'me bear saturdays my
# 82 tensor(3053.8940, device='cuda:0', grad_fn=<NllLossBackward0>)
# extra scrape heels emske maybe heels maybe
# ago enjoying were for the they will,
# 83 tensor(2946.2791, device='cuda:0', grad_fn=<NllLossBackward0>)
# his for did up said his for,
# ##abe. idea ` whole, dr.
# 84 tensor(2651.1365, device='cuda:0', grad_fn=<NllLossBackward0>)
# while, while horizonbs restless lingering laughed
# although the that department sister t my been
# 85 tensor(3072.8425, device='cuda:0', grad_fn=<NllLossBackward0>)
# running the running looks running way lips lips
# sat you is on across starting knew,
# 86 tensor(2892.5325, device='cuda:0', grad_fn=<NllLossBackward0>)
# ##sy ref relax tone. warm late rose
# curse agreed hard that greatest. the they
# 87 tensor(2687.6570, device='cuda:0', grad_fn=<NllLossBackward0>)
# cabinets trim trim trim never trim t trim
# guards was giving both its a all there
# 88 tensor(2847.9646, device='cuda:0', grad_fn=<NllLossBackward0>)
# ,, she, name,,,
# she before on the several there thing -
# 89 tensor(6044.4482, device='cuda:0', grad_fn=<NllLossBackward0>)
# trying trying york we personnel yeah fourteen personnel
# cold your fruit.ce his be looked
# 90 tensor(6089.4980, device='cuda:0', grad_fn=<NllLossBackward0>)
# bad days in days days everyone days bad
# n is first of ` house never and
# 91 tensor(4354.4565, device='cuda:0', grad_fn=<NllLossBackward0>)
# as something expensive as something something as something
# lemon. deposited onto and he feel have
# 92 tensor(3777.3169, device='cuda:0', grad_fn=<NllLossBackward0>)
# wood useless curved number fitted ignorant lucylene
# n s chest''.. her
# 93 tensor(4949.8457, device='cuda:0', grad_fn=<NllLossBackward0>)
# had and ` would emergency d face quietly
# teresa'himself? of sally me right
# 94 tensor(3103.5420, device='cuda:0', grad_fn=<NllLossBackward0>)
# former. n.'perhaps'settle
# whisky go ` to. s d a
# 95 tensor(2522.3333, device='cuda:0', grad_fn=<NllLossBackward0>)
# or setting money thought though or becoming joined
# whileliner hand her of n i her
# 96 tensor(2941.2109, device='cuda:0', grad_fn=<NllLossBackward0>)
# and change six to falling beautiful began began
# 'd i. get, but lu
# 97 tensor(2810.4331, device='cuda:0', grad_fn=<NllLossBackward0>)
# strides matter daughters beautiful falling talking daughters hear
# . again it typicallyt i do i
# 98 tensor(4079.9446, device='cuda:0', grad_fn=<NllLossBackward0>)
# camera what wants we immediately no you purple
# monsters head have ininal willing to you
# 99 tensor(4008.8213, device='cuda:0', grad_fn=<NllLossBackward0>)
# yeah stumbled warned stumbleire yeah delay yeah
# my punish. elizabeth larry couldn were.
# delay non physically yeah delay yeah yeah carla
# ''their pre when. sounded she
# follow yeah stumbled van stumbled stumbled tray boarded
# t of not, he, finished to
# non yeah yeah stumbled boarded will days relaxed
# the that curtains shattered the shelle `
# yeah yeah physically yeah delay yeah yeah delay
# sword nows two ill.ct.
# fires carla slips van delay hunt elizabeth chilly
# a about looking i that this, because
# stumbled delay childish yeah endured wood stumbled follow
# .'', people,. d
# yeah follow send follow yeah stumbled attractive smaller
# closed'` sure dragged time here one
# attitudes yeah knocked terms yeah follow delay yeah
# . for excuse can too t to his
# carla stumbled sol forgot yeah chilly stumbled send
# had ` n freaking not my coffee s
# Loss at step = 100 for train data is 232.4163 for val it is 225.5771
# yeah boarded yeah hunt sat yeah hunt stumbled
# have not saw a squeeze knew and later
# 100 tensor(4536.8765, device='cuda:0', grad_fn=<NllLossBackward0>)
# attractive pointed trying moment when back when of
# i just. see,ray have lore
# 101 tensor(3838.9551, device='cuda:0', grad_fn=<NllLossBackward0>)
# draginin his drag panties to drag
# `. one my returned call damn my
# 102 tensor(3630.4321, device='cuda:0', grad_fn=<NllLossBackward0>)
# brand days maybe was days to days roll
# who own'spend gr s calm legs
# 103 tensor(4333.8667, device='cuda:0', grad_fn=<NllLossBackward0>)
# without soed so so teeth on here
# , conversationisi imp it to save about
# 104 tensor(4644.5991, device='cuda:0', grad_fn=<NllLossBackward0>)
# ##hol i secretary considered maehol mae mae
# the you *.. body, do
# 105 tensor(5714.6406, device='cuda:0', grad_fn=<NllLossBackward0>)
# had be be see of be it be
# larry on over sexual song waist of glare
# 106 tensor(5101.6880, device='cuda:0', grad_fn=<NllLossBackward0>)
# gratitude at attack knowingthic resignation something appointments
# he'a king jared m the '
# 107 tensor(4414.0757, device='cuda:0', grad_fn=<NllLossBackward0>)
# clung king. king.. waitress quiet
# thenur.lyn gasped they i threatened
# 108 tensor(4191.2573, device='cuda:0', grad_fn=<NllLossBackward0>)
# them'so locker'''so
# what risks more days forest as skin
# 109 tensor(4653.7578, device='cuda:0', grad_fn=<NllLossBackward0>)
# movie snuggled you secretary movie here beautiful the
# shit it. flying a my to the
# 110 tensor(4319.0547, device='cuda:0', grad_fn=<NllLossBackward0>)
# did pale sweat fall actually won talk days
# brought tara yourself ond, eyes would
# 111 tensor(4799.8818, device='cuda:0', grad_fn=<NllLossBackward0>)
# on ont i stand i i i
# the `'' and i not '
# 112 tensor(4894.3159, device='cuda:0', grad_fn=<NllLossBackward0>)
# breath nose say. ` reached ` raising
# bending but that and metal on even arched
# 113 tensor(5038.3325, device='cuda:0', grad_fn=<NllLossBackward0>)
# liquor swing ben o ass finallynar horse
# loss or? thick property for at had
# 114 tensor(5038.3423, device='cuda:0', grad_fn=<NllLossBackward0>)
# go help leaned shrugged leaned said picture at
# we, materialized was all - the is
# 115 tensor(4465.5884, device='cuda:0', grad_fn=<NllLossBackward0>)
# ##ss soon, whose fair certainly don :
# . better the floor full anmp wave
# 116 tensor(4258.8247, device='cuda:0', grad_fn=<NllLossBackward0>)
# ticked scentures sensitivearister willome
# ' much ears '. it they me
# 117 tensor(4399.3779, device='cuda:0', grad_fn=<NllLossBackward0>)
# to side to to to blood to to
# to of. cause the brow not the
# 118 tensor(6709.4854, device='cuda:0', grad_fn=<NllLossBackward0>)
# talking laughing disappeared'us'rain us
# ,, relationship thinking, i some price
# 119 tensor(5222.9707, device='cuda:0', grad_fn=<NllLossBackward0>)
# saving saving protected saving saving protected think saving
# fresh of bottles wife beg grey'a
# 120 tensor(6904.3960, device='cuda:0', grad_fn=<NllLossBackward0>)
# now now knows see call said now see
# too ` none orchestrated my sea he two
# 121 tensor(7792.4404, device='cuda:0', grad_fn=<NllLossBackward0>)
# wouldn but doesn corner numbered other chance.
# of railing - s visit hair than off
# 122 tensor(6546.4302, device='cuda:0', grad_fn=<NllLossBackward0>)
# poking caressing caressing gets sir poking poking poking
# after'on'total. my.
# 123 tensor(6534.8726, device='cuda:0', grad_fn=<NllLossBackward0>)
# the quietly she figure the i, the
# shell fall am to. ll that has
# 124 tensor(5741.7891, device='cuda:0', grad_fn=<NllLossBackward0>)
# he,, figure'now us ah
# until shear easy acrosssrose not they
# 125 tensor(7303.1582, device='cuda:0', grad_fn=<NllLossBackward0>)
# awesome truck believe're as saving surprises
# missed'the stones maris'saving of
# 126 tensor(5997.4409, device='cuda:0', grad_fn=<NllLossBackward0>)
# - ; on from'- and and
# ' at as sit'yeah into '
# 127 tensor(6476.6777, device='cuda:0', grad_fn=<NllLossBackward0>)
# her minutes main stepfather afraid mind minutes fl
# keep with he inery same a it
# 128 tensor(6235.8784, device='cuda:0', grad_fn=<NllLossBackward0>)
# ##tion led slant soo soo rescue clue sealed
# to'n.'` was deep
# 129 tensor(6798.5093, device='cuda:0', grad_fn=<NllLossBackward0>)
# had aim can i never both had both
# petite fuel i the. theyly western
# 130 tensor(9335.1123, device='cuda:0', grad_fn=<NllLossBackward0>)
# and and and and your and and more
# . sue pink walked'neither of cl
# 131 tensor(8748.3389, device='cuda:0', grad_fn=<NllLossBackward0>)
# away something away something series overwhelmed something shame
# way : couldn when the children caughtrad
# 132 tensor(7680.9160, device='cuda:0', grad_fn=<NllLossBackward0>)
# lost emily activity doesn shihi bending shi
# do it. rough in her did and
# 133 tensor(7590.8979, device='cuda:0', grad_fn=<NllLossBackward0>)
# ##tt bog boghy sealed trackrierie
# admit we had that '. know and
# 134 tensor(7494.6035, device='cuda:0', grad_fn=<NllLossBackward0>)
# ' things two 't best best best
# knowing the, free. february back is
# 135 tensor(7706.5269, device='cuda:0', grad_fn=<NllLossBackward0>)
# adored off pairs t, itself not pairs
# '. ` his two up after me
# 136 tensor(8447.6348, device='cuda:0', grad_fn=<NllLossBackward0>)
# and parts disappear jesse and so moment so
# water said that swept the to her what
# 137 tensor(7002.4727, device='cuda:0', grad_fn=<NllLossBackward0>)
# ##lam ` so forth ` vein elite years
# ,, problems liszt emily shapes that to
# 138 tensor(7788.9429, device='cuda:0', grad_fn=<NllLossBackward0>)
# you ` breeze deserved hard you now something
# thet con even bean ` sure friends
# 139 tensor(7503.6377, device='cuda:0', grad_fn=<NllLossBackward0>)
# yesterday bruised the sky insane same stab the
# s. him did keep them eachago
# 140 tensor(7429.1289, device='cuda:0', grad_fn=<NllLossBackward0>)
# ' their their debate with scrubbed done gr
# could'' ins his managed, laughing
# 141 tensor(6991.0703, device='cuda:0', grad_fn=<NllLossBackward0>)
# holdline dun nadiaded barking loop could
# wrapping i as ', as'since
# 142 tensor(7757.6191, device='cuda:0', grad_fn=<NllLossBackward0>)
# get from get his get get get of
# my lashed tell high it a stretch.
# 143 tensor(9677.8096, device='cuda:0', grad_fn=<NllLossBackward0>)
# now now now old bail old now old
# `. the admitted case you looked kept
# 144 tensor(10406.1748, device='cuda:0', grad_fn=<NllLossBackward0>)
# ` ` ` ` ` ` ` `
# murmured ll.'his being remember him
# 145 tensor(17216.6230, device='cuda:0', grad_fn=<NllLossBackward0>)
# riot riot reading'riot'riot riot
# he continue d n hair ', but
# 146 tensor(23178.5605, device='cuda:0', grad_fn=<NllLossBackward0>)
# . a. a a re a a
# ' believe be though i'no towel
# 147 tensor(25524.5762, device='cuda:0', grad_fn=<NllLossBackward0>)
# - - - - - - - -
# took back get on a that yeah never
# 148 tensor(25303.4414, device='cuda:0', grad_fn=<NllLossBackward0>)
# darted darted ro darted darted darted ro darted
# sorry? something on her'that '
# 149 tensor(26860.6113, device='cuda:0', grad_fn=<NllLossBackward0>)
# ''''''' '
# out at clipped phone need `. on
# 150 tensor(26940.9102, device='cuda:0', grad_fn=<NllLossBackward0>)
# me me me me me me me me
# starters ` ` dusty stepped a sherlock all
# 151 tensor(28793.4023, device='cuda:0', grad_fn=<NllLossBackward0>)
# now the doorbell my thinking entered announcement father
# about she to neck her the an hands
# 152 tensor(26313.5508, device='cuda:0', grad_fn=<NllLossBackward0>)
# make year because make relationship relationship i feel
# fire sans flesh reed brother it aria,
# 153 tensor(21844.6348, device='cuda:0', grad_fn=<NllLossBackward0>)
# riot close riot stormy riot riot absolutely riot
# ' never and at they played. much
# 154 tensor(26235.3086, device='cuda:0', grad_fn=<NllLossBackward0>)
# the at told... boy.
# say all really frontcia staring, in
# 155 tensor(35361.4727, device='cuda:0', grad_fn=<NllLossBackward0>)
# half snow complete as complete gather riot dried
# , to been could time, had outside
# 156 tensor(35684.9922, device='cuda:0', grad_fn=<NllLossBackward0>)
# hot really up out brother moving brother am
# ,. were at'said manting
# 157 tensor(27600.2793, device='cuda:0', grad_fn=<NllLossBackward0>)
# darted, hadt of outside of darted
# dozen nik i or saw structures like was
# 158 tensor(27732.5176, device='cuda:0', grad_fn=<NllLossBackward0>)
# ? i mass mass i got m funny
# kirkiving,re neck chapter, adding
# 159 tensor(27276.6465, device='cuda:0', grad_fn=<NllLossBackward0>)
# worry gulped moose worry gulpedpedped nor
# she on hands ` the that the slick
# 160 tensor(27742.3184, device='cuda:0', grad_fn=<NllLossBackward0>)
# the knight down res down who down down
# lights probably i,uri so i the
# 161 tensor(37789.5547, device='cuda:0', grad_fn=<NllLossBackward0>)
# pages alert bulge rumor alert filled usually alert
# re thinking'now did demoted? reached
# 162 tensor(39616.9805, device='cuda:0', grad_fn=<NllLossBackward0>)
# have have'we okay i because would
# prostitute father of has. i head heads
# 163 tensor(33567.0039, device='cuda:0', grad_fn=<NllLossBackward0>)
# anything on time,, since on,
# expecting body turning internal was cher the `
# 164 tensor(34594.6406, device='cuda:0', grad_fn=<NllLossBackward0>)
# linked ro fl ro whirled wonder cass differently
# be with that a more, goose hot
# 165 tensor(42516.8359, device='cuda:0', grad_fn=<NllLossBackward0>)
# face m to wound there m together s
# ##ues flower again bored closing. a it
# 166 tensor(35450.6953, device='cuda:0', grad_fn=<NllLossBackward0>)
# little lot little.. lot put.
# ##champ lucius see enveloped what finished tell bottom
# 167 tensor(31051.3496, device='cuda:0', grad_fn=<NllLossBackward0>)
# difficult upule glimpseule best rolling presence
# you gag thing own gasped to into
# 168 tensor(33135.7422, device='cuda:0', grad_fn=<NllLossBackward0>)
# beside said through the what the could mom
# station lang this but hundred good the memories
# 169 tensor(39034.2461, device='cuda:0', grad_fn=<NllLossBackward0>)
# becomes di ashton ny ashton torment ashton coincidence
# ., i,,o wake rani
# 170 tensor(46844.9492, device='cuda:0', grad_fn=<NllLossBackward0>)
# at at at at at at at at
# it'i n. his around fallen
# 171 tensor(57067.8359, device='cuda:0', grad_fn=<NllLossBackward0>)
# longeren low asked parents longer asked longer
# .. '. laughter my say t
# 172 tensor(85729.7656, device='cuda:0', grad_fn=<NllLossBackward0>)
# as perfect as who perfect perfect of perfect
# ##fted, not. more me rush in
# 173 tensor(69734.7266, device='cuda:0', grad_fn=<NllLossBackward0>)
# over him since few between couple if n
# sub the died,'meek, resting
# 174 tensor(61075.3125, device='cuda:0', grad_fn=<NllLossBackward0>)
# piles piles did ability plansne back ability
# with many, n become case murmured `
# 175 tensor(61366.7617, device='cuda:0', grad_fn=<NllLossBackward0>)
# spot whening no,, no no
# stared human which spotlight ofasi invented thank
# 176 tensor(75696.3828, device='cuda:0', grad_fn=<NllLossBackward0>)
# balfour smoothly notch smoothly vegetables strawras smoothly
# were. one down pre. it want
# 177 tensor(98686.9062, device='cuda:0', grad_fn=<NllLossBackward0>)
# the the brown bones three three bones c
# n touched no i this these want red
# 178 tensor(73066.4688, device='cuda:0', grad_fn=<NllLossBackward0>)
# where in. in in in. parents
# madame her meg steve but, of arrived
# 179 tensor(90131.1719, device='cuda:0', grad_fn=<NllLossBackward0>)
# cheeks broken ny hardly she cheeks cheeks kissing
# some sm then returned tended very d was
# 180 tensor(82642.2344, device='cuda:0', grad_fn=<NllLossBackward0>)
# mind explore noing says for noing
# agitation control'just to her ink
# 181 tensor(67303.8047, device='cuda:0', grad_fn=<NllLossBackward0>)
# i from we his thrilled remain that im
# southhead kidnap. readers to the softer
# 182 tensor(54725.8477, device='cuda:0', grad_fn=<NllLossBackward0>)
# of pray used his day of right day
# madeing is forehead her eyes at,
# 183 tensor(58747.7539, device='cuda:0', grad_fn=<NllLossBackward0>)
# spirits i seriously families families max families to
# both with to something was turns smell kade
# 184 tensor(70257.0625, device='cuda:0', grad_fn=<NllLossBackward0>)
# mistake, woman hardo could thoughts hard
# times hear findings ho thought'grandpa '
# 185 tensor(76746.4688, device='cuda:0', grad_fn=<NllLossBackward0>)
# to girl what lots awake one cold girl
# were ` puff reinforcements pay you. little
# 186 tensor(75855.7969, device='cuda:0', grad_fn=<NllLossBackward0>)
# ##tis burnsulsion oldest hockey hockey intotis
# tonight '. here who leaping? wrestlers
# 187 tensor(156213.4062, device='cuda:0', grad_fn=<NllLossBackward0>)
# and switch and thing in in certainty in
# in in she d she realized ` suddenly
# 188 tensor(92168.9375, device='cuda:0', grad_fn=<NllLossBackward0>)
# of going hard had of of of had
# terrible ` out heryp on of may
# 189 tensor(132659.8438, device='cuda:0', grad_fn=<NllLossBackward0>)
# tea long him him camea t still
# fell so aimed they i that tried '
# 190 tensor(88519.6094, device='cuda:0', grad_fn=<NllLossBackward0>)
# ability brokenara sites shepherd ability respond again
# facial the of up when table very she
# 191 tensor(146806.2188, device='cuda:0', grad_fn=<NllLossBackward0>)
# ' three in forest three where, where
# the happened i a kind. me '
# 192 tensor(103537.4531, device='cuda:0', grad_fn=<NllLossBackward0>)
# sat i i had i t t.
# your have me mother people `ac which
# 193 tensor(112435.9844, device='cuda:0', grad_fn=<NllLossBackward0>)
# smoothly harden speakingete your more body go
# - totally to does never she and little
# 194 tensor(108131.4609, device='cuda:0', grad_fn=<NllLossBackward0>)
# `r ` familiar ` determine fever.
# ##iate inside at. face out. so
# 195 tensor(95078.9453, device='cuda:0', grad_fn=<NllLossBackward0>)
# my. that head head my pink ked
# 'ied as organs ` streaks to and
# 196 tensor(86646.3203, device='cuda:0', grad_fn=<NllLossBackward0>)
# his endure of several his ll down his
# .,'shoulder dem jen the idea
# 197 tensor(91022.2344, device='cuda:0', grad_fn=<NllLossBackward0>)
# eyes to already even real fore eyes even
# bag. couch there i would. it
# 198 tensor(99437.5391, device='cuda:0', grad_fn=<NllLossBackward0>)
# cr cr did do cr her did that
# had inside onto block?, me hand
# 199 tensor(110691.5547, device='cuda:0', grad_fn=<NllLossBackward0>)
# real the face quickly theing into the
# steps seen good than, i sheless
# part i is quiet quickly quickly real part
# was obligatory soup his made s body.
# , i quickly quickly real the quickly real
# was one could with the against,,
# quickly quickly is the is quickly wake part
# beverly half the one cr went just and
# part quickly void the starting the was part
# a then lips wal we i? ca
# totally quickly real quickly real the quickly was
# ' in since full are never s,
# the quickly quickly the says real quickly real
# we we'beenin hundreds on rick
# face the was quickly anymore sister into the
# they metal - i hole of you was
# real affair says quickly part into the the
# herself,. ` now said time sky
# , manner the real quickly into quickly real
# sc death true into stuff s'perfectly
# Loss at step = 200 for train data is 5776.5312 for val it is 5596.0454
# void quickly real weapon, face wakeing
# thes deliver arms you eyes help against
# 200 tensor(117668.7891, device='cuda:0', grad_fn=<NllLossBackward0>)
# that that that want that i that that
# the my would, she s the `
# 201 tensor(124361.7188, device='cuda:0', grad_fn=<NllLossBackward0>)
# ##boardboard filesboard closet ocean closet guess
# . get, life so. the -
# 202 tensor(121375.9766, device='cuda:0', grad_fn=<NllLossBackward0>)
# the the.. everything just just should
# attention move their. was. my as
# 203 tensor(101185.6797, device='cuda:0', grad_fn=<NllLossBackward0>)
# brian ter ter stirred danger kinds ter hilt
# a. at asked and i then find
# 204 tensor(128977.1016, device='cuda:0', grad_fn=<NllLossBackward0>)
# longed this will to brother use my
# looked had up say 'fully ing repeat
# 205 tensor(128365.8203, device='cuda:0', grad_fn=<NllLossBackward0>)
# other. private.. beyond hear.
# ##st for na in,hea we.
# 206 tensor(109575.5859, device='cuda:0', grad_fn=<NllLossBackward0>)
# mere drum thenan defeat mouthscan,
# from the ca ` about he wait about
# 207 tensor(122143.6094, device='cuda:0', grad_fn=<NllLossBackward0>)
# cl he her cl brains softly short short
# father him to me the spells the bigger
# 208 tensor(90542.9922, device='cuda:0', grad_fn=<NllLossBackward0>)
# ask you made sector a bit easy made
# goes he weathered a had your''
# 209 tensor(102375.5000, device='cuda:0', grad_fn=<NllLossBackward0>)
# with tension for watch buildings parchment right about
# even interesting the ',! gently move
# 210 tensor(101861.1953, device='cuda:0', grad_fn=<NllLossBackward0>)
# accomplishier when asic when chain this
# . -ie probably idea 37s look
# 211 tensor(95469.8281, device='cuda:0', grad_fn=<NllLossBackward0>)
# here. he thegging than gap today
# a, threat tightly when the'nodded
# 212 tensor(93096.9375, device='cuda:0', grad_fn=<NllLossBackward0>)
# look. was.'much they.
# a without. was wasn for lived,
# 213 tensor(88569.1250, device='cuda:0', grad_fn=<NllLossBackward0>)
# ? when? he looking he upon breathing
# was involving set in? somewhere,.
# 214 tensor(99346.3984, device='cuda:0', grad_fn=<NllLossBackward0>)
# toward keep able shake brushing raised answer firm
# be your to arm use'look at
# 215 tensor(84470.4219, device='cuda:0', grad_fn=<NllLossBackward0>)
# fl burst the away when she away gently
# either lights her at there thing is pulled
# 216 tensor(96748.8906, device='cuda:0', grad_fn=<NllLossBackward0>)
# he then themselves night he he he warned
# i lab son par. that way adding
# 217 tensor(89788.0625, device='cuda:0', grad_fn=<NllLossBackward0>)
# - and ready - - ready - and
# light others! and noticed crew dh shooter
# 218 tensor(91248.4844, device='cuda:0', grad_fn=<NllLossBackward0>)
# accepted doors eyeen wall adjust short eye
# night dad it that m - was `
# 219 tensor(76522.6875, device='cuda:0', grad_fn=<NllLossBackward0>)
# guy physicalhe met makeup, she her
# anson men rule forehead to minuteslar believe
# 220 tensor(88268.8594, device='cuda:0', grad_fn=<NllLossBackward0>)
# , forearms carrying roommate completely plus forearms forearms
# ' woke - may she bite `.
# 221 tensor(81097.9531, device='cuda:0', grad_fn=<NllLossBackward0>)
# ' of t look ` you't
# guess it re, '. ` all
# 222 tensor(71542.2578, device='cuda:0', grad_fn=<NllLossBackward0>)
# ##tt shet ` see / with
# you you filteringcha mug bringing inca in
# 223 tensor(74586.3672, device='cuda:0', grad_fn=<NllLossBackward0>)
# ##tra painful. tales.. demanded.
# as drugs with sure your my am around
# 224 tensor(67530.0312, device='cuda:0', grad_fn=<NllLossBackward0>)
# . the making air sure does and the
# me 'rked killed ` i, walked
# 225 tensor(73764.3438, device='cuda:0', grad_fn=<NllLossBackward0>)
# ' his and'hand his and.
# s he, '. except. shrugged
# 226 tensor(76523.4141, device='cuda:0', grad_fn=<NllLossBackward0>)
# buildings danger back sweetheart stay flies ding melanie
# . behind sure to time forcing followed the
# 227 tensor(86643.4062, device='cuda:0', grad_fn=<NllLossBackward0>)
# only out shook said side was said eyes
# seemed. ellis glanceds, faced sean
# 228 tensor(67681.2891, device='cuda:0', grad_fn=<NllLossBackward0>)
# ,, be, sort were are here
# us as '. '. i knotted
# 229 tensor(76112.8828, device='cuda:0', grad_fn=<NllLossBackward0>)
# horses is'leg notlind worn con
# anyone chapter but calledant that himself police
# 230 tensor(76046.0547, device='cuda:0', grad_fn=<NllLossBackward0>)
# ionel photographied groan runven hart
# chemical where examined understandcated what. the
# 231 tensor(72702.0781, device='cuda:0', grad_fn=<NllLossBackward0>)
# needooped still for too for this man
# `'his needed he, spoon what
# 232 tensor(62151.9844, device='cuda:0', grad_fn=<NllLossBackward0>)
# why cheek to to probably to everything to
# ##y i...que. is
# 233 tensor(64251.4297, device='cuda:0', grad_fn=<NllLossBackward0>)
# ##sss the ohss '
# eyes 'antly? whisper his, '
# 234 tensor(59267.8789, device='cuda:0', grad_fn=<NllLossBackward0>)
# cards rev emotions that anxious that cards `
# early sand,, so and'a
# 235 tensor(68817.6641, device='cuda:0', grad_fn=<NllLossBackward0>)
# scrub same animal bomb on actually claim breathed
# offended turned pair train i. years must
# 236 tensor(71086.7422, device='cuda:0', grad_fn=<NllLossBackward0>)
# baby air voice just his been baby,
# a. made would? way n with
# 237 tensor(66489.7422, device='cuda:0', grad_fn=<NllLossBackward0>)
# and again purpose was crowd his.,
# over ` remnants now her and. would
# 238 tensor(59368.1641, device='cuda:0', grad_fn=<NllLossBackward0>)
# restaurant smoke trip violet sharinglla all forward
# he the to. in with,uity
# 239 tensor(61199.9219, device='cuda:0', grad_fn=<NllLossBackward0>)
# her her heights hand theina her the
# much to him to distracted di him did
# 240 tensor(62645.8320, device='cuda:0', grad_fn=<NllLossBackward0>)
# the had the square the yes car him
# granite'surprised back of he christian near
# 241 tensor(66729.8828, device='cuda:0', grad_fn=<NllLossBackward0>)
# pierce sadnessers jake accomplished dark anything will
# , brown him'hoped phone do make
# 242 tensor(67564.9531, device='cuda:0', grad_fn=<NllLossBackward0>)
# you back futile heap heap heap you on
# instead apology made. bittri the hook
# 243 tensor(55676.8984, device='cuda:0', grad_fn=<NllLossBackward0>)
# withs gu know the added mess composure
# . and that and stabbed wanted heels then
# 244 tensor(50917.4531, device='cuda:0', grad_fn=<NllLossBackward0>)
# dr or know had probably with large.
# she,ening my standing'ave
# 245 tensor(53944.9648, device='cuda:0', grad_fn=<NllLossBackward0>)
# a clear se murmurs kissing katie. take
# witnessed day half she, a dead unique
# 246 tensor(55639.9141, device='cuda:0', grad_fn=<NllLossBackward0>)
# balcony n quickly simple bellowed locked busted heart
# to tiredyr every would'his able
# 247 tensor(51020.7695, device='cuda:0', grad_fn=<NllLossBackward0>)
# quickly near'' alive arched possibly heart
# yearble principals then why two.
# 248 tensor(56108.5547, device='cuda:0', grad_fn=<NllLossBackward0>)
# just my cast mu reputation someone dancing feelings
# , you this sent cracked you the starting
# 249 tensor(46155.6055, device='cuda:0', grad_fn=<NllLossBackward0>)
# be right my woman blondze sorry sky
# , maybe direct twosa her felt still
# 250 tensor(55671.3164, device='cuda:0', grad_fn=<NllLossBackward0>)
# ##nian gentle protect forgotten spearess advisor forgotten
# , almost she up that have, me
# 251 tensor(59094.6094, device='cuda:0', grad_fn=<NllLossBackward0>)
# in in i? very in thegan
# ##sso reason d imp.'and.
# 252 tensor(84336.4766, device='cuda:0', grad_fn=<NllLossBackward0>)
# is roots ofy is twicei scooped
# . or powerful as guess to body would
# 253 tensor(66743.3125, device='cuda:0', grad_fn=<NllLossBackward0>)
# gots fury i josie next without rested
# beginning projectedr, she ` maybe of
# 254 tensor(54356.9453, device='cuda:0', grad_fn=<NllLossBackward0>)
# blessing'stand that of, reason of
# d an over she h sy as relaxed
# 255 tensor(68963.5469, device='cuda:0', grad_fn=<NllLossBackward0>)
# that found re that maybe than find found
# close that `'i'hand '
# 256 tensor(53265.5312, device='cuda:0', grad_fn=<NllLossBackward0>)
# bankaking year dollar year gravity * know
# statutes? that hand she the for her
# 257 tensor(65358.9531, device='cuda:0', grad_fn=<NllLossBackward0>)
# ,,,, post, scared,
# we. ` we killed sleeves and reason
# 258 tensor(56093.0586, device='cuda:0', grad_fn=<NllLossBackward0>)
# like swinging heart them had accepted ass talk
# look. one food planned youed straighten
# 259 tensor(59756.0820, device='cuda:0', grad_fn=<NllLossBackward0>)
# away pain ` beach should residence beach liked
# new bop it. of finger was quietly
# 260 tensor(59372.3047, device='cuda:0', grad_fn=<NllLossBackward0>)
# so was by. they they by she
# '. never in she ran walked coughing
# 261 tensor(60055.5000, device='cuda:0', grad_fn=<NllLossBackward0>)
# see result result and help result pickedoon
# i starting? neck each greet frustration start
# 262 tensor(70187.3828, device='cuda:0', grad_fn=<NllLossBackward0>)
# been in minute i means been in i
# . m'' common and your touch
# 263 tensor(61009.7461, device='cuda:0', grad_fn=<NllLossBackward0>)
# are catch. my keys to means off
# . cool.. date.? seth
# 264 tensor(63057.2695, device='cuda:0', grad_fn=<NllLossBackward0>)
# blown challenge thirteen recent alexandra dealt l following
# leaning aimed i does and created to for
# 265 tensor(64318.5508, device='cuda:0', grad_fn=<NllLossBackward0>)
# she fell she the ` the fell red
# said male m hands casey in a a
# 266 tensor(63527.7070, device='cuda:0', grad_fn=<NllLossBackward0>)
# the although, the was the was,
# . of that '. hear your on
# 267 tensor(67474.8125, device='cuda:0', grad_fn=<NllLossBackward0>)
# wake seat use use that kill as use
# appeared theway smileness tos i
# 268 tensor(62621.5547, device='cuda:0', grad_fn=<NllLossBackward0>)
# glove took how daggers with dismissed loose must
# do, agony made wonderful myself i ask
# 269 tensor(60467.2734, device='cuda:0', grad_fn=<NllLossBackward0>)
# they they speakers. monster could its.
# ?dling his are had * think.
# 270 tensor(56402.1406, device='cuda:0', grad_fn=<NllLossBackward0>)
# chloe printying throat wind we to knew
# his and he towardt from wasn amber
# 271 tensor(51550.4531, device='cuda:0', grad_fn=<NllLossBackward0>)
# find through nurse they never he wanted bolted
# . s of of, guy. a
# 272 tensor(51878.5430, device='cuda:0', grad_fn=<NllLossBackward0>)
# ##ly his say he had. that find
# my could whisperingt with.? now
# 273 tensor(44971.0430, device='cuda:0', grad_fn=<NllLossBackward0>)
# ##ping couchrb wanted grinning his but fine
# . n'sir a jo where '
# 274 tensor(38032.1914, device='cuda:0', grad_fn=<NllLossBackward0>)
# reached changed exactly dripping taken. tonight want
# of you eaauria added right fury
# 275 tensor(45543.3594, device='cuda:0', grad_fn=<NllLossBackward0>)
# you convince.'knew generally sighswork
# of of. ther a 3 did
# 276 tensor(42471.4844, device='cuda:0', grad_fn=<NllLossBackward0>)
# use told draw couch. boy. '
# through trouble to keep toward it m everything
# 277 tensor(35300.6055, device='cuda:0', grad_fn=<NllLossBackward0>)
# birthday boyfriend kicked couch suddenly final he boyfriend
# from frame so understand didn will be.
# 278 tensor(37362.1133, device='cuda:0', grad_fn=<NllLossBackward0>)
# , be about? of k they brave
# weapons us like an from'' on
# 279 tensor(39652.4648, device='cuda:0', grad_fn=<NllLossBackward0>)
# . it ruined '! the it it
# hair, to a i'got n
# 280 tensor(32163.4453, device='cuda:0', grad_fn=<NllLossBackward0>)
# up stretching anguish the flowers mouth occasionally cubic
# know a, to re s of take
# 281 tensor(38336.6445, device='cuda:0', grad_fn=<NllLossBackward0>)
# the a to their ` and a and
# brought? learn i'connor right when
# 282 tensor(34999.2734, device='cuda:0', grad_fn=<NllLossBackward0>)
# her in thirsty pulledling trust by `
# i shook'ever broke house i so
# 283 tensor(29879.5918, device='cuda:0', grad_fn=<NllLossBackward0>)
# . eye susan susan. about, in
# raising you ofria if you untilgos
# 284 tensor(34763.9102, device='cuda:0', grad_fn=<NllLossBackward0>)
# jameson sharply will retrieved him housekeeper ob burst
# lookmini'the t didri authorities
# 285 tensor(31855.8594, device='cuda:0', grad_fn=<NllLossBackward0>)
# yo. the come.'back!
# wait had were ear. this you he
# 286 tensor(26916.1680, device='cuda:0', grad_fn=<NllLossBackward0>)
# we the i off some searched very.
# the how s as, breath ward could
# 287 tensor(28086.8398, device='cuda:0', grad_fn=<NllLossBackward0>)
# had eh security to ` fell front eh
# the melted auditioned it room built would my
# 288 tensor(27854.9121, device='cuda:0', grad_fn=<NllLossBackward0>)
# head only chapter on word loved relieved found
# i'monday and the eye answer,
# 289 tensor(25077.9980, device='cuda:0', grad_fn=<NllLossBackward0>)
# body like i down equally had the i
# would! he ` came my way learned
# 290 tensor(23857.6445, device='cuda:0', grad_fn=<NllLossBackward0>)
# thought of day been by the sight valley
# near hours you a. rooms that earth
# 291 tensor(22124.9414, device='cuda:0', grad_fn=<NllLossBackward0>)
# balance teacher is number nuts is drinking a
# ' you ri ', the to once
# 292 tensor(22425.3828, device='cuda:0', grad_fn=<NllLossBackward0>)
# kitchen shut um heries at's
# tomorrow up slowing there too. jace t
# 293 tensor(22420.5020, device='cuda:0', grad_fn=<NllLossBackward0>)
# pl the..enia at indeed of
# important ` moaned jorge the whereves his
# 294 tensor(21745.5332, device='cuda:0', grad_fn=<NllLossBackward0>)
# ' to.. i her s of
# want women face she us to ` pulled
# 295 tensor(21086.3926, device='cuda:0', grad_fn=<NllLossBackward0>)
# ##ria regain bathroom window blood found me take
# the volunteered no intoner world right out
# 296 tensor(20668.5312, device='cuda:0', grad_fn=<NllLossBackward0>)
# thankfully i i i n, i she
# herself n '?, ` a be
# 297 tensor(18974.7715, device='cuda:0', grad_fn=<NllLossBackward0>)
# she n, constantly you wci o
# more. to father body of kind you
# 298 tensor(22057.7754, device='cuda:0', grad_fn=<NllLossBackward0>)
# and. would im probably., and
# of to going a - we up tell
# 299 tensor(22674.4258, device='cuda:0', grad_fn=<NllLossBackward0>)
# told and insides was fake list, '
# the they you tenor theyund.,
# ` mess br to thought had be was
# do, door me realized me it my
# to to him to to and. '
# on.. the.? thebo
# had and and to ` you typed piper
# a display her. then and the sex
# needs., final die,. '
# worthy could. she., he if
# had... some to. to
# panicked chest was fairly he, cathedral handgun
# and oneppet. juice to, she
# with trying ryder t ` inside the.
# be gear she. to die lead.
# building the there seen to threaded, wears
# will.o him. to ',
# away to the his where last tunic mountains
# was vacuum ` ` to away talked hand
# i behind t splinter'' russia,
# Loss at step = 300 for train data is 1071.4042 for val it is 1129.7500
# she,. ` and and to child
# read both from'not she evan ready
# 300 tensor(17152.8789, device='cuda:0', grad_fn=<NllLossBackward0>)
# to? sound together crumbling mess mess arching
# ''whistled to much ', ruin
# 301 tensor(16759.5527, device='cuda:0', grad_fn=<NllLossBackward0>)
# probablyper bad'of of jo twelve
# , like,'sharp about am the
# 302 tensor(18814.6660, device='cuda:0', grad_fn=<NllLossBackward0>)
# t'spa his'in, his
# many he considered part aden the at some
# 303 tensor(19436.5039, device='cuda:0', grad_fn=<NllLossBackward0>)
# into that in bandits knew i the chop
# you twin that going but. of is
# 304 tensor(22400.8047, device='cuda:0', grad_fn=<NllLossBackward0>)
# the free english possibility that sterling wake the
# trek and not improved should on i red
# 305 tensor(25285.7578, device='cuda:0', grad_fn=<NllLossBackward0>)
# home women was merchandise we about about completely
# g be friends at fall walked make that
# 306 tensor(20330.9414, device='cuda:0', grad_fn=<NllLossBackward0>)
# of waters glanced posted to. had the
# , as of said i, to he
# 307 tensor(18001.7051, device='cuda:0', grad_fn=<NllLossBackward0>)
# ' grease, explained his andoo and
# long did minute'of much a the
# 308 tensor(21736.8926, device='cuda:0', grad_fn=<NllLossBackward0>)
# and not without needed truth down team loudly
# the likes ` n so was he,
# 309 tensor(19117.2148, device='cuda:0', grad_fn=<NllLossBackward0>)
# could had. you scratches drinks her s
# the to. how was knowing lifts.
# 310 tensor(17701.0645, device='cuda:0', grad_fn=<NllLossBackward0>)
# was mana. s about she. her
# interte who'there that. there
# 311 tensor(21467.6738, device='cuda:0', grad_fn=<NllLossBackward0>)
# . am information fast carried back my able
# was'tapestry'when - naomi his
# 312 tensor(17201.4590, device='cuda:0', grad_fn=<NllLossBackward0>)
# support besides if ka granted my * saw
# twelve apocalypse rye it'' sweet,
# 313 tensor(17262.0684, device='cuda:0', grad_fn=<NllLossBackward0>)
# , surrounded mood. friends gettingv took
# really more ` on his to away move
# 314 tensor(19992.0938, device='cuda:0', grad_fn=<NllLossBackward0>)
# there of we skirt in the stuff planting
# you as. himself -,, of
# 315 tensor(18276.4570, device='cuda:0', grad_fn=<NllLossBackward0>)
# he on to and into itness,
# alternating glanced their above now swung so picked
# 316 tensor(20225.3203, device='cuda:0', grad_fn=<NllLossBackward0>)
# settled can models on happy sustaining baby yes
# choose leaves. court been re approach,
# 317 tensor(22091.6816, device='cuda:0', grad_fn=<NllLossBackward0>)
# our here do my orrow ice he
# that ourcum one problems in'like
# 318 tensor(15232.4658, device='cuda:0', grad_fn=<NllLossBackward0>)
# he to to to'he my he
# feature to had, her the the `
# 319 tensor(17519.9551, device='cuda:0', grad_fn=<NllLossBackward0>)
# weekend manor widowpa substantial attendance activities lower
# and, path so thousand worth elserbin
# 320 tensor(20576.0254, device='cuda:0', grad_fn=<NllLossBackward0>)
# off do mo afterwards stealpas that it
# ##t ` i'i aively the
# 321 tensor(17148.7734, device='cuda:0', grad_fn=<NllLossBackward0>)
# in, yes.. understand, and
# her after. warehouse the where, result
# 322 tensor(18022.0723, device='cuda:0', grad_fn=<NllLossBackward0>)
# then first hoping but aware find would he
# blood my with been it effects down could
# 323 tensor(14809.0947, device='cuda:0', grad_fn=<NllLossBackward0>)
# ` us water i he sister he sharp
# a standing not her delilah might man out
# 324 tensor(18842.1719, device='cuda:0', grad_fn=<NllLossBackward0>)
# vanished shit as had burnt me boyfriend annoying
# lack to. fought and border pe if
# 325 tensor(22044.2188, device='cuda:0', grad_fn=<NllLossBackward0>)
# , clothes had from. them. had
# right bigger like ava than with guy '
# ...
# 1366 tensor(773.8983, device='cuda:0', grad_fn=<NllLossBackward0>)
# with understand `ing bitch an. most
# re uss that thought train protection say
# 1367 tensor(768.1645, device='cuda:0', grad_fn=<NllLossBackward0>)
# , said.., to. to
# onto to womanls. newly doctor though
# 1368 tensor(822.6122, device='cuda:0', grad_fn=<NllLossBackward0>)
# mor and he at.s amazed into
# you crime home spent - you,,
# 1369 tensor(750.6376, device='cuda:0', grad_fn=<NllLossBackward0>)
# no, stillmas?'stocked a
# him ` dead. beyond youmis as
# 1370 tensor(934.6700, device='cuda:0', grad_fn=<NllLossBackward0>)
# talk larger about killed its fierce f `
# a marshal. much dad waist out i
# 1371 tensor(776.0297, device='cuda:0', grad_fn=<NllLossBackward0>)
# that does the and all the are of
# ##s anyr ban being what a stock
# 1372 tensor(879.3120, device='cuda:0', grad_fn=<NllLossBackward0>)
# and it smiled she, in ` bread
# a to, k gotten ever that from
# 1373 tensor(758.7480, device='cuda:0', grad_fn=<NllLossBackward0>)
# , they utility, thought, them operatives
# sun feeds, had here your '
# 1374 tensor(1001.1030, device='cuda:0', grad_fn=<NllLossBackward0>)
# drew of.'i of chair d
# up real with'and. of his
# 1375 tensor(759.7318, device='cuda:0', grad_fn=<NllLossBackward0>)
# anything to '. know loose 'uri
# the have ` around'and quietlysant
# 1376 tensor(708.6276, device='cuda:0', grad_fn=<NllLossBackward0>)
# ' to top to few eight up '
# ' of accent the really alive, toward
# 1377 tensor(719.7625, device='cuda:0', grad_fn=<NllLossBackward0>)
# normally.'custom own save back '
# supposed'needs win hint take, b
# 1378 tensor(746.8766, device='cuda:0', grad_fn=<NllLossBackward0>)
# wouldn they at ear adjective them agreed a
# above, eaten'design and buckle question
# 1379 tensor(783.5577, device='cuda:0', grad_fn=<NllLossBackward0>)
# info thanks enjoyed see by are almost rafael
# what night death as lookedrle his out
# 1380 tensor(699.0099, device='cuda:0', grad_fn=<NllLossBackward0>)
# more n '. his under run and
# to i she it, john feet.
# 1381 tensor(835.5623, device='cuda:0', grad_fn=<NllLossBackward0>)
# a. to. thick he. friends
# went regular. for wear promised to '
# 1382 tensor(730.2938, device='cuda:0', grad_fn=<NllLossBackward0>)
# stationed themselves.. i been readily.
# still sighed tight from when no my.
# 1383 tensor(655.8751, device='cuda:0', grad_fn=<NllLossBackward0>)
# put there looked'flying sinks'soul
# . you should leaving him to prefer keep
# 1384 tensor(713.4702, device='cuda:0', grad_fn=<NllLossBackward0>)
# look scanning thel my she was official
# has would yeah to but book of he
# 1385 tensor(672.6314, device='cuda:0', grad_fn=<NllLossBackward0>)
# was with next and as to. to
# in tie in kill,'to in
# 1386 tensor(680.1705, device='cuda:0', grad_fn=<NllLossBackward0>)
# read gut my specifically of was between.
# him will. shrieked you not going,
# 1387 tensor(766.6613, device='cuda:0', grad_fn=<NllLossBackward0>)
# bolt firstfy of rememberedber at who
# .. was idea grin, floor,
# 1388 tensor(615.8309, device='cuda:0', grad_fn=<NllLossBackward0>)
# in, stood you. stoodt of
# ' about you is at. what my
# 1389 tensor(690.2039, device='cuda:0', grad_fn=<NllLossBackward0>)
# . it city to a, anda
# ` stop'position did ever else '
# 1390 tensor(626.3181, device='cuda:0', grad_fn=<NllLossBackward0>)
# ' hand b looked tried. be night
# or went me than head we lies of
# 1391 tensor(632.3460, device='cuda:0', grad_fn=<NllLossBackward0>)
# up i t ` i. more mind
# body i more'standard more attend never
# 1392 tensor(663.8873, device='cuda:0', grad_fn=<NllLossBackward0>)
# n alerted have the earth '. es
# had zone, a colby you pile few
# 1393 tensor(627.3044, device='cuda:0', grad_fn=<NllLossBackward0>)
# ''i,'pushed - mouth
# travels looked he jen the ryan he m
# 1394 tensor(538.9329, device='cuda:0', grad_fn=<NllLossBackward0>)
# ,'was then ages left name his
# hands not'the'to. dancing
# 1395 tensor(495.9032, device='cuda:0', grad_fn=<NllLossBackward0>)
# more why her much matter paper the did
# allow do and she day a the s
# 1396 tensor(688.7043, device='cuda:0', grad_fn=<NllLossBackward0>)
# since ligament worry. in see paper lashes
# single asleep song him do, up d
# 1397 tensor(623.3498, device='cuda:0', grad_fn=<NllLossBackward0>)
# he if. over againstvot substitutes from
# ' lips parts. about next designer could
# 1398 tensor(505.1186, device='cuda:0', grad_fn=<NllLossBackward0>)
# a. people. for ` but a
# . of back that a weree?
# 1399 tensor(574.5436, device='cuda:0', grad_fn=<NllLossBackward0>)
# . s vr -zo'my hair
# ##s a, squashlor now want both
# trigger the power hands dayton is 'lls
# the under'for br'what her
# cisco city helllli to'apartment.
# he draped fairfield closed ` to into she
# ##ari kind swallowed you it of - steps
# ##lish'staring and inch something was know
# leaned hayward `'the emcture she
# . ',, the in than bite
# theois rocky make emblem dayton was be
# , it,. but to back point
# hayward bureau imagine huh dayton other'taken
# shivering steady it janice ride picture. covenant
# flew is holm voice 'zone'you
# to ` there war in was roughly but
# - your slls she children night we
# ? ` t sideways'he and exactly
# other a kidding access checkedtom s -
# ' mis then trap rubs to!,
# Loss at step = 1400 for train data is 34.5247 for val it is 36.2201
# ##ites i his mace stared light open woman
# to courageous they he frowned flames can daughter
# 1400 tensor(540.9869, device='cuda:0', grad_fn=<NllLossBackward0>)
# mouth. lock which the he even thirty
# figure s would a in'of n
# 1401 tensor(527.3822, device='cuda:0', grad_fn=<NllLossBackward0>)
# to i'- scroll there will gaze
# about how practice executive to ;cut of
# 1402 tensor(795.6138, device='cuda:0', grad_fn=<NllLossBackward0>)
# ', fog me was them'joined
# '. i had with you papert
# 1403 tensor(537.0757, device='cuda:0', grad_fn=<NllLossBackward0>)
# ' that ll herping m be -
# ` sanchez'we fine. bad `
# 1404 tensor(592.4481, device='cuda:0', grad_fn=<NllLossBackward0>)
# , you, the'if you he
# us butci over'to until hell
# 1405 tensor(550.5980, device='cuda:0', grad_fn=<NllLossBackward0>)
# to it the i and. had said
# companions matter people for hot our line we
# 1406 tensor(662.8627, device='cuda:0', grad_fn=<NllLossBackward0>)
# m summon predator writhing. soul was were
# 'ed eyes a, and one shit
# 1407 tensor(641.8855, device='cuda:0', grad_fn=<NllLossBackward0>)
# look deep the she honolulu house two n
# thinkingication this signalss uncle the,
# 1408 tensor(705.8621, device='cuda:0', grad_fn=<NllLossBackward0>)
# cutting mya he into at walked and
# ''was of of that fine to
# 1409 tensor(577.2473, device='cuda:0', grad_fn=<NllLossBackward0>)
# and to on..'to '
# him su. yeah his fromrri `
# 1410 tensor(550.8204, device='cuda:0', grad_fn=<NllLossBackward0>)
# doesy said'the right laugh the
# climbing `,'to eyes `.
# 1411 tensor(647.4453, device='cuda:0', grad_fn=<NllLossBackward0>)
# they. looking. hadn. at.
# had,. know she about? high
# 1412 tensor(551.9280, device='cuda:0', grad_fn=<NllLossBackward0>)
# , to'what we the. had
# stop answered ` come he only told '
# 1413 tensor(478.4872, device='cuda:0', grad_fn=<NllLossBackward0>)
# same was hilly? that foot for would
# the muchthus plan horn beenating the
# 1414 tensor(775.0923, device='cuda:0', grad_fn=<NllLossBackward0>)
# .'with tight id? my was
# whatle k my obscene her which of
# 1415 tensor(562.8620, device='cuda:0', grad_fn=<NllLossBackward0>)
# make it still window mind closeo really
# blinked me theres as unfortunately drop great
# 1416 tensor(540.4695, device='cuda:0', grad_fn=<NllLossBackward0>)
# - hisamp really anyway a want,
# `'danger ',llen the.
# 1417 tensor(597.5095, device='cuda:0', grad_fn=<NllLossBackward0>)
# keep bradford bethany shoes may guess that tone
# provide. him there her spoilful show
# 1418 tensor(654.7658, device='cuda:0', grad_fn=<NllLossBackward0>)
# . likely six the six pet her
# , dirt upls mys hers too
# 1419 tensor(617.5914, device='cuda:0', grad_fn=<NllLossBackward0>)
# pretend to but gr her. wait en
# head we we he that argument since marry
# 1420 tensor(614.2828, device='cuda:0', grad_fn=<NllLossBackward0>)
# but.'a why he from all
# again andr metal a down out gone
# 1421 tensor(773.2633, device='cuda:0', grad_fn=<NllLossBackward0>)
# much should s by? how d '
# ke. t she she camp t t
# 1422 tensor(537.7903, device='cuda:0', grad_fn=<NllLossBackward0>)
# see withss capital. do is.
# miss to, that a celebrate her crack
# 1423 tensor(658.8862, device='cuda:0', grad_fn=<NllLossBackward0>)
# ##ging she where squad there.list know
# .,,'held. ` failed
# 1424 tensor(573.0676, device='cuda:0', grad_fn=<NllLossBackward0>)
# last ve. scratch and t is wrong
# take ` ` women against d off and
# 1425 tensor(571.1349, device='cuda:0', grad_fn=<NllLossBackward0>)
# ahead still enrique, thinksies,.
# at get work it'him you -
# 1426 tensor(573.8359, device='cuda:0', grad_fn=<NllLossBackward0>)
# and'''over arms i trying
# bigs music, for sigh then she
# 1427 tensor(730.4307, device='cuda:0', grad_fn=<NllLossBackward0>)
# it imagine effect thing at i and shook
# ' what,s in ex i horde
# 1428 tensor(628.4427, device='cuda:0', grad_fn=<NllLossBackward0>)
# ##hi who talonat the tree hu stumble
# bo you my him ` write realizing got
# 1429 tensor(577.7261, device='cuda:0', grad_fn=<NllLossBackward0>)
# my i, the look,. he
# ae likely johnny toward my they if
# 1430 tensor(568.8226, device='cuda:0', grad_fn=<NllLossBackward0>)
# the his i of blamed.,.
# filled shut the going very enough brother battles
# 1431 tensor(603.3436, device='cuda:0', grad_fn=<NllLossBackward0>)
# hundredach'me withs sat either
# but after hatch know we we very thickness
# 1432 tensor(703.5359, device='cuda:0', grad_fn=<NllLossBackward0>)
# pressed glass have let were tyrone to.
# the sts hairave thick. dead to
# 1433 tensor(609.7861, device='cuda:0', grad_fn=<NllLossBackward0>)
# have tea then human he the of,
# i, watch groan what lips'out
# 1434 tensor(548.0079, device='cuda:0', grad_fn=<NllLossBackward0>)
# ''to and the this in hiding
# hair `'that a and he '
# 1435 tensor(598.9611, device='cuda:0', grad_fn=<NllLossBackward0>)
# ' never in to, and going king
# said service ` head clive yes individual undeveloped
# 1436 tensor(739.8945, device='cuda:0', grad_fn=<NllLossBackward0>)
# ' another? out most pulling too turned
# the ', e spirit should lunch a
# 1437 tensor(759.3305, device='cuda:0', grad_fn=<NllLossBackward0>)
# ##k ka - don dripped someone tapes.
# shoulder to to the and?'t
# 1438 tensor(623.3032, device='cuda:0', grad_fn=<NllLossBackward0>)
# slept clinic princess in from smalll `
# , various meanwhile toils the toward.
# 1439 tensor(705.3204, device='cuda:0', grad_fn=<NllLossBackward0>)
# ' out to''? ve and
# there the much it and be be,
# 1440 tensor(587.1716, device='cuda:0', grad_fn=<NllLossBackward0>)
# ..., in i or.
# ' he `, ` shooter. heart
# 1441 tensor(637.9401, device='cuda:0', grad_fn=<NllLossBackward0>)
# trust. added. said marker could and
# in prick forced he shirt sad your hand
# 1442 tensor(660.5738, device='cuda:0', grad_fn=<NllLossBackward0>)
# time and son watching had just for your
# of her floor stryker protecting him was back
# 1443 tensor(587.5028, device='cuda:0', grad_fn=<NllLossBackward0>)
# tongue felt they i. do president `
# of'gone then essence lily him me
# 1444 tensor(597.5045, device='cuda:0', grad_fn=<NllLossBackward0>)
# tongue be body - that this tavi was
# and ride it so t a, portion
# 1445 tensor(573.2447, device='cuda:0', grad_fn=<NllLossBackward0>)
# please, you control damn she through.
# wedt t and'either table next
# 1446 tensor(498.3933, device='cuda:0', grad_fn=<NllLossBackward0>)
# sent you that of ` behind tal this
# un ` casualties here in'tar bug
# 1447 tensor(538.5714, device='cuda:0', grad_fn=<NllLossBackward0>)
# `'me on, still reach i
# ' ready left than the heart,.
# 1448 tensor(496.2237, device='cuda:0', grad_fn=<NllLossBackward0>)
# she'about'was mouth with into
# `'the. auk now she
# 1449 tensor(609.2670, device='cuda:0', grad_fn=<NllLossBackward0>)
# at not it, dirty. ones '
# were'handered the be them simon
# 1450 tensor(619.2122, device='cuda:0', grad_fn=<NllLossBackward0>)
# ogden his depression. glances alaska week flared
# already would, `gr he'`
# 1451 tensor(627.3004, device='cuda:0', grad_fn=<NllLossBackward0>)
# . of began face'job you out
# ., z, t a through human
# 1452 tensor(504.8275, device='cuda:0', grad_fn=<NllLossBackward0>)
# done back'the sigh. the the
# that. yout him knife alright should
# 1453 tensor(722.6522, device='cuda:0', grad_fn=<NllLossBackward0>)
# the ever. ` girl'it choice
# in once one what in queener win
# 1454 tensor(673.6853, device='cuda:0', grad_fn=<NllLossBackward0>)
# swke hour unable line 57 tears by
# oneo the were or was look assured
# 1455 tensor(612.3353, device='cuda:0', grad_fn=<NllLossBackward0>)
# , in. as it almost the air
# got five arrows should on light. table
# 1456 tensor(618.5130, device='cuda:0', grad_fn=<NllLossBackward0>)
# . to only she position nowhere to new
# , sipped the hand you quite bob into
# 1457 tensor(606.2484, device='cuda:0', grad_fn=<NllLossBackward0>)
# ##er organ'as and it that and
# mother'walked'was need his fireplace
# 1458 tensor(524.3586, device='cuda:0', grad_fn=<NllLossBackward0>)
# that next and her said me,.
# dance of behind iis off bought '
# 1459 tensor(484.7780, device='cuda:0', grad_fn=<NllLossBackward0>)
# for i to looked been thing. talk
# it another'them walks me o her
# 1460 tensor(545.8895, device='cuda:0', grad_fn=<NllLossBackward0>)
# busy camera squintedcatt, him is
# fate as my come an wonder spoke rise
# 1461 tensor(580.3800, device='cuda:0', grad_fn=<NllLossBackward0>)
# the was no would few.,
# the, thick tosa vowed where even
# 1462 tensor(517.7552, device='cuda:0', grad_fn=<NllLossBackward0>)
# then head were little nothing'stream get
# ` but and ` who going nng
# 1463 tensor(462.5351, device='cuda:0', grad_fn=<NllLossBackward0>)
# not wife quiet huh,s ` stream
# pulled have another him'want. of
# 1464 tensor(500.4759, device='cuda:0', grad_fn=<NllLossBackward0>)
# ' what.. it and either more
# to would door his done ` sutton '
# 1465 tensor(618.6734, device='cuda:0', grad_fn=<NllLossBackward0>)
# ' lived a your we, him hurt
# the kitchen low considered and will having up
# 1466 tensor(666.2491, device='cuda:0', grad_fn=<NllLossBackward0>)
# hands afterward get?acies jim brushed room
# of over breath to noeonress ste
# 1467 tensor(642.7390, device='cuda:0', grad_fn=<NllLossBackward0>)
# he my he n afraid and all d
# ' she t about someone back them d
# 1468 tensor(485.4260, device='cuda:0', grad_fn=<NllLossBackward0>)
# voice a -. by like don like
# eyes for face look there. could valentine
# 1469 tensor(530.5749, device='cuda:0', grad_fn=<NllLossBackward0>)
# sending. not lived. some near had
# as the see and at from healinglia
# 1470 tensor(668.0198, device='cuda:0', grad_fn=<NllLossBackward0>)
# want my him continued and save made.
# ,.. - at and to deemed
# 1471 tensor(497.2573, device='cuda:0', grad_fn=<NllLossBackward0>)
# people had, the hair used f who
# instantlytale electrical'anyone ', `
# 1472 tensor(495.8925, device='cuda:0', grad_fn=<NllLossBackward0>)
# some changing been to withdrew hitler f screwing
# lucy. then myaint. could vincent
# 1473 tensor(673.1880, device='cuda:0', grad_fn=<NllLossBackward0>)
# not those they bowl i.'like
# in, paul a the face he carry
# 1474 tensor(608.0255, device='cuda:0', grad_fn=<NllLossBackward0>)
# man he was to said it it this
# . the and around she, asked thing
# 1475 tensor(576.8184, device='cuda:0', grad_fn=<NllLossBackward0>)
# traffic wereglass so `, so mu
# ' was does you, 293 ` tired
# 1476 tensor(542.4510, device='cuda:0', grad_fn=<NllLossBackward0>)
# like na one room surged explaining us rocky
# , previousing.. get whatever he
# 1477 tensor(511.9423, device='cuda:0', grad_fn=<NllLossBackward0>)
# have my for do i going taken look
# for'right the the then and fooled
# 1478 tensor(505.6324, device='cuda:0', grad_fn=<NllLossBackward0>)
# , of. story test it for life
# might workedsth - a.,
# 1479 tensor(603.9080, device='cuda:0', grad_fn=<NllLossBackward0>)
# your look defiant winemantion moved.
# started the'were months cab himms
# 1480 tensor(563.3685, device='cuda:0', grad_fn=<NllLossBackward0>)
# to t was, t me,.
# my'theika sure was. tha
# 1481 tensor(501.9564, device='cuda:0', grad_fn=<NllLossBackward0>)
# he giving aions die see, `
# it an through he heat no night them
# 1482 tensor(461.7488, device='cuda:0', grad_fn=<NllLossBackward0>)

# %%
test('Summer season is upon us and you are all set to head to the beach or to an outdoor event. Outfit. Check, Sunglasses. Check. Hat. Check. Sunscreen? Well, check the ingredients before applying it. While sunscreen is essential for protecting your skin')

# %%
test('An apple is')

# %%
test('This was the greatest outcome for me because')

# %%
sum(p.numel() for p in gen.parameters())

# %%
prompt = 'They wanted to fight and '
test(prompt)

# %%
prompt = 'He was walking on the middle of road when a car started coming at high speed behind him '
test(prompt)

# %%
if (not pretrained) or build_pretrained:
    with open('text_generator.pkl', 'wb') as handler:
        pickle.dump(gen, handler)

# %%
with open('text_generator.pkl', 'rb') as handler:
    gen = pickle.load(handler)

# %%
if (not pretrained) or build_pretrained:
    # create a PyTorch optimizer
    # optimizer = torch.optim.AdamW(gen.parameters(), lr=learning_rate, weight_decay=0.01, amsgrad=True)

    for iter in range(iterations):
        try:
            
            if (iter != 0) and (iter % eval_iters == 0):
                losses = estimate_loss()
                train_loss = losses['train']
                val_loss = losses['val']
                print(f'Loss at step = {iter} for train data is {train_loss:.4f} for val it is {val_loss:.4f}')

            # sample a batch of data
            xb, yb = get_batch('train')

            # evaluate the loss
            logits, loss = gen.forward(xb, yb, tokenizer)
            if not torch.isnan(loss).any():
                test_deep(logits, yb)
                print(iter, loss)
                optimizer.zero_grad(set_to_none=True)
                loss.backward()
                # torch.torch.nn.utils.clip_grad_norm_(gen.parameters(), max_norm=15.0)
                optimizer.step()
            else:
                print('NaN loss')
                print(iter, loss)
                input()
        except Exception as e:
            print(e)
